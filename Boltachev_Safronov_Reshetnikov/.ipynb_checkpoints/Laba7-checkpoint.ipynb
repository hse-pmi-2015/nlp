# %%
import pandas as pd
import numpy as np
import re
import string
import stop_words

# %%
FILE_UNIGRAMS = '1grams-3.txt'
N_WORDS = 192689044
TOL = 1e-20

# %%
frequencies = {}

with open(FILE_UNIGRAMS, 'r') as f:
    for line in f:
        split = line.strip().split('\t')
        try:
            freq, word = split
        except:
            print(split)
        frequencies[word] = float(freq) / N_WORDS

# %%
frequencies
# Out:
# {'и': 0.03544554406528687,
#  'в': 0.026935703723767503,
#  'не': 0.016424908932549376,
#  'на': 0.014163804767229008,
#  'с': 0.010713676071795759,
#  'что': 0.010712482438804356,
#  'как': 0.005949393780790152,
#  'я': 0.005668080433260129,
#  'к': 0.005429950651475546,
#  'он': 0.005400986887453757,
#  'по': 0.005038849017279882,
#  'а': 0.004994212333110128,
#  'его': 0.004828671006328725,
#  'из': 0.004079432767334711,
#  'это': 0.0037862505561032313,
#  'от': 0.003687443692958485,
#  'все': 0.0036104128473438274,
#  'за': 0.0035842411465801865,
#  'у': 0.003491381689557814,
#  'же': 0.003450528302999936,
#  'то': 0.003430973480775586,
#  'В': 0.003386051362629626,
#  'но': 0.003311750303769217,
#  'о': 0.0031870831223803258,
#  'И': 0.0030450511758208735,
#  'А': 0.0030051942133253826,
#  'было': 0.002991820334113028,
#  'для': 0.0028078451621774613,
#  'так': 0.002773961554347636,
#  'Я': 0.0025945948437006102,
#  'бы': 0.002519925315525464,
#  'только': 0.002400779984148969,
#  'был': 0.002230671713748292,
#  'ее': 0.002186169962003652,
#  'она': 0.0021835958665091513,
#  'Но': 0.002125777322347398,
#  'или': 0.002119227910020665,
#  'меня': 0.002098313384127849,
#  'их': 0.002056572557389407,
#  'еще': 0.002053225195304825,
#  'мне': 0.0020140947920214915,
#  'мы': 0.0019564319391194864,
#  'до': 0.0019428193333088518,
#  'уже': 0.0019045919393320568,
#  'Он': 0.0017430674470521532,
#  'они': 0.0016822233027426303,
#  'когда': 0.001583478716101783,
#  'ни': 0.001482149654549119,
#  'ему': 0.001447632902262985,
#  'чтобы': 0.0013833687399476642,
#  'быть': 0.0013412905821464348,
#  'ты': 0.0013301638467831103,
#  'время': 0.0012849095872830216,
#  'при': 0.001278484727964087,
#  'есть': 0.0012620541103520136,
#  'были': 0.0012567709869378977,
#  'была': 0.0012483117618249224,
#  'даже': 0.00124301825899349,
#  'вы': 0.001242374735119865,
#  'если': 0.001237325148595371,
#  'сказал': 0.0011971100962024598,
#  'очень': 0.001194162341684564,
#  'ли': 0.0011929842778191375,
#  'Это': 0.0011815409702276587,
#  'может': 0.0011765225219551143,
#  'во': 0.001174706123924721,
#  'себя': 0.0011391202916549838,
#  'Не': 0.001132306204186679,
#  'него': 0.001116368608897141,
#  'под': 0.0011015779392210799,
#  'нас': 0.001097747934231279,
#  'со': 0.0010971822559875278,
#  'того': 0.0010768178392124878,
#  'На': 0.001062130963709592,
#  'чем': 0.001039721801723195,
#  'будет': 0.0010394623162902816,
#  'этого': 0.0010236440842998837,
#  'где': 0.0010018784461871117,
#  'без': 0.0010008872118333826,
#  'этом': 0.0009826142476476243,
#  'нет': 0.0009614661848651862,
#  'себе': 0.0009349882912907077,
#  'раз': 0.0009219828813930905,
#  'вот': 0.0009075503016144499,
#  'том': 0.000902734251979578,
#  'Да': 0.0008949652581181522,
#  'можно': 0.0008791833540883622,
#  'них': 0.000875119812208939,
#  'которые': 0.0008680981363943038,
#  'да': 0.0008596337215726702,
#  'всех': 0.0008522591455692727,
#  'С': 0.0008508112168536163,
#  'более': 0.0008410597542847325,
#  'тем': 0.0008284695210797766,
#  'там': 0.0008098903640831806,
#  'человек': 0.0007992722201683661,
#  'Как': 0.000796334845067787,
#  'теперь': 0.0007890692529462132,
#  'этот': 0.000783370952839436,
#  'который': 0.0007742163067662529,
#  'после': 0.0007644337059454195,
#  'Что': 0.0007548016066756759,
#  'жизни': 0.0007545006035734964,
#  'Ну': 0.0007471312172787572,
#  'ничего': 0.0007299636610372098,
#  'потому': 0.0007225423776558879,
#  'лет': 0.0007094331735851054,
#  'один': 0.0007052710272411752,
#  'Вот': 0.0007027125008726495,
#  'надо': 0.0006975487407576738,
#  'года': 0.0006948864202159828,
#  'Она': 0.0006881916960468183,
#  'своей': 0.0006870032527640751,
#  'всего': 0.0006770338224315442,
#  'тоже': 0.0006721087889148487,
#  'Так': 0.0006697941788532617,
#  'через': 0.0006604682723943558,
#  'тут': 0.0006585428904821387,
#  'потом': 0.0006576346914669419,
#  'им': 0.0006573025501128128,
#  'этой': 0.0006571987559396475,
#  'У': 0.0006538773423983566,
#  'ним': 0.0006469438916309119,
#  'больше': 0.0006445670050654255,
#  'нам': 0.00064317616314501,
#  'Мы': 0.0006427557967436903,
#  '1': 0.0006424911216021187,
#  'здесь': 0.0006415829225869219,
#  'вас': 0.0006381421457464909,
#  'тогда': 0.0006322570161280161,
#  'эти': 0.0006307831388690683,
#  'Все': 0.0006299112678144794,
#  'об': 0.000629418245491944,
#  'между': 0.000623725135093825,
#  'несколько': 0.0006214312838668711,
#  'кто': 0.0006209019335837278,
#  'сам': 0.0006018557028078877,
#  'дело': 0.0005984045465501401,
#  'всегда': 0.0005960172805673373,
#  'день': 0.0005950312359222665,
#  'перед': 0.0005904331540510419,
#  'ней': 0.0005869456698326865,
#  'два': 0.0005805986561436259,
#  'ей': 0.000579571093829289,
#  'над': 0.0005751806003043951,
#  'свою': 0.0005748121309896581,
#  '2': 0.0005661453175303522,
#  'Если': 0.0005652371185151554,
#  'вам': 0.0005600370304395719,
#  'тебя': 0.0005543335406241363,
#  'сейчас': 0.000539771218129039,
#  'жизнь': 0.0005375136948626929,
#  'много': 0.000531898430094448,
#  'людей': 0.0005229669414935703,
#  'По': 0.0005167237219776751,
#  'тебе': 0.0005157584361672374,
#  'Вы': 0.0005125460065077701,
#  'человека': 0.0005103196214933735,
#  'своих': 0.0005009937150344676,
#  'такой': 0.0004965668935489659,
#  'почти': 0.0004935724316531458,
#  'хотя': 0.0004876769226173544,
#  'нее': 0.0004874797136883403,
#  'России': 0.0004870904855389702,
#  'тот': 0.0004865767043818018,
#  'вдруг': 0.0004816983782430308,
#  'своего': 0.0004797885654567885,
#  'люди': 0.00047974704778752235,
#  'также': 0.0004775362318991006,
#  'просто': 0.00047567831619944103,
#  'всем': 0.0004755693323176174,
#  'Ты': 0.0004749828952392332,
#  'г': 0.0004732391531300555,
#  'лишь': 0.00046616039052017926,
#  'сказать': 0.00046516915616645025,
#  'другой': 0.0004606281610904666,
#  'ведь': 0.00045966806498868717,
#  'Они': 0.0004593411133432163,
#  'глаза': 0.0004589985925717707,
#  'свои': 0.00045818899802108103,
#  'мог': 0.00045538136563695857,
#  'говорит': 0.0004545198739996862,
#  'совсем': 0.0004535338293546155,
#  'К': 0.0004472023847915297,
#  'этих': 0.00044684948460276756,
#  'уж': 0.000445770025201848,
#  'которых': 0.0004431751708727145,
#  'стал': 0.00044173762157437453,
#  'которой': 0.00044061664450418885,
#  'Когда': 0.0004400198280084881,
#  'Нет': 0.000436169064184054,
#  'времени': 0.0004319290722102498,
#  'хорошо': 0.00042539522900949156,
#  'году': 0.0004245908241674602,
#  'три': 0.0004195464273516246,
#  'мой': 0.00041176186436422404,
#  'которая': 0.0004049270180612864,
#  '3': 0.00040415894117986283,
#  'конечно': 0.0004036918674006188,
#  'будто': 0.00039851772786832657,
#  'чего': 0.0003967636063418323,
#  'опять': 0.0003939559739577098,
#  'т': 0.0003927104438797257,
#  'что-то': 0.00038962256722805685,
#  'вместе': 0.0003889998021890648,
#  'именно': 0.0003879878090007027,
#  'пока': 0.00038131903337482956,
#  'спросил': 0.0003794351691318786,
#  'никогда': 0.00037850102157339054,
#  'эту': 0.00037705309285773406,
#  'свое': 0.0003766950029603136,
#  'руки': 0.00037306739660818497,
#  'слова': 0.00037056076732624196,
#  'О': 0.0003688377840516973,
#  'нем': 0.0003682357778473383,
#  'одной': 0.00036785692911528483,
#  'других': 0.0003655890264316221,
#  'знаю': 0.00036367921364537987,
#  'нужно': 0.00036213787017387453,
#  'говорил': 0.00035996857195471894,
#  'которого': 0.00035813660479835067,
#  'тех': 0.00035806913858579315,
#  'своим': 0.00035449861902890547,
#  'стороны': 0.00035386547457259685,
#  'друг': 0.0003538602848639386,
#  'такое': 0.0003534295390453024,
#  'эта': 0.00035191933382574674,
#  'должен': 0.0003497500356065911,
#  'образом': 0.0003496721899767171,
#  'случае': 0.00034930372066198015,
#  'совершенно': 0.00034895601018187627,
#  'тому': 0.000347648203599993,
#  'сразу': 0.000343859716279458,
#  'свой': 0.00034103132506070247,
#  'сказала': 0.0003395107404238302,
#  'собой': 0.0003344092568127537,
#  'этим': 0.000331907817239469,
#  'дома': 0.0003295257409653244,
#  'лучше': 0.00032832172855660645,
#  'За': 0.0003282231240920994,
#  'одного': 0.00032684266158900037,
#  'те': 0.0003231060713550481,
#  'против': 0.00032051121702591454,
#  'Мне': 0.00031936429141243757,
#  'оно': 0.0003190217706409919,
#  'место': 0.00031772434347642517,
#  'нельзя': 0.0003163750192252757,
#  '4': 0.0003158716174854238,
#  'всю': 0.00030939486107990654,
#  'лицо': 0.00030937410224527346,
#  'весь': 0.0003077964308131603,
#  'При': 0.0003058451003576519,
#  'про': 0.00030532612949182516,
#  'Для': 0.0003045476731930851,
#  'ко': 0.0003001779385028243,
#  'снова': 0.00029987693540064477,
#  'голову': 0.0002989843055114228,
#  'вообще': 0.0002971782868983459,
#  'могут': 0.00029707968243383883,
#  'двух': 0.00029509202401772254,
#  'кажется': 0.0002919211120275214,
#  'будут': 0.0002863006575506182,
#  'год': 0.0002857038410549175,
#  'должны': 0.00028567789251162615,
#  'руку': 0.0002832439191508989,
#  'вопрос': 0.0002819309228603573,
#  'нашей': 0.0002813133475300236,
#  '5': 0.00028061792656981576,
#  'работы': 0.00028052451181396695,
#  'одна': 0.000279086962515627,
#  'Только': 0.00027856799164980027,
#  'которое': 0.0002778881398155673,
#  'стало': 0.0002758901019821345,
#  'делать': 0.0002753399928643582,
#  'две': 0.0002739335818179678,
#  'Его': 0.00027362219929847177,
#  'наконец': 0.00027342499036945764,
#  'другие': 0.0002731810740625191,
#  'могу': 0.00027290082979497266,
#  'особенно': 0.0002726672929053507,
#  'чтоб': 0.0002723714795118294,
#  'Однако': 0.0002720289587403838,
#  'одно': 0.000271390624575417,
#  'назад': 0.0002700776282848754,
#  'дня': 0.00026906563509651333,
#  'сегодня': 0.0002671246840583215,
#  'самом': 0.00026598813786216097,
#  'никто': 0.0002639330132334872,
#  'куда': 0.0002637980808083723,
#  'говорить': 0.0002636423895486243,
#  'такие': 0.00026308190101353144,
#  'точно': 0.0002606583070701207,
#  'стали': 0.00025864988981937135,
#  'нему': 0.00025853571622888946,
#  'знал': 0.0002583748352604832,
#  'долго': 0.0002581412983708612,
#  'Из': 0.0002579752276937966,
#  'хоть': 0.00025628857237985984,
#  'почему': 0.0002560602251988961,
#  'Теперь': 0.0002554789778291702,
#  'дела': 0.0002542957242550853,
#  'самого': 0.0002541400329953373,
#  'ними': 0.00025283741612211225,
#  'около': 0.00025212642603592966,
#  'После': 0.0002517423875952179,
#  'каждый': 0.0002516593522566856,
#  'часто': 0.0002512078476034164,
#  'первый': 0.00025105734605232666,
#  'быстро': 0.0002503930633440685,
#  'той': 0.0002497754880137347,
#  'например': 0.00024918905093535053,
#  'которую': 0.0002490852567621852,
#  'среди': 0.0002476010000859208,
#  'давно': 0.0002470041835902201,
#  'моей': 0.0002467862158265729,
#  'сделать': 0.00024619458903953046,
#  'прежде': 0.00024474147061521567,
#  'ж': 0.00024329354189955916,
#  'имеет': 0.0002429562108367718,
#  'Потом': 0.0002423282560891215,
#  'таких': 0.00024154979979038144,
#  'деле': 0.00024085437883017365,
#  'деньги': 0.00024081286116090753,
#  'является': 0.00023976972972059585,
#  '10': 0.00023933379419330142,
#  'значит': 0.00023700880471439777,
#  'прямо': 0.00023520278610132084,
#  'всей': 0.00023467862552683586,
#  'хотел': 0.00023371852942505648,
#  'какой': 0.00023343309544885177,
#  'таким': 0.00023252489643365505,
#  'М': 0.00023243148167780624,
#  'сколько': 0.00023236920517390704,
#  '6': 0.00023217199624489288,
#  'менее': 0.00023182947547344726,
#  'видел': 0.0002296186595850255,
#  'этому': 0.0002290166533806665,
#  'котором': 0.0002281084543654698,
#  'стоит': 0.00022800466019230444,
#  'пор': 0.000227646570294884,
#  'кроме': 0.00022674356098834555,
#  'мало': 0.0002254461338237788,
#  'моя': 0.00022525411460342292,
#  'своем': 0.00022489083499734421,
#  'наши': 0.00022476109228088755,
#  'всё': 0.00022363492550204358,
#  'часть': 0.00022196902902273986,
#  'иногда': 0.00022040173700794323,
#  'должно': 0.0002199813706066236,
#  'знает': 0.0002198671970161417,
#  'наших': 0.00021966998808712758,
#  'части': 0.00021945202032348036,
#  'го': 0.00021902646421350245,
#  'довольно': 0.0002186268566468159,
#  'идет': 0.00021675856152983974,
#  'слишком': 0.0002164835069709516,
#  'из-за': 0.00021613060678218944,
#  'действительно': 0.00021583998309732648,
#  'все-таки': 0.00021583479338866822,
#  'большой': 0.00021548189319990605,
#  'слово': 0.00021440762350764478,
#  'сами': 0.00021435053671240386,
#  'рядом': 0.00021426750137387156,
#  'наш': 0.00021336968177599139,
#  'сторону': 0.0002128455212015064,
#  'нашего': 0.000212720968193708,
#  'жить': 0.00021255489751664344,
#  'вся': 0.00021168821617071286,
#  'Ведь': 0.00021151695578499002,
#  'мира': 0.00021150138665901522,
#  'ответил': 0.0002112107629741523,
#  'однако': 0.00021084748336807358,
#  'е': 0.00021076963773819957,
#  'такого': 0.0002107488789035665,
#  'сама': 0.00021042711696675395,
#  'Н': 0.00020895323970780613,
#  'дом': 0.00020839794088137154,
#  'глазами': 0.00020502463025349796,
#  'весьма': 0.0002041216209469595,
#  'места': 0.0002035559427032084,
#  'месте': 0.00020330683668761158,
#  'мои': 0.00020305773067201476,
#  'мной': 0.000202907229120925,
#  'самое': 0.00020259584660142898,
#  'Москве': 0.00020182258001134719,
#  'голос': 0.00020115829730308902,
#  'вполне': 0.0001978057455098485,
#  'чуть': 0.0001969702024158675,
#  'словно': 0.00019670033756563762,
#  'могли': 0.0001964200932980912,
#  'которым': 0.00019627478145565973,
#  'области': 0.00019624364320371013,
#  'самой': 0.0001960256754400629,
#  'отец': 0.00019533025447985512,
#  'начал': 0.00019527316768461417,
#  'конце': 0.00019468673060623001,
#  'власти': 0.00019404320673260488,
#  'Тогда': 0.00019396017139407262,
#  'Кто': 0.00019241363821390905,
#  'мир': 0.00019198289239527288,
#  'лица': 0.00019142240386018004,
#  'казалось': 0.00019141721415152175,
#  'какой-то': 0.00019089824328569506,
#  'равно': 0.00019050382542766677,
#  'моего': 0.00018994333689257393,
#  'сердце': 0.00018973574854624323,
#  'Еще': 0.00018972017942026843,
#  'как-то': 0.00018960600582978656,
#  'годы': 0.00018941917631808895,
#  'пять': 0.00018916488059383387,
#  'дальше': 0.00018909741438127639,
#  'Там': 0.00018897286137347798,
#  'Может': 0.00018893653341287012,
#  'детей': 0.00018884830836567957,
#  'стала': 0.0001885473052635001,
#  'затем': 0.00018846945963362608,
#  'нами': 0.00018792454022450804,
#  'кого': 0.00018779479750805138,
#  'От': 0.00018713051479979319,
#  'буду': 0.00018598877889497445,
#  'ночь': 0.00018533487560403277,
#  'дверь': 0.00018491450920271314,
#  'говорят': 0.00018484704299015568,
#  'друга': 0.00018473805910833207,
#  'должна': 0.00018460312668321712,
#  'города': 0.00018373125562862826,
#  'Здесь': 0.0001830514037943953,
#  'своими': 0.00018274002127489927,
#  'одну': 0.00018234560341687096,
#  'смерти': 0.00018214839448785683,
#  'такая': 0.00018108969392157035,
#  'вокруг': 0.00018099627916572155,
#  'ноги': 0.00017981821530029492,
#  'мысли': 0.00017902418987558006,
#  'ибо': 0.00017844294250585413,
#  'воды': 0.0001780433349391676,
#  'То': 0.00017800181726990145,
#  '8': 0.00017760220970321487,
#  '7': 0.00017729601689237714,
#  'думал': 0.0001765902165148528,
#  'войны': 0.0001765123708849788,
#  'мать': 0.0001765123708849788,
#  'истории': 0.00017626845457804026,
#  'связи': 0.0001759466926412277,
#  'немного': 0.00017578062196416314,
#  '20': 0.00017513190838187978,
#  'силы': 0.00017352828840647527,
#  'Тут': 0.00017348158102855086,
#  'работу': 0.00017332070006014457,
#  'мое': 0.00017270831443846906,
#  'Конечно': 0.00017247477754884705,
#  'мере': 0.00017155619911633378,
#  'следует': 0.00017149911232109284,
#  'дней': 0.00017143164610853537,
#  'скоро': 0.00017083482961283464,
#  'Во': 0.00017064281039247877,
#  'говорю': 0.00017059610301455437,
#  'тысяч': 0.00017022244399115914,
#  'туда': 0.00016999928651885367,
#  'пути': 0.00016969828341667416,
#  'м': 0.00016853059896856408,
#  'Поэтому': 0.00016845275333869007,
#  'стоял': 0.00016817250907114365,
#  'самый': 0.00016809466344126965,
#  'Иван': 0.00016801162810273738,
#  'домой': 0.00016773138383519096,
#  'город': 0.00016722279238668079,
#  'выше': 0.00016720722326070598,
#  'пошел': 0.0001667193906468289,
#  'видно': 0.00016595131376540535,
#  'головой': 0.00016575929454504948,
#  'ну': 0.00016569701804115028,
#  'многие': 0.00016519361630129838,
#  'виде': 0.0001650950118367913,
#  'часов': 0.00016449300563243233,
#  'правда': 0.00016433731437268432,
#  'второй': 0.0001639013788453899,
#  'понял': 0.00016307621516872543,
#  'хочу': 0.00016226143090937749,
#  'раньше': 0.00016204346314573027,
#  'вовсе': 0.00016100552141407688,
#  'одном': 0.00016075122568982178,
#  'рублей': 0.00015971847366682665,
#  'страны': 0.00015940709114733062,
#  'Почему': 0.0001592513998875826,
#  'далеко': 0.00015924102047026607,
#  'начала': 0.0001592358307616078,
#  'письмо': 0.00015877394669102204,
#  'д': 0.00015791764476240797,
#  'могла': 0.00015722222380220018,
#  'легко': 0.00015662540730649948,
#  'четыре': 0.0001556912597480114,
#  'мысль': 0.00015560303470082086,
#  'одним': 0.00015540582577180674,
#  'думаю': 0.00015535392868522405,
#  'увидел': 0.0001548920446146383,
#  'час': 0.0001547000253942824,
#  'сделал': 0.00015424852074101317,
#  'тихо': 0.0001541966236544305,
#  'возможность': 0.0001540720706466321,
#  'минуту': 0.00015391637938688409,
#  'сюда': 0.00015307045687558657,
#  'поэтому': 0.0001525411065924433,
#  'ту': 0.00015253591688378504,
#  'имя': 0.00015245807125391104,
#  'внимание': 0.0001524321227106197,
#  'руками': 0.00015227643145087168,
#  'вперед': 0.00015214149902575676,
#  'многих': 0.00015172113262443713,
#  'народ': 0.00015146683690018202,
#  'едва': 0.0001513941809789663,
#  'столь': 0.00015130595593177576,
#  'сих': 0.00015087002040448132,
#  'отца': 0.00015079217477460732,
#  'сил': 0.0001506364835148593,
#  'любви': 0.0001504340848771869,
#  'деятельности': 0.00015008118468842473,
#  'своему': 0.00014996701109794286,
#  '12': 0.000149852837507461,
#  'какие': 0.00014978018158624525,
#  'знать': 0.00014974385362563739,
#  'Сейчас': 0.0001497230947910043,
#  'свет': 0.00014947398877540748,
#  'вышел': 0.000149250831303102,
#  'доме': 0.00014910032975201225,
#  '15': 0.00014818694102815727,
#  'руках': 0.0001477717643354959,
#  'новые': 0.00014744481269002508,
#  'право': 0.00014739291560344242,
#  'сильно': 0.0001470815330839464,
#  'иметь': 0.00014702444628870545,
#  'взял': 0.00014697773891078104,
#  'Надо': 0.00014695698007614799,
#  'момент': 0.0001467805299817669,
#  'земли': 0.0001465418033834866,
#  'достаточно': 0.0001462148517380158,
#  'трудно': 0.00014577891621072136,
#  'столько': 0.00014556094844707414,
#  'та': 0.00014510425408514662,
#  'рукой': 0.0001449329936994238,
#  'денег': 0.0001449226142821073,
#  'развития': 0.00014491223486479075,
#  'женщина': 0.00014486552748686635,
#  'вместо': 0.00014393137992837828,
#  'мире': 0.00014357329003095786,
#  'глаз': 0.0001434746855664508,
#  'другого': 0.00014272217781100205,
#  'путь': 0.0001423381393702903,
#  'меньше': 0.0001421305510239596,
#  'числе': 0.0001415025962763093,
#  'говорили': 0.00014097843570182433,
#  'самых': 0.00014094729744987473,
#  'системы': 0.00014070857085159445,
#  'подумал': 0.000140641104639037,
#  'течение': 0.00014024149707235042,
#  'иначе': 0.000140116944064552,
#  'ясно': 0.00013971733649786544,
#  'б': 0.00013958240407275049,
#  'конца': 0.00013918279650606394,
#  'идти': 0.00013896482874241673,
#  'видеть': 0.00013892331107315058,
#  'Александр': 0.00013858079030170496,
#  'дни': 0.0001385704108843884,
#  'либо': 0.00013776081633369875,
#  'другое': 0.0001373923470189618,
#  'хотелось': 0.00013713286158604845,
#  'пришел': 0.00013700311886959178,
#  'Через': 0.0001369512217830091,
#  'Впрочем': 0.00013642187149986586,
#  'бывает': 0.00013608973014573678,
#  'трех': 0.0001358198652955069,
#  'армии': 0.0001356901225790502,
#  'её': 0.00013526456646907232,
#  'роль': 0.00013520747967383137,
#  'минут': 0.0001351244443352991,
#  'землю': 0.00013502583987079204,
#  'хочет': 0.00013499470161884244,
#  'сидел': 0.00013497394278420935,
#  'понять': 0.000134558766091548,
#  'известно': 0.00013421624532010238,
#  'всеми': 0.00013417472765083624,
#  'права': 0.0001341643482335197,
#  'Или': 0.00013368689503695915,
#  'разных': 0.00013359348028111034,
#  'До': 0.00013351563465123633,
#  'имел': 0.00013330804630490563,
#  'дать': 0.00013324058009234817,
#  'новых': 0.00013311083737589148,
#  'зачем': 0.00013284616223431986,
#  'Этот': 0.00013275274747847105,
#  'моих': 0.00013259186651006478,
#  'взгляд': 0.00013247769291958292,
#  'десять': 0.00013247769291958292,
#  '9': 0.00013238946787239237,
#  'народа': 0.000132129982439479,
#  'самым': 0.0001320988441875294,
#  'любовь': 0.00013202618826631368,
#  'вроде': 0.00013170442632950112,
#  'получил': 0.00013121140400696574,
#  'вами': 0.00013112317895977522,
#  '30': 0.00013100900536929333,
#  'новый': 0.00013099343624331853,
#  'общества': 0.00013091040090478626,
#  'вид': 0.00013090002148746972,
#  'необходимо': 0.0001307754684796713,
#  'пришлось': 0.00013059382867663198,
#  'Бог': 0.00013047446537749183,
#  'души': 0.00013039143003895957,
#  'другим': 0.00013008004751946354,
#  'некоторые': 0.00012982056208655018,
#  'земле': 0.00012887084540208732,
#  'П': 0.00012866325705575664,
#  'заметил': 0.00012865806734709836,
#  'другом': 0.00012778100658385124,
#  'Даже': 0.00012700255028511118,
#  'писал': 0.00012678977223012222,
#  'будем': 0.00012674306485219782,
#  'самые': 0.00012618776602576324,
#  'голосом': 0.00012613067923052232,
#  'силу': 0.0001258660040889507,
#  'слов': 0.0001257829687504184,
#  'Есть': 0.0001257518304984688,
#  'возможности': 0.0001257518304984688,
#  'первой': 0.00012565322603396174,
#  'нового': 0.00012544563768763107,
#  'Кроме': 0.00012537817147507358,
#  'степени': 0.00012509792720752716,
#  'й': 0.0001249370462391209,
#  'часа': 0.0001249370462391209,
#  'отвечал': 0.00012492666682180435,
#  'знаете': 0.00012469312993218233,
#  'пусть': 0.00012468275051486581,
#  'положение': 0.00012467756080620753,
#  'глазах': 0.00012452186954645952,
#  'мою': 0.00012411188256245643,
#  'говоря': 0.00012403403693258242,
#  'века': 0.00012398732955465802,
#  'жена': 0.00012388872509015096,
#  'скорее': 0.00012368113674382026,
#  'речь': 0.00012342684101956518,
#  'работать': 0.00012342165131090692,
#  'кто-то': 0.00012333861597237463,
#  'первого': 0.0001231725452953101,
#  'Ах': 0.0001223681404532787,
#  'невозможно': 0.0001223370022013291,
#  'Где': 0.00012210865502036534,
#  'книги': 0.00012205675793378268,
#  'удалось': 0.00012202561968183308,
#  'двери': 0.00012187511813074333,
#  'никак': 0.00012182841075281892,
#  'Москву': 0.00012180765191818586,
#  'наша': 0.00012171942687099532,
#  'дал': 0.0001214703208553985,
#  'стол': 0.00012113817950126942,
#  'главное': 0.00012107071328871194,
#  'партии': 0.00012102400591078754,
#  'работе': 0.00012101362649347101,
#  'ответ': 0.00012065553659605058,
#  'последние': 0.00012058288067483483,
#  '11': 0.00012039605116313722,
#  'дети': 0.00012025592902936401,
#  'решил': 0.0001200846686436412,
#  'Андрей': 0.0001200379612657168,
#  'Ему': 0.00011995492592718453,
#  'Николай': 0.00011991859796657666,
#  'ещё': 0.00011969025078561291,
#  'лицом': 0.00011969025078561291,
#  'смысле': 0.00011955531836049796,
#  'наиболее': 0.00011949823156525703,
#  'смотрел': 0.00011929064321892634,
#  'двадцать': 0.00011879762089639098,
#  'Петр': 0.00011878724147907443,
#  'молодой': 0.00011863155021932642,
#  'мною': 0.00011855370458945242,
#  'собою': 0.00011854851488079416,
#  'возможно': 0.00011841358245567921,
#  'матери': 0.00011840320303836268,
#  'шел': 0.00011837206478641308,
#  'сначала': 0.00011831497799117214,
#  'думать': 0.00011788423217253597,
#  'Правда': 0.00011757284965303995,
#  'продолжал': 0.00011753652169243209,
#  'Очень': 0.00011748462460584941,
#  'Вам': 0.00011744829664524154,
#  'отношения': 0.00011734969218073447,
#  'завтра': 0.00011733931276341793,
#  'Москвы': 0.000117282225968177,
#  'мимо': 0.00011722513917293606,
#  'женщины': 0.00011717843179501166,
#  'Ничего': 0.00011707982733050458,
#  'качестве': 0.00011696046403136445,
#  'сын': 0.0001169189463620983,
#  'каждого': 0.00011662313296857708,
#  'городе': 0.00011650895937809521,
#  'Наконец': 0.00011645706229151254,
#  'гораздо': 0.000116368837244322,
#  'спросила': 0.0001163221298663976,
#  'знаешь': 0.0001162754224884732,
#  'которому': 0.00011606783414214251,
#  'что-нибудь': 0.0001159432811343441,
#  'комнате': 0.00011593809142568583,
#  'условиях': 0.00011587062521312837,
#  'новой': 0.00011583429725252049,
#  'значение': 0.00011563189861484808,
#  'разве': 0.00011552291473302447,
#  'рода': 0.00011537241318193472,
#  'несмотря': 0.0001152167219221867,
#  'медленно': 0.00011447459358405452,
#  'разговор': 0.00011426700523772384,
#  'виду': 0.00011424624640309078,
#  'найти': 0.00011423067727711598,
#  'последний': 0.0001142099184424829,
#  'стране': 0.00011406460660005142,
#  'наше': 0.00011385701825372075,
#  'сквозь': 0.00011377398291518847,
#  'плохо': 0.00011363386078141526,
#  'вновь': 0.00011355082544288299,
#  'комнату': 0.00011330690913594444,
#  'Иванович': 0.00011329652971862791,
#  'свете': 0.0001131408384588799,
#  'Сергей': 0.00011269452351426892,
#  'СССР': 0.00011246617633330518,
#  'русской': 0.0001123520027428233,
#  'Один': 0.00011221188060905009,
#  'улице': 0.00011209770701856821,
#  'отношении': 0.00011207694818393515,
#  'никаких': 0.00011157354644408324,
#  'раза': 0.00011154240819213364,
#  'Эти': 0.00011153721848347537,
#  'никакого': 0.00011152683906615884,
#  'ночи': 0.00011127773305056202,
#  'Российской': 0.0001112673536332455,
#  'очередь': 0.00011123102567263762,
#  'вещи': 0.00011121545654666282,
#  'всему': 0.00011113761091678881,
#  'спокойно': 0.00011103900645228173,
#  'взять': 0.00011103381674362348,
#  'вопросы': 0.00011100786820033213,
#  'работа': 0.00011096116082240773,
#  'человеком': 0.00011096116082240773,
#  'дороге': 0.0001109507814050912,
#  'какая': 0.00011089888431850852,
#  'Хотя': 0.00011089369460985027,
#  'утра': 0.00011068091655486131,
#  'зрения': 0.00011007372064184407,
#  'чувство': 0.0001096585439491827,
#  'брат': 0.00010937829968163629,
#  'Федерации': 0.00010919665987859694,
#  'Сегодня': 0.00010914476279201427,
#  'помню': 0.00010885932881580958,
#  'действия': 0.00010870363755606157,
#  'становится': 0.00010845453154046475,
#  'таком': 0.00010824694319413406,
#  'тобой': 0.0001082417534854758,
#  'имени': 0.00010823137406815926,
#  'постоянно': 0.00010806530339109472,
#  'х': 0.00010798745776122072,
#  'такую': 0.00010785252533610578,
#  'власть': 0.00010739583097417827,
#  'Россия': 0.00010739064126552,
#  'дает': 0.00010736988243088694,
#  'происходит': 0.00010732317505296254,
#  'ночью': 0.000107312795635646,
#  'государства': 0.00010714153524992318,
#  'Эта': 0.00010704293078541612,
#  'организации': 0.00010695470573822557,
#  'начале': 0.0001068561012737185,
#  'случай': 0.00010681458360445236,
#  'говорила': 0.00010645130399837368,
#  'разные': 0.00010591676400657217,
#  '14': 0.0001055794329437848,
#  'воду': 0.0001055482946918352,
#  'князь': 0.00010544450051866986,
#  'вижу': 0.00010530956809355492,
#  'Можно': 0.00010524210188099745,
#  'средств': 0.00010513311799917384,
#  'состоянии': 0.00010503970324332503,
#  'имеют': 0.0001049203399441849,
#  'ради': 0.00010476464868443688,
#  'море': 0.00010423529840129365,
#  'вечер': 0.00010408998655886216,
#  'ваше': 0.00010407441743288736,
#  'впервые': 0.00010382531141729054,
#  'счет': 0.00010366443044888426,
#  'Л': 0.00010355544656706065,
#  'человеку': 0.00010354506714974412,
#  'США': 0.00010339456559865438,
#  'дел': 0.00010312989045708277,
#  'тотчас': 0.00010306761395318356,
#  'откуда': 0.00010273547259905447,
#  'точки': 0.00010232548561505137,
#  'головы': 0.00010224763998517736,
#  'любил': 0.00010220093260725296,
#  'писать': 0.00010212308697737895,
#  'обычно': 0.00010207118989079628,
#  'стать': 0.00010171309999337585,
#  'Их': 0.0001013913380565633,
#  'кому': 0.00010115261145828301,
#  'Таким': 0.00010114223204096648,
#  'Чтобы': 0.00010097616136390194,
#  'русских': 0.00010089312602536966,
#  'характер': 0.00010085160835610353,
#  'вниз': 0.00010083084952147046,
#  'труда': 0.00010061288175782324,
#  'общем': 0.00010060769204916497,
#  'голове': 0.00010057655379721537,
#  'вероятно': 0.0001004001037028343,
#  'людям': 0.00010009391089199653,
#  'Ни': 0.00010004201380541387,
#  '13': 9.997973730151467e-05,
#  'оба': 9.989151225432412e-05,
#  'шли': 9.978252837250051e-05,
#  'Между': 9.962164740409424e-05,
#  'какие-то': 9.941924876642183e-05,
#  'лиц': 9.938292080581395e-05,
#  'поскольку': 9.934140313654782e-05,
#  'письма': 9.921166042009114e-05,
#  'группы': 9.911305595558406e-05,
#  '16': 9.909748682960926e-05,
#  'некоторых': 9.903521032571006e-05,
#  'компании': 9.884838081401244e-05,
#  'могло': 9.86044645070739e-05,
#  'окна': 9.857851596378255e-05,
#  'душе': 9.855256742049122e-05,
#  'наверное': 9.82411849009952e-05,
#  'Зачем': 9.823599519233693e-05,
#  '50': 9.816852897977947e-05,
#  'решение': 9.814258043648812e-05,
#  'жил': 9.798688917674011e-05,
#  'Уже': 9.796613034210705e-05,
#  'оказался': 9.78311979169921e-05,
#  'месяц': 9.782081849967557e-05,
#  'смотреть': 9.772740374382676e-05,
#  'сына': 9.767031694858583e-05,
#  'никого': 9.748867714554648e-05,
#  'движения': 9.731741675982366e-05,
#  'остается': 9.719286375202525e-05,
#  '18': 9.714615637410085e-05,
#  '25': 9.710463870483472e-05,
#  'понимаю': 9.708906957885992e-05,
#  'случилось': 9.706312103556859e-05,
#  'смерть': 9.704236220093551e-05,
#  'посмотрел': 9.701641365764418e-05,
#  'людьми': 9.691261948447883e-05,
#  'внимания': 9.69022400671623e-05,
#  'мама': 9.67776870593639e-05,
#  'тело': 9.677249735070562e-05,
#  'русского': 9.675692822473082e-05,
#  'хочется': 9.658047813034975e-05,
#  'другую': 9.625352648487893e-05,
#  'солнце': 9.619643968963798e-05,
#  'вечером': 9.608745580781437e-05,
#  'люблю': 9.606669697318132e-05,
#  'оказалось': 9.604074842988997e-05,
#  'Потому': 9.598366163464904e-05,
#  'стояли': 9.595252338269944e-05,
#  'Значит': 9.578645270563488e-05,
#  'дороги': 9.578645270563488e-05,
#  'получить': 9.578126299697662e-05,
#  'двумя': 9.570341736710262e-05,
#  'старик': 9.564114086320341e-05,
#  'глядя': 9.54543113515058e-05,
#  'Г': 9.544912164284753e-05,
#  'каким': 9.540241426492313e-05,
#  'утром': 9.536608630431525e-05,
#  'лице': 9.528305096578299e-05,
#  'страшно': 9.526229213114992e-05,
#  'управления': 9.516368766664284e-05,
#  'всякий': 9.51377391233515e-05,
#  'язык': 9.491977135970429e-05,
#  'период': 9.480559776922241e-05,
#  'живет': 9.477964922593108e-05,
#  'прав': 9.477964922593108e-05,
#  'берегу': 9.459281971423347e-05,
#  'помощью': 9.444750787180199e-05,
#  'недавно': 9.432295486400358e-05,
#  'делает': 9.418283273023037e-05,
#  'результате': 9.407903855706503e-05,
#  'Бога': 9.40686591397485e-05,
#  'какое': 9.40219517618241e-05,
#  'душу': 9.395967525792489e-05,
#  'Хорошо': 9.378841487220208e-05,
#  'Меня': 9.364829273842887e-05,
#  'первых': 9.333172051027458e-05,
#  'которыми': 9.332134109295805e-05,
#  'впрочем': 9.325387488040057e-05,
#  'вчера': 9.290097469163842e-05,
#  'крайней': 9.275566284920693e-05,
#  'находится': 9.275566284920693e-05,
#  'всякого': 9.249617741629357e-05,
#  'причем': 9.247022887300224e-05,
#  'п': 9.233010673922903e-05,
#  'церкви': 9.225226110935503e-05,
#  'словом': 9.198239625912514e-05,
#  'поле': 9.182670499937713e-05,
#  'где-то': 9.172810053487006e-05,
#  'словами': 9.169696228292046e-05,
#  'возле': 9.140114888939924e-05,
#  'почему-то': 9.13907694720827e-05,
#  'хуже': 9.133887238550003e-05,
#  'помощи': 9.130254442489216e-05,
#  '17': 9.127140617294256e-05,
#  'машины': 9.116242229111895e-05,
#  'узнал': 9.115204287380242e-05,
#  'производства': 9.114685316514415e-05,
#  'случаях': 9.104305899197881e-05,
#  'N': 9.103267957466227e-05,
#  'Тем': 9.089255744088906e-05,
#  'солдат': 9.087698831491426e-05,
#  'знали': 9.083547064564813e-05,
#  'однажды': 9.081990151967332e-05,
#  'самому': 9.076281472443239e-05,
#  'большие': 9.064345142529224e-05,
#  'чему': 9.04618116222529e-05,
#  'решения': 9.044105278761983e-05,
#  'конец': 9.04151042443285e-05,
#  'последнее': 9.028017181921356e-05,
#  'остался': 8.981828774862778e-05,
#  'РФ': 8.959513027632231e-05,
#  'Затем': 8.953285377242309e-05,
#  'количество': 8.945500814254908e-05,
#  'поводу': 8.907096970183733e-05,
#  'порядке': 8.881667397758224e-05,
#  'тела': 8.871806951307517e-05,
#  'ими': 8.864022388320117e-05,
#  'принять': 8.857275767064369e-05,
#  'Владимир': 8.8365169324313e-05,
#  'молча': 8.826137515114767e-05,
#  'дорогу': 8.81939089385902e-05,
#  'пошли': 8.815758097798233e-05,
#  'Пока': 8.810049418274139e-05,
#  'придется': 8.801226913555085e-05,
#  'приехал': 8.800188971823432e-05,
#  'рук': 8.799151030091778e-05,
#  'Ее': 8.786176758446111e-05,
#  'ряд': 8.782543962385324e-05,
#  'первые': 8.780987049787844e-05,
#  'сел': 8.777873224592883e-05,
#  'станет': 8.76593689467887e-05,
#  'число': 8.76126615688643e-05,
#  'Разве': 8.760228215154775e-05,
#  'сего': 8.740507322253361e-05,
#  'нашел': 8.730127904936827e-05,
#  'нашем': 8.7218243710836e-05,
#  'стояла': 8.719229516754466e-05,
#  'культуры': 8.701065536450531e-05,
#  'неожиданно': 8.69172406086565e-05,
#  'успел': 8.691205089999824e-05,
#  'нечего': 8.681863614414944e-05,
#  'другими': 8.651763304196994e-05,
#  'большим': 8.645016682941247e-05,
#  'приходится': 8.624776819174005e-05,
#  'революции': 8.621144023113218e-05,
#  'ушел': 8.619068139649912e-05,
#  'касается': 8.599347246748496e-05,
#  'Москва': 8.58637297510283e-05,
#  'первую': 8.567171053067241e-05,
#  'различных': 8.561462373543148e-05,
#  'делу': 8.555234723153227e-05,
#  'подошел': 8.55004501449496e-05,
#  'Дело': 8.546412218434173e-05,
#  'Под': 8.539665597178426e-05,
#  'одновременно': 8.533956917654332e-05,
#  'воздух': 8.509565286960477e-05,
#  'осталось': 8.498666898778116e-05,
#  'видели': 8.473756297218434e-05,
#  'из-под': 8.471161442889301e-05,
#  'света': 8.471161442889301e-05,
#  'месяца': 8.464414821633554e-05,
#  'хочешь': 8.448845695658753e-05,
#  'написал': 8.439504220073872e-05,
#  'комнаты': 8.437947307476392e-05,
#  'слышал': 8.433795540549779e-05,
#  'небо': 8.421340239769938e-05,
#  'нечто': 8.420302298038284e-05,
#  'чаще': 8.41615053111167e-05,
#  'движение': 8.40836596812427e-05,
#  'любит': 8.40213831773435e-05,
#  'одному': 8.398505521673562e-05,
#  'шесть': 8.396948609076082e-05,
#  'немедленно': 8.393834783881122e-05,
#  'средства': 8.36581035712648e-05,
#  'большая': 8.354392998078293e-05,
#  'памяти': 8.345570493359238e-05,
#  'существует': 8.338823872103492e-05,
#  'Пусть': 8.322735775262864e-05,
#  'русский': 8.315989154007116e-05,
#  'состояние': 8.31391327054381e-05,
#  'видимо': 8.311318416214676e-05,
#  'нашу': 8.308204591019715e-05,
#  'путем': 8.297825173703182e-05,
#  'история': 8.292116494179087e-05,
#  'ума': 8.288483698118301e-05,
#  'пожалуй': 8.26824383435106e-05,
#  'новое': 8.265648980021925e-05,
#  'форме': 8.259421329632005e-05,
#  'читал': 8.259421329632005e-05,
#  'Д': 8.258902358766179e-05,
#  'населения': 8.255788533571219e-05,
#  'смысл': 8.254231620973739e-05,
#  ...}

# %%
data = pd.read_csv("laba1.csv", header=[0, 1], index_col=0, encoding='utf-8')
data
# Out:
#                                              политика  \
#                                                 Title
# 0      Путин отверг возможность возврата к социализму
# 1   Путин пообещал поддерживать оппозиционных губе...
# 2   Главное — не "квасной". Путин назвал патриотиз...
# 3   Путин анонсировал переговоры с Пашиняном на сл...
# 4   Путин ответил на вопрос, хочет ли он править м...
# 5             Обновление пользовательского соглашения
# 6   Не как обычно. Политтехнолог перечислил главны...
# 7   От НДС и Сирии до Бутиной и рэпа. Эксперты оце...
# 8   Прорыв неизбежен. Политолог расшифровал сигнал...
# 9   "Президент — прагматик". Песков заявил, что Пу...
# 10  Песков заявил, что хаотичность действий США вы...
# 11  Хакеры вместо боеголовок. Пентагон изучит кибе...
# 12  Уж точно не "прагматичный сухарь". Кириенко оз...
# 13  Кириенко: Сопереживание — важная вещь для упра...
# 14  Лукашенко указал на важность всесторонних отно...
# 15  Лукашенко переживает, что Россия перестала счи...
# 16  Лукашенко предложил Путину "не тащить" текущие...
# 17  Путин поднимет энергетические вопросы на встре...
# 18  В Совфеде предложили заносить лживых иностранн...
# 19  Володин на встрече с Путиным предложил оценить...
# 20  Вице-губернаторы Петербурга Игорь Албин и Миха...
# 21  Песков объяснил необходимость ещё одной встреч...
# 22            Обновление пользовательского соглашения
# 23  Путин встретится с вновь избранными губернатор...
# 24  Порошенко анонсировал новые санкции против России
# 25  "Надо будет — договорюсь". Зеленский обещает о...
# 26  Кожемяко подготовит доклад для Путина о пробле...
# 27  Песков: Путин и Лукашенко продолжат обсуждение...
# 28  Рабочая суббота. В Кремле началась встреча Пут...
# 29  Путин и Лукашенко поздравили с наступающим Нов...
# 30  Ответные меры. Россия запретила импорт ряда ук...
# 31  Песков о сотрудничестве Москвы и Минска: Не пр...
# 32  Песков: Интеграция Москвы и Минска не должна т...
# 33  Абэ надеется "предметно" обсудить с Путиным ми...
# 34  В Интернет попали личные данные сотен немецких...
# 35           Президент Турции посетит Россию в январе
# 36  Пригласил на ВЭФ как главного гостя. Путин про...
# 37  "Вялая деградация". Пушков рассказал, что ждёт...
# 38  Суд Киева признал вмешательство украинских пол...
# 39  Зеленский попросил украинцев написать ему пред...
# 40  Глава МИД Ирана: Европа укрывает у себя террор...
# 41  Бразилия вышла из Глобального договора о миграции
# 42  Япония выразила надежду на поддержку США в воп...
# 43  Песков отреагировал на данные СМИ о "вмешатель...
# 44  НАТО заявило о готовности к диалогу с Москвой ...
# 45  Украинский министр назвал Крымский мост бутафо...
# 46  Эксперт считает, что США потеряли статус ведущ...
# 47  Эксперт рассказал, чем опасно избрание Зеленск...
# 48  Надо ценить. Медведев напомнил Минску о кредит...
# 49  Медведев высказался о компенсациях за налоговы...
#
#                                                        \
#                                                  Text
# 0   Глава государства при этом допустил, что возмо...
# 1   Все избранные главы регионов, даже представите...
# 2   Патриотизм должен выступать в роли основы для ...
# 3   Президент РФ Владимир Путин на следующей недел...
# 4   Президент России Владимир Путин в ходе большой...
# 5   Российский лидер Владимир Путин назвал два сам...
# 6   Мероприятие длилось 3 часа 44 минуты. За это в...
# 7   Российский лидер был полностью открыт для пред...
# 8   Российский лидер во время общения с журналиста...
# 9   Пресс-секретарь президента РФ Дмитрий Песков р...
# 10  Россия ищет в азимутах внешней политики стабил...
# 11  В усложняющейся геополитической обстановке на ...
# 12  В списке оказались знание истории и литературы...
# 13  Аналогичной точки зрения придерживается и през...
# 14  Президент Белоруссии Александр Лукашенко на со...
# 15  25 декабря Путин и Лукашенко проведут перегово...
# 16  На встрече в Кремле стороны рассчитывают обсуд...
# 17  Открывая переговоры со своим белорусским колле...
# 18  Перечень мог бы получить имя деятеля, впервые ...
# 19  В Госдуме считают, что было бы полезно вместе ...
# 20  Врио губернатора Санкт-Петербурга Александр Бе...
# 21  Пресс-секретарь президента РФ Дмитрий Песков о...
# 22  ×\n\nОбновление пользовательского соглашения\n...
# 23  Среди участников встречи ожидаются главы Хакас...
# 24  ×\n\nОбновление пользовательского соглашения\n...
# 25  Шоумен, за которого готовы проголосовать 14,6%...
# 26  Губернатор Приморского края Олег Кожемяко заяв...
# 27  Предыдущий раунд переговоров в Кремле состоялс...
# 28  Предыдущий раунд переговоров состоялся 25 дека...
# 29  Российский лидер пожелал всем жителям Белорусс...
# 30  Россия ввела запрет на ввоз ряда товаров из Ук...
# 31  В Кремле считают, что расширение сотрудничеств...
# 32  В Кремле напомнили, что интеграционные процесс...
# 33  ×\n\nОбновление пользовательского соглашения\n...
# 34  В настоящий момент расследованием занимается Ф...
# 35  Путин и Эрдоган обсудят ситуацию в Сирии и кон...
# 36  Политики тепло поздравили друг друга с наступи...
# 37  Сенатор Алексей Пушков уверен, что в этом году...
# 38  Как пояснил Виктор Медведчук, этот факт может ...
# 39  Шоумен призывает жителей Незалежной указать пя...
# 40  Ранее Евросоюз ввёл санкции против иранских сп...
# 41  На днях вступивший в должность новый президент...
# 42  В Токио заявили, что таким образом Вашингтон п...
# 43  Пресс-секретарь президента РФ Дмитрий Песков п...
# 44  Хотя ранее генсек альянса пригрозил российской...
# 45  Истерика на Украине в связи с запуском в экспл...
# 46  Бывший постпред США при НАТО Иво Даалдер заяви...
# 47  По мнению политолога, президентство шоумена об...
# 48  По словам премьера, мы по сути помогаем Белору...
# 49  Белоруссия оценивает потери за этот год пример...
#
#                                                  кино  \
#                                                 Title
# 0   Маколей Калкин рассказал, что думает об играх ...
# 1   В Сети появился трейлер новых "Людей в чёрном"...
# 2   Звезда "Аквамена" Джейсон Момоа вышел в свет с...
# 3      Экранизация Uncharted вновь лишилась режиссёра
# 4             Обновление пользовательского соглашения
# 5      Джеймса Бонда предложили сделать трансгендером
# 6   Комедия "Полицейский с Рублёвки" стала лидером...
# 7             Обновление пользовательского соглашения
# 8   "Щелкунчик и четыре королевства" назван одним ...
# 9   Фильм "Аквамен" стал лидером американского про...
# 10  Netflix снимет сериал о помощниках Шерлока Холмса
# 11  Актриса Галина Тихонова скоропостижно умерла в...
# 12            Россияне назвали лучший фильм 2018 года
# 13  Кевин Спейси вернулся. Актёр записал обращение...
# 14  Актёр из "Чудо-женщины" спел рождественскую пе...
# 15  Съёмки продолжения "Чудо-женщины" завершены — ...
# 16  Назван график фильмов Disney, которые выйдут в...
# 17  Российское кино побило рекорды по кассовым сбо...
# 18  Дэвид Духовны заинтересовался группой "Ленинград"
# 19  Раскрыты подробности продолжения "Человека-паука"
# 20       Каким должен быть идеальный новогодний фильм
# 21  Как с "Алиэкспресс", только в порно. Девушки н...
# 22  Блогер сделал шлем Тора, от которого светятся ...
# 23        Названы номинанты кинопремии "Золотой орёл"
# 24  Эдгар Райт проспорил "Оскар" режиссёру "Аквамена"
# 25  Голливуд установил новый рекорд по кассовым сб...
# 26  Режиссёр "Джона Уика" всё ещё надеется снять р...
# 27  Гангстерская драма из фильма "Один дома" оказа...
# 28  Россияне в 2018 году предпочитали фильмы о вой...
# 29  В Польше обязали немецкий телеканал извиниться...
# 30  Книга жены — любимая. Обама рассказал, что смо...
# 31  Топ фильмов и сериалов 2018 года по версии "Ме...
# 32  Известный кинорежиссёр Марлен Хуциев госпитали...
# 33        Названы лучшие новые сериалы уходящего года
# 34  "Недалёк умом". Мягков ответил митрополиту Ряз...
# 35  Комедия "Полицейский с Рублёвки" снова возглав...
# 36  Стала известна дата выхода третьего сезона "Оч...
# 37  Фильмы Marvel доминируют в рейтинге самых ожид...
# 38  Режиссёр "Аквамена" попросил фанатов фильма не...
# 39       Умер актёр фильма "Лето" Владимир Дыховичный
# 40  Disney сэкономит почти 100 миллионов долларов ...
# 41  "Ходячие мертвецы" — самый скачиваемый среди "...
# 42  Скарлетт Йоханссон назвала Интернет кротовой н...
# 43  Рекордные 480 млн рублей составила выручка кин...
# 44  Создатель "Чёрного зеркала" назвал причину пер...
# 45            Обновление пользовательского соглашения
# 46  Стало известно, когда 5-й сезон "Чёрного зерка...
# 47  Авторы "Чёрного зеркала": Фанаты никогда не по...
# 48  Звезда "Гарри Поттера" не может смотреть фильм...
# 49  Российское кино побило рекорды по сборам и пос...
#
#                                                        \
#                                                  Text
# 0   В Сети появилось великолепное видео, которое п...
# 1   ×\n\nОбновление пользовательского соглашения\n...
# 2   Фанаты популярного актёра, который чаще всего ...
# 3   На этот раз от проекта отказался Шон Леви, кот...
# 4   Новый комикс по "Звёздным войнам" Darth Vader ...
# 5   ×\n\nОбновление пользовательского соглашения\n...
# 6   ×\n\nОбновление пользовательского соглашения\n...
# 7   Сценарий к новому фильму должны будут написать...
# 8   Кинокритики журнала The Hollywood Reporter выб...
# 9   В Северной Америке фантастический боевик вышел...
# 10  Беспризорники станут новыми главными героями с...
# 11  Актриса театра и кино Галина Тихонова умерла н...
# 12  Лучшей оказалась кинодрама под названием "Три ...
# 13  Это первое публичное высказывание звезды "Карт...
# 14  Крис Пайн, озвучивший в картине Питера Паркера...
# 15  Фильм, главную роль в котором сыграет актриса ...
# 16  Всего в настоящий момент студия планирует выпу...
# 17  Число зрителей в кинотеатрах страны в 2018 год...
# 18  Актёр, звезда сериалов "Секретные материалы" и...
# 19  Сюжет будущей киноленты должен будет достаточн...
# 20  ×\n\nОбновление пользовательского соглашения\n...
# 21  ×\n\nОбновление пользовательского соглашения\n...
# 22  Аксессуар был распечатан с помощью 3D-принтера...
# 23  Лидирующую позицию по количеству номинаций зан...
# 24  Спор между двумя авторами популярных американс...
# 25  Добиться удалось этого благодаря "Аквамену", п...
# 26  Чад Стахелски в очередной раз решил подтвердит...
# 27  Спустя много лет стало известно о том, что чёр...
# 28  ×\n\nОбновление пользовательского соглашения\n...
# 29  Перед каждой трансляцией сериала теперь должна...
# 30  В личный рейтинг экс-президента США вошло боле...
# 31  "Мегафон" проанализировал данные по количеству...
# 32  Прославленный кинорежиссёр и сценарист Марлен ...
# 33  Сайт-агрегатор Metacritic, специализирующийся ...
# 34  По мнению священнослужителя, фильм транслирует...
# 35  На втором месте оказалась кинолента "Ёлки Посл...
# 36  Компания Netflix поделилась тизером и постером...
# 37  Соответствующий список был составлен сайтом Fa...
# 38  Соответствующее заявление автор американской к...
# 39  Свои соболезнования выразили друзья и коллеги ...
# 40  Популярный американский актёр не появится на э...
# 41  Сериал про зомби вышел в лидер в связи с отсут...
# 42  Таким образом популярная американская актриса ...
# 43  По сравнению с результатом, который был продем...
# 44  Это произошло из-за того, что команда работала...
# 45  Он был одним из последних творцов золотого век...
# 46  По словам авторов шоу, "Бандерснэтч" можно счи...
# 47  По словам режиссёра специального эпизода, в нё...
# 48  Исполнитель роли Рона Уизли из популярной сери...
# 49  В прошлом году доля отечественных фильмов в ки...
#
#                                            технологии  \
#                                                 Title
# 0   ¯\_(ツ)_/¯ - В Windows 10 появятся смайлики из ...
# 1       Первый в мире веб-сайт запустили 28 лет назад
# 2   В 2019 году Steam перестанет работать на стары...
# 3   Появилось пятно. Пользователи iPad Pro 2017 го...
# 4   Смартфоны, одежда, фастфуд. Названы 20 любимых...
# 5             Обновление пользовательского соглашения
# 6   Facebook начал делить СМИ на "фейковые" и "неф...
# 7      Названо, какие iPad Apple выпустит в 2019 году
# 8   "Это нормально". В Apple прокомментировали сит...
# 9   Xiaomi представила "молодёжный" смартфон c гра...
# 10     Google не стала обжаловать штраф Роскомнадзора
# 11  Матвиенко объяснила необходимость закона о сув...
# 12  Samsung Galaxy Note 10 получит увеличенный дис...
# 13  Хакеры выводят из строя компьютеры на Windows ...
# 14  "Яндекс" выяснил, что покупают россияне к Ново...
# 15  "Одноклассники" назвали главные события 2018 года
# 16   Fortnite стала самой обсуждаемой игрой в Twitter
# 17            Цена PlayStation 4 Pro рухнула в России
# 18  Названы причины выпуска в декабре большинства ...
# 19  В 2018 году "ВКонтакте" выплатила 2 млрд рубле...
# 20  Названы самые высокооплачиваемые российские Yo...
# 21  "Мстители без конечностей". Названы самые смеш...
# 22       "Яндекс" удалил Telegram из поисковой выдачи
# 23  Эксперты: Россияне заинтересованы в iPhone, но...
# 24  IKEA выпустила инструкцию по "сборке" салата о...
# 25  Смартфоны, планшеты, умные часы. Названы лучши...
# 26          Москвичи стали чаще заказывать еду на дом
# 27  Снег, замри. 10 советов, как сделать снежный ф...
# 28  Названы самые популярные среди интернет-пирато...
# 29  "ВКонтакте" и Иван Ургант переформатируют "Кле...
# 30  Запрет iPhone, утечка данных. Главные скандалы...
# 31  Путин, "Мстители", Элджей. Названы главные тем...
# 32         Nokia 9 с пятью камерами появился на видео
# 33  Huawei представила бюджетный смартфон без скан...
# 34  Неймар променял празднование нового года на иг...
# 35  WhatsApp перестанет работать на некоторых теле...
# 36  Цукерберг продал акции Facebook, чтобы лечить ...
# 37            Обновление пользовательского соглашения
# 38  Apple предупредила инвесторов о замедлении тем...
# 39  Steam больше не поддерживает старые версии Win...
# 40  Роналду стал рекордсменом по числу подписчиков...
# 41  Смартфоны Redmi компании Xiaomi станут отдельн...
# 42  И они туда же. Первый складной Xiaomi появился...
# 43  Учёные нашли способ превращать новогодние ёлки...
# 44  Есть подтверждения: Apple уже занимается разра...
# 45  Tesla готовится начать продажи электромобиля M...
# 46  Акции Apple упали из-за провально низких прода...
# 47  Qualcomm заплатила 1,3 млрд евро за запрет про...
# 48  "Просто настали новые времена". Аналитики назв...
# 49  Touch ID в экране, USB-C. Аналитик назвал ново...
#
#                                                        \
#                                                  Text
# 0   Сейчас их ищут в Интернете и копируют, в следу...
# 1   Это сделал Тим Бернерс-Ли, британский учёный и...
# 2   Разработчики сервиса цифровой дистрибуции заяв...
# 3   Похоже, проблема заключается в подсветке. Одна...
# 4   Лидером восьмой год подряд остаётся Samsung, в...
# 5   По мнению экспертов, рост цен на связь неизбеж...
# 6   Соцсеть составляет досье на СМИ, которые цитир...
# 7   Авторитетный ресурс узнал, что в Купертино гот...
# 8   Вице-президент Apple по аппаратному обеспечени...
# 9   Бюджетная модель удивит оригинальными цветами ...
# 10  Компания отказалась комментировать, будет ли о...
# 11  В то же время она высказалась за широкую общес...
# 12  Авторитетный инсайдер поделился информацией о ...
# 13  Злоумышленники создали вредоносную ссылку, кот...
# 14  В топе приобретений через интернет-магазины — ...
# 15  Пользователи соцсети обсуждали кемеровскую тра...
# 16  Эта многопользовательская игра стала невероятн...
# 17  Популярная игровая консоль японского производи...
# 18  В 2017 году магазин App Store продал перед Нов...
# 19  В уходящем году пользователи самой популярной ...
# 20  Исследователи определили, какой доход с продаж...
# 21  Видимо, в 2018 году пользователи были обеспоко...
# 22  По имеющимся данным, сайт не отображается в по...
# 23  Смартфоны китайского бренда Xiaomi покупали в ...
# 24  Компания поиронизировала над собой, выпустив и...
# 25  Смартфон — по-прежнему лучший подарок. Также в...
# 26  Число заказов еды на дом среди столичных абоне...
# 27  Для кого-то зима — это холод и уныние, для дру...
# 28  "Собибор", "За гранью реальности" и "Гоголь. В...
# 29  Основным режимом игры станет бой, а не виктори...
# 30  Замедление iPhone\n\nВ декабре 2017 года Apple...
# 31  ×\n\nОбновление пользовательского соглашения\n...
# 32  Новый смартфон HMD Global удивит количеством м...
# 33  Устройство за 170 долларов узнает владельца в ...
# 34  Популярный бразильский футболист в настоящий м...
# 35  Сейчас пользователи гаджетов на устаревших опе...
# 36  Фонд создателя самой популярной социальной сет...
# 37  ×\n\nОбновление пользовательского соглашения\n...
# 38  Руководитель американской корпорации связывает...
# 39  Помимо операционных систем Windows XP и Window...
# 40  До этого популярный футболист заявлял о том, ч...
# 41  Под брендом Mi выходить будут гаджеты премиум-...
# 42  Кажется, популярный китайский бренд тоже готов...
# 43  Исследователи выяснили, что из срубленных на п...
# 44  Журналисты обнаружили посещения своего сайта с...
# 45  По полученной информации, сейчас производитель...
# 46  Компания ожидает прибыль ниже ожидаемого и соо...
# 47  Ранее чипмейкер выиграл у компании из Купертин...
# 48  Эксперты усомнились, что снижение спроса на iP...
# 49  По мнению эксперта, следующий смартфон Apple у...
#
#                                              культура  \
#                                                 Title
# 0   "Все умрут!" Робб Старк из "Игры престолов" пр...
# 1   Эксперты оценили условия возврата Германии цен...
# 2             Обновление пользовательского соглашения
# 3   Умер один из режиссёров программы "Спокойной н...
# 4   Мария Шарапова снялась в клипе на песню Spice ...
# 5    Певица Рианна рассказала фанатам о новом альбоме
# 6   В Минкультуры подвели итоги конкурса "Мой люби...
# 7   Посвящённый Году театра портал заработает в по...
# 8   И это не Козловский. Россияне выбрали лучшего ...
# 9   Боярскому — 69. Главный мушкетёр страны поведа...
# 10  "Чисто русская сказка". Последний фильм Михаил...
# 11  Лидер чартов. "Величайший шоумен" побил рекорд...
# 12          Назван главный российский фильм 2018 года
# 13  Стал известен победитель седьмого сезона шоу "...
# 14  Путин поздравил хореографа Юрия Григоровича с ...
# 15  Паустовский входил в число основных кандидатов...
# 16  Гитарист Queen посвятил новую песню космическо...
# 17     Юрий Лоза резко раскритиковал "Голубой огонёк"
# 18  "Всем хватит". Стало известно о завещании Крис...
# 19       Российский фильм "Праздник" вышел на YouTube
# 20  Назван самый популярный фильм 2018 года среди ...
# 21  Стала известна дата выхода фильма "Жил-был Дэд...
# 22  "Угроз нет". Жена Николая Дроздова рассказала ...
# 23           Зрители Netflix устроили опасный флешмоб
# 24  Фильм "Т-34" уже посмотрели полтора миллиона ч...
# 25  Объявлено начало работы над перезапуском "Джея...
# 26  Прощание с Иваном Бортником состоится в Театре...
# 27  Супруга режиссёра Марлена Хуциева умерла в реа...
# 28  Назван лучший фильм года по версии Национально...
# 29     Названы победители кинопремии "Золотой глобус"
# 30  Умер британский актёр Уильям Морган Шеппард, и...
# 31  Опубликованы первые кадры финального сезона "И...
# 32          Sony Pictures снимет продолжение "Венома"
# 33  Спродюсировал "Ку! Кин-дза-дза". Умер режиссёр...
# 34  Путин потребовал назвать точные сроки создания...
# 35  Путин призвал избегать шаблонов при создании к...
# 36  Уилл Смит объявил о начале съёмок третьих "Пло...
# 37  Марго Робби получила главную роль в фильме "Ба...
# 38  Режиссёр "Дэдпула" снимет мультфильм про робот...
# 39        Опубликован новый трейлер "Капитана Марвел"
# 40  Руководитель студии Marvel похвалил режиссёра ...
# 41  Опубликована посмертная песня Честера Беннингт...
# 42  Назван актёрский состав приквела "Игры престолов"
# 43  "18 мне уже". Солист "Руки вверх!" предложил в...
# 44  Российские фильмы заработали за новогодние пра...
# 45  "Закрою тему навсегда". Лукьяненко сообщил о з...
# 46  "А судьи кто?" Гурцкая раскритиковала предложе...
# 47  "Прекрати жить во грехе!" Депутат ответил на п...
# 48         Объявлен список номинантов на премию BAFTA
# 49  Российский фильм вошёл в главный конкурс Ротте...
#
#
#                                                  Text
# 0   Ричард Мэдден признался, что рад гибели своего...
# 1   Собеседники Лайфа считают, что Берлину для нач...
# 2   ×\n\nОбновление пользовательского соглашения\n...
# 3   Прощание с актёром пройдёт в понедельник, 24 д...
# 4   Популярная российская теннисистка отметила, чт...
# 5   По словам певицы, его звучание будет похожим н...
# 6   ×\n\nОбновление пользовательского соглашения\n...
# 7   По словам замглавы Минкультуры Павла Степанова...
# 8   Граждане страны также выбрали музыканта года, ...
# 9   Народный артист России Михаил Боярский отмечае...
# 10  Сатирик написал сценарий картины, впервые выст...
# 11  Саундтрек к мюзиклу "Величайший шоумен" побил ...
# 12  В списке успешных картин — "Лёд", "Тренер", а ...
# 13  ×\n\nОбновление пользовательского соглашения\n...
# 14  ×\n\nОбновление пользовательского соглашения\n...
# 15  Опубликованные Шведской академией архивные док...
# 16  Популярный музыкант опубликовал композицию в т...
# 17  Популярный артист считает, что в российском шо...
# 18  Певец умер 1 января в Подмосковье, он нескольк...
# 19  В основе новой отечественной киноленты — празд...
# 20  Рейтинг кинокартин, которые больше всего интер...
# 21  При этом в российском прокате кинолента в обно...
# 22  Жена известного российского телеведущего Никол...
# 23  Создатели кинокартины "Птичий короб" при этом ...
# 24  В настоящий момент кассовые сборы новой отечес...
# 25  В настоящий момент творческая команда будущей ...
# 26  Исполнителя роли Промокашки в культовой картин...
# 27  Сам 93-летний народный артист СССР остаётся в ...
# 28  ×\n\nОбновление пользовательского соглашения\n...
# 29  В Голливуде в 76-й раз прошла церемония вручен...
# 30  Чаще всего британца можно было встретить в тел...
# 31  Заключительный, восьмой сезон популярного теле...
# 32  Компания Sony Pictures Entertainment снимет пр...
# 33  Прощание состоится 10 января в 11:00 в ритуаль...
# 34  Президент РФ Владимир Путин потребовал от губе...
# 35  При создании культурных центров в регионах стр...
# 36  Премьера многострадального американского комед...
# 37  Авторы картины обещают придерживаться феминист...
# 38  Всего планируется создать несколько мультиплик...
# 39  ×\n\nОбновление пользовательского соглашения\n...
# 40  По мнению Кевина Файги, постановщик, который б...
# 41  Композиция стала частью дебютного сольного аль...
# 42  Режиссёром пилотного эпизода будущего шоу теле...
# 43  По мнению исполнителя, зрителей также следует ...
# 44  ×\n\nОбновление пользовательского соглашения\n...
# 45  На данный момент автор работает над другим про...
# 46  Вместе с тем певица призналась, что какие-то в...
# 47  Чернышов уверен, что у самого исполнителя рыль...
# 48  Лидером по числу номинаций стал фильм "Фаворит...
# 49  Это первый за последние пять лет российский фи...

# %%
EXCLUDE_SYMBOLS_STR = u''.join(['№', '«', 'ђ', '°', '±', '‚', 'ћ', '‰', '…', '»', 'ѓ', 'µ', '·', 'ґ', 'њ', 'ї', 'џ', 'є', '‹',
                                '‡', '†', '¶', 'ќ', '€', '“', 'ў', '§', '„', '”', '\ufeff', '’', 'љ', '›', '•', '—', '‘', 
                                '\x7f', '\xad', '¤', '\xa0', '¯ツ¯', chr(8211), chr(9583), chr(9633)])

# %%
regex_punct = re.compile('[%s]' % re.escape(string.punctuation))
regex_dig = re.compile('[%s]' % re.escape(string.digits))
regex_symb = re.compile('[%s]' % re.escape(EXCLUDE_SYMBOLS_STR))
regex_struct = re.compile('[%s]' % string.printable + string.whitespace)
emoji_pattern = re.compile("["
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+")

# %%
for category in data.columns.levels[0]:
    for key in data.columns.levels[1]:
        for i, item in enumerate(data[category][key]):
            item = emoji_pattern.sub(' ', item)
            item = item.strip().strip('\t').replace('\n', '')
            item = regex_punct.sub(' ', item)
            item = regex_dig.sub(' ', item)
            item = regex_symb.sub(' ', item)
            item = regex_struct.sub(' ', item)
            tokens = []
            sp = item.lower().split()
            for word in sp:
                if word not in stop_words.get_stop_words('ru'):
                    tokens.append(word)
            data.loc[i, (category, key)] = tokens

# %%
data['технологии']['Title'][0]
# Out:
# ['windows', 'появятся', 'смайлики', 'иероглифов']

# %%
docs_ = []
for category in data.columns.levels[0]:
    for key in data.columns.levels[1]:
        for i, item in enumerate(data[category][key]):
            docs_.append(item)

# %%
docs_
# Out:
# [['сети',
#   'появилось',
#   'великолепное',
#   'видео',
#   'которое',
#   'позволит',
#   'каждому',
#   'зрителей',
#   'поднять',
#   'рождественское',
#   'настроениепопулярный',
#   'американский',
#   'видеоблогер',
#   'the',
#   'angry',
#   'video',
#   'game',
#   'nerd',
#   'джеймс',
#   'рольф',
#   'записал',
#   'рождественский',
#   'й',
#   'эпизод',
#   'шоу',
#   'компанию',
#   'составил',
#   'актёр',
#   'маколей',
#   'калкин',
#   'известный',
#   'ролям',
#   'частях',
#   'фильма',
#   'домакалкин',
#   'рольф',
#   'поиграли',
#   'обсудили',
#   'игровые',
#   'адаптации',
#   'фильмов',
#   'дома',
#   'актёр',
#   'остался',
#   'доволен',
#   'провёл',
#   'блогером',
#   'сюжету',
#   'калкин',
#   'появился',
#   'экране',
#   'роли',
#   'доставщика',
#   'пиццы',
#   'пришёл',
#   'рольфу',
#   'коробкой',
#   'игр',
#   'дома',
#   'разных',
#   'игровых',
#   'консолей',
#   'предложил',
#   'сделать',
#   'обзор',
#   'ходу',
#   'игры',
#   'маколей',
#   'калкин',
#   'джеймс',
#   'рольф',
#   'комментировали',
#   'расхождения',
#   'игры',
#   'сюжетом',
#   'отмечали',
#   'достоинства',
#   'недостатки',
#   'той',
#   'иной',
#   'игрыв',
#   'итоге',
#   'блогеру',
#   'удалось',
#   'создать',
#   'отличное',
#   'рождественское',
#   'видео',
#   'вырос',
#   'любит',
#   'творчество',
#   'маколей',
#   'калкина'],
#  ['×обновление',
#   'пользовательского',
#   'соглашениямы',
#   'повышаем',
#   'качество',
#   'наших',
#   'пользовательских',
#   'служб',
#   'поэтому',
#   'обновляем',
#   'соглашение',
#   'использовании',
#   'служб',
#   'ооо',
#   'медиа',
#   'контент',
#   'далее',
#   'компания',
#   'издателем',
#   'сетевого',
#   'издания',
#   'телеканала',
#   'liferu',
#   'физическим',
#   'лицом',
#   'далее',
#   'пользователь',
#   'использованию',
#   'сайта',
#   'wwwliferu',
#   'далее',
#   'сайтознакомиться',
#   'данными',
#   'изменениями',
#   'можете',
#   'страницепользовательское',
#   'соглашение'],
#  ['фанаты',
#   'популярного',
#   'актёра',
#   'выбирает',
#   'брутальные',
#   'образы',
#   'удивились',
#   'такому',
#   'поступкупопулярный',
#   'американский',
#   'актёр',
#   'джейсон',
#   'момоа',
#   'появился',
#   'публике',
#   'достаточно',
#   'необычной',
#   'причёской',
#   'школьницы',
#   'длинные',
#   'вьющиеся',
#   'волосы',
#   'решил',
#   'связать',
#   'розовыми',
#   'резинками',
#   'хвоста',
#   'притом',
#   'звезда',
#   'аквамена',
#   'отличается',
#   'брутальным',
#   'внешним',
#   'видом',
#   'подчёркивает',
#   'творческое',
#   'амплуасвой',
#   'образ',
#   'школьницы',
#   'артист',
#   'решил',
#   'дополнить',
#   'гавайским',
#   'венком',
#   'шее',
#   'предмет',
#   'знаком',
#   'детства',
#   'летний',
#   'актёр',
#   'родился',
#   'гонолулу',
#   'гавайях',
#   'таком',
#   'образе',
#   'момоа',
#   'пришёл',
#   'шоу',
#   'the',
#   'project',
#   'tvвыбор',
#   'причёски',
#   'непонятен',
#   'фанатам',
#   'актёра',
#   'момоа',
#   'отметил',
#   'дети',
#   'неплохо',
#   'получается',
#   'заплетать',
#   'косички',
#   'словам',
#   'поклонников',
#   'актёра',
#   'таком',
#   'образе',
#   'равно',
#   'выглядел',
#   'уверенно',
#   'мужественно'],
#  ['проекта',
#   'отказался',
#   'шон',
#   'леви',
#   'ранее',
#   'работал',
#   'популярным',
#   'сериалом',
#   'странные',
#   'деластудия',
#   'sony',
#   'ищет',
#   'нового',
#   'режиссёра',
#   'экранизации',
#   'игры',
#   'uncharted',
#   'пишет',
#   'eurogamer',
#   'кресло',
#   'постановщика',
#   'освободил',
#   'шон',
#   'леви',
#   'ранее',
#   'работавший',
#   'сериалом',
#   'странные',
#   'дела',
#   'режиссёр',
#   'отказался',
#   'проекта',
#   'планирует',
#   'вместо',
#   'снимать',
#   'фильм',
#   'свободный',
#   'главную',
#   'роль',
#   'котором',
#   'исполнит',
#   'райан',
#   'рейнольдскомпания',
#   'sony',
#   'пытается',
#   'экранизировать',
#   'uncharted',
#   'разное',
#   'проекту',
#   'присматривались',
#   'сет',
#   'гордон',
#   'нил',
#   'бёргер',
#   'джо',
#   'карнахан',
#   'экранизация',
#   'вновь',
#   'вновь',
#   'оказывается',
#   'режиссёрасогласно',
#   'слухам',
#   'фильм',
#   'неизведанное',
#   'удача',
#   'дрейка',
#   'должен',
#   'стать',
#   'приквелом',
#   'игры',
#   'рассказать',
#   'первом',
#   'приключении',
#   'бесстрашного',
#   'искателя',
#   'сокровищ',
#   'нейтана',
#   'дрейка',
#   'исполнителем',
#   'главной',
#   'роли',
#   'значится',
#   'холланд',
#   'новый',
#   'человекпаук',
#   'настоящий',
#   'момент',
#   'сложно',
#   'останется',
#   'актёр',
#   'картиной'],
#  ['новый',
#   'комикс',
#   'звёздным',
#   'войнам',
#   'darth',
#   'vader',
#   'no',
#   'подтвердил',
#   'давнюю',
#   'фанатскую',
#   'теорию',
#   'происхождении',
#   'энакина',
#   'скайуокерасогласно',
#   'сюжету',
#   'ленты',
#   'скрытая',
#   'угроза',
#   'шми',
#   'мать',
#   'энакина',
#   'родила',
#   'мальчика',
#   'чудесного',
#   'непорочного',
#   'зачатия',
#   'квайгон',
#   'считал',
#   'произошло',
#   'благодаря',
#   'воле',
#   'силы',
#   'фанаты',
#   'спекулировали',
#   'чудо',
#   'случайным',
#   'ситуацию',
#   'ктото',
#   'подстроилиз',
#   'нового',
#   'комикса',
#   'стало',
#   'известно',
#   'отец',
#   'энакина',
#   'палпатин',
#   'дарт',
#   'сидиус',
#   'будущий',
#   'император',
#   'манипулировал',
#   'потоками',
#   'силы',
#   'создать',
#   'могущественного',
#   'тёмного',
#   'джедая',
#   'утробе',
#   'шмисамо',
#   'секса',
#   'манипуляций',
#   'сидиуса',
#   'вполне',
#   'достаточно',
#   'считать',
#   'палпатина',
#   'отцом',
#   'дарта',
#   'вейдера',
#   'сцену',
#   'зачатия',
#   'видит',
#   'дарт',
#   'вейдер',
#   'погружается',
#   'медитацию',
#   'силы',
#   'наблюдает',
#   'собственную',
#   'возможно',
#   'дальнейшем',
#   'использовано',
#   'сценаристами',
#   'подано',
#   'вейдеру',
#   'ктото',
#   'внушил',
#   'отец',
#   'палпатин'],
#  ['×обновление',
#   'пользовательского',
#   'соглашениямы',
#   'повышаем',
#   'качество',
#   'наших',
#   'пользовательских',
#   'служб',
#   'поэтому',
#   'обновляем',
#   'соглашение',
#   'использовании',
#   'служб',
#   'ооо',
#   'медиа',
#   'контент',
#   'далее',
#   'компания',
#   'издателем',
#   'сетевого',
#   'издания',
#   'телеканала',
#   'liferu',
#   'физическим',
#   'лицом',
#   'далее',
#   'пользователь',
#   'использованию',
#   'сайта',
#   'wwwliferu',
#   'далее',
#   'сайтознакомиться',
#   'данными',
#   'изменениями',
#   'можете',
#   'страницепользовательское',
#   'соглашение'],
#  ['×обновление',
#   'пользовательского',
#   'соглашениямы',
#   'повышаем',
#   'качество',
#   'наших',
#   'пользовательских',
#   'служб',
#   'поэтому',
#   'обновляем',
#   'соглашение',
#   'использовании',
#   'служб',
#   'ооо',
#   'медиа',
#   'контент',
#   'далее',
#   'компания',
#   'издателем',
#   'сетевого',
#   'издания',
#   'телеканала',
#   'liferu',
#   'физическим',
#   'лицом',
#   'далее',
#   'пользователь',
#   'использованию',
#   'сайта',
#   'wwwliferu',
#   'далее',
#   'сайтознакомиться',
#   'данными',
#   'изменениями',
#   'можете',
#   'страницепользовательское',
#   'соглашение'],
#  ['сценарий',
#   'новому',
#   'фильму',
#   'должны',
#   'написать',
#   'комики',
#   'шоу',
#   'субботним',
#   'вечером',
#   'прямом',
#   'эфире',
#   'майки',
#   'дэй',
#   'стритер',
#   'сейделстудии',
#   'disney',
#   'fox',
#   'планируют',
#   'вернуть',
#   'экраны',
#   'комедию',
#   'дома',
#   'настоящий',
#   'момент',
#   'проект',
#   'находится',
#   'огромном',
#   'приоритете',
#   'компаний',
#   'сообщает',
#   'splashreportнад',
#   'сценарием',
#   'фильма',
#   'работают',
#   'майки',
#   'дэй',
#   'стритер',
#   'сейдел',
#   'музыкальноюмористическая',
#   'передача',
#   'субботним',
#   'вечером',
#   'прямом',
#   'эфире',
#   'касается',
#   'режиссёра',
#   'студии',
#   'настоящий',
#   'момент',
#   'занимаются',
#   'поисками',
#   'человекапо',
#   'словам',
#   'источника',
#   'передал',
#   'информацию',
#   'журналистам',
#   'зрителей',
#   'ждёт',
#   'ремейк',
#   'прямое',
#   'продолжение',
#   'серии',
#   'новыми',
#   'героями',
#   'аналогичная',
#   'ситуация',
#   'произошла',
#   'фильмом',
#   'джуманджи'],
#  ['кинокритики',
#   'журнала',
#   'the',
#   'hollywood',
#   'reporter',
#   'выбрали',
#   'худших',
#   'фильмов',
#   'уходящего',
#   'годана',
#   'первом',
#   'месте',
#   'антирейтинга',
#   'оказалась',
#   'криминальная',
#   'драма',
#   'названием',
#   'кодекс',
#   'готти',
#   'режиссёр',
#   'кевин',
#   'коннолли',
#   'ленте',
#   'главного',
#   'американского',
#   'мафиози',
#   'сыграл',
#   'джон',
#   'траволта',
#   'сайте',
#   'rotten',
#   'tomatoes',
#   'агрегирующем',
#   'отзывы',
#   'рецензии',
#   'картина',
#   'получила',
#   'рейтинг',
#   'процентовна',
#   'втором',
#   'месте',
#   'списка',
#   'самых',
#   'провальных',
#   'фильмов',
#   'оказался',
#   'боевик',
#   'робин',
#   'гуд',
#   'начало',
#   'снятый',
#   'отто',
#   'батхёрстом',
#   'главный',
#   'кинокритик',
#   'the',
#   'hollywood',
#   'reporter',
#   'тодд',
#   'маккарти',
#   'заявил',
#   'вовлечён',
#   'работу',
#   'фильмом',
#   'должен',
#   'совершить',
#   'публичное',
#   'покаяние',
#   'замыкает',
#   'тройку',
#   'фильм',
#   'пятьдесят',
#   'оттенков',
#   'свободы',
#   'джеймса',
#   'фолитакже',
#   'десятку',
#   'худших',
#   'фильмов',
#   'вошли',
#   'веном',
#   'щелкунчик',
#   'королевства',
#   'лосанджелес',
#   'огне',
#   'операция',
#   'шаровая',
#   'молния',
#   'излом',
#   'суспирия'],
#  ['северной',
#   'америке',
#   'фантастический',
#   'боевик',
#   'вышел',
#   'российской',
#   'федерации',
#   'китаефильм',
#   'аквамен',
#   'завершил',
#   'первые',
#   'выходные',
#   'американском',
#   'прокате',
#   'внушительной',
#   'суммой',
#   'миллиона',
#   'долларов',
#   'всём',
#   'мире',
#   'лента',
#   'собрала',
#   'миллиона',
#   'долларов',
#   'сообщает',
#   'varietyдля',
#   'сравнения',
#   'веном',
#   'обогнал',
#   'выручке',
#   'чудоженщину',
#   'недель',
#   'дебютные',
#   'выходные',
#   'заработал',
#   'долларов',
#   'следует',
#   'отметить',
#   'китае',
#   'сделал',
#   'наибольшую',
#   'кассу',
#   'аквамена',
#   'фильм',
#   'оказался',
#   'экранах',
#   'неделю',
#   'америкеаналитики',
#   'считают',
#   'неделя',
#   'рождеством',
#   'сша',
#   'правило',
#   'достаточно',
#   'тихая',
#   'праздника',
#   'количество',
#   'посетителей',
#   'кинотеатров',
#   'сильно',
#   'вырастет',
#   'таким',
#   'образом',
#   'аквамен',
#   'собрать',
#   'достаточно',
#   'большую',
#   'кассу'],
#  ['беспризорники',
#   'станут',
#   'новыми',
#   'главными',
#   'героями',
#   'сериала',
#   'произведениям',
#   'артура',
#   'конана',
#   'дойлакомпания',
#   'netflix',
#   'снимет',
#   'сериал',
#   'книгам',
#   'артура',
#   'конана',
#   'дойла',
#   'детективе',
#   'шерлоке',
#   'холмсе',
#   'центре',
#   'сюжета',
#   'расследование',
#   'сыщик',
#   'беспризорники',
#   'докладывали',
#   'холмсу',
#   'происходящем',
#   'улицах',
#   'лондонасогласно',
#   'циклу',
#   'рассказов',
#   'холмсе',
#   'детектив',
#   'периодически',
#   'просил',
#   'мальчиков',
#   'помощи',
#   'слежке',
#   'поиске',
#   'улик',
#   'называли',
#   'глазами',
#   'холмса',
#   'улицах',
#   'предыдущих',
#   'экранизациях',
#   'переднем',
#   'плане',
#   'расследование',
#   'холмса',
#   'напарника',
#   'ватсонасценарий',
#   'нового',
#   'сериала',
#   'напишет',
#   'бидвелл',
#   'закончил',
#   'работу',
#   'экранизацией',
#   'опаснейшего',
#   'путешествия',
#   'даты',
#   'премьеры',
#   'нового',
#   'шоу'],
#  ['актриса',
#   'театра',
#   'кино',
#   'галина',
#   'тихонова',
#   'умерла',
#   'жизни',
#   'скоропостижной',
#   'кончине',
#   'сообщил',
#   'портал',
#   'sakha',
#   'life',
#   'предварительным',
#   'данным',
#   'артистка',
#   'ушла',
#   'жизни',
#   'изза',
#   'тяжёлой',
#   'болезни',
#   'подробности',
#   'известныдата',
#   'прощания',
#   'похорон',
#   'уточняетсягалина',
#   'тихонова',
#   'известна',
#   'крупным',
#   'якутским',
#   'кинопроектам',
#   'снялась',
#   'белом',
#   'ягеле',
#   'заблудившихся',
#   'моём',
#   'убийце',
#   'дороге',
#   'тд'],
#  ['лучшей',
#   'оказалась',
#   'кинодрама',
#   'названием',
#   'билборда',
#   'границе',
#   'эббинга',
#   'миссурипользователи',
#   'сервиса',
#   'кинопоиск',
#   'выбрали',
#   'лучший',
#   'полнометражный',
#   'художественный',
#   'фильм',
#   'оказалась',
#   'лента',
#   'билборда',
#   'границе',
#   'эббинга',
#   'миссурирейтинг',
#   'фильма',
#   'кинопоиске',
#   'составляет',
#   'балла',
#   'главным',
#   'российским',
#   'фильмом',
#   'стала',
#   'картина',
#   'движение',
#   'антона',
#   'мегердичева',
#   'рейтингом',
#   'фильм',
#   'возглавил',
#   'список',
#   'российского',
#   'проката',
#   'лента',
#   'собрала',
#   'миллиарда',
#   'рублейсамыми',
#   'популярными',
#   'российскими',
#   'актёрами',
#   'стали',
#   'александр',
#   'петров',
#   'любовь',
#   'аксёнова',
#   'итогам',
#   'александр',
#   'петров',
#   'возглавлял',
#   'рейтинг',
#   'самых',
#   'популярных',
#   'отечественных',
#   'актёров',
#   'главным',
#   'сериалом',
#   'выбран',
#   'видоизменённый',
#   'углерод',
#   'netflix',
#   'среди',
#   'российских',
#   'сериалов',
#   'лидирует',
#   'домашний',
#   'арест'],
#  ['первое',
#   'публичное',
#   'высказывание',
#   'звезды',
#   'карточного',
#   'домика',
#   'спустя',
#   'обвинений',
#   'домогательствах',
#   'декабря',
#   'голливудский',
#   'актёр',
#   'кевин',
#   'спейси',
#   'записал',
#   'видеообращение',
#   'названием',
#   'let',
#   'me',
#   'be',
#   'frank',
#   'позвольте',
#   'побыть',
#   'искреннимфрэнком',
#   'игра',
#   'слов',
#   'трёхминутном',
#   'видео',
#   'спейси',
#   'лица',
#   'фрэнка',
#   'андервуда',
#   'главных',
#   'персонажей',
#   'шоу',
#   'карточный',
#   'домик',
#   'netflix',
#   'решил',
#   'впервые',
#   'публично',
#   'высказаться',
#   'обвинений',
#   'домогательствахвы',
#   'доверяли',
#   'знали',
#   'должны',
#   'закончили',
#   'знаю',
#   'хотите',
#   'хотите',
#   'вернулся',
#   'кевин',
#   'спейсикевин',
#   'спейси',
#   'опубликовал',
#   'ссылку',
#   'видеообращение',
#   'социальных',
#   'сетях',
#   'забросил',
#   'октябре',
#   'netflix',
#   'отказался',
#   'сотрудничать',
#   'актёром',
#   'обвинили',
#   'сексуальных',
#   'домогательствах',
#   'летнему',
#   'подросткунапомним',
#   'сентябре',
#   'прокуратура',
#   'стала',
#   'возбуждать',
#   'уголовное',
#   'дело',
#   'отношении',
#   'актёра',
#   'изза',
#   'истекшего',
#   'срока',
#   'давности'],
#  ['крис',
#   'пайн',
#   'озвучивший',
#   'картине',
#   'питера',
#   'паркера',
#   'исполнил',
#   'композицию',
#   'spideybells',
#   'a',
#   'hero',
#   's',
#   'lament',
#   'паучью',
#   'пародию',
#   'jingle',
#   'bellsкомпания',
#   'sony',
#   'опубликовала',
#   'композиции',
#   'специального',
#   'альбома',
#   'a',
#   'very',
#   'spidey',
#   'christmas',
#   'звёзды',
#   'мультфильма',
#   'человекпаук',
#   'вселенные',
#   'поют',
#   'классические',
#   'рождественские',
#   'песни',
#   'одну',
#   'spideybells',
#   'a',
#   'hero',
#   's',
#   'lament',
#   'исполнил',
#   'крис',
#   'пайн',
#   'озвучивал',
#   'питера',
#   'паркера',
#   'играл',
#   'фильме',
#   'чудоженщинапри',
#   'джейк',
#   'джонсон',
#   'подарил',
#   'голос',
#   'циничному',
#   'уставшему',
#   'питеру',
#   'б',
#   'паркеру',
#   'спел',
#   'deck',
#   'the',
#   'halls',
#   'добавил',
#   'текст',
#   'шутки',
#   'супергеройскую',
#   'жизньпомимо',
#   'представленных',
#   'песен',
#   'a',
#   'very',
#   'spidey',
#   'christmas',
#   'входят',
#   'joy',
#   'to',
#   'the',
#   'world',
#   'шамеика',
#   'мура',
#   'up',
#   'on',
#   'the',
#   'house',
#   'top',
#   'пайна',
#   'the',
#   'night',
#   'before',
#   'christmas',
#   'spoken',
#   'word',
#   'которую',
#   'йорма',
#   'такконе',
#   'зачитывает',
#   'человекпаук',
#   'мультсериала',
#   'альбом',
#   'послушать',
#   'itunes'],
#  ['фильм',
#   'главную',
#   'роль',
#   'котором',
#   'сыграет',
#   'актриса',
#   'галь',
#   'гадот',
#   'выйдет',
#   'прокат',
#   'июне',
#   'годапопулярная',
#   'актриса',
#   'галь',
#   'гадот',
#   'instagram',
#   'опубликовала',
#   'поздравление',
#   'съёмочной',
#   'команды',
#   'звезда',
#   'чудоженщины',
#   'поздравила',
#   'команду',
#   'последним',
#   'днём',
#   'площадкемы',
#   'сделали',
#   'съёмки',
#   'первой',
#   'части',
#   'чудоженщины',
#   'невероятны',
#   'получилось',
#   'уникальным',
#   'особенным',
#   'снимали',
#   'четырёх',
#   'разных',
#   'местах',
#   'трёх',
#   'странах',
#   'горжусь',
#   'тысячу',
#   'членов',
#   'съёмочной',
#   'группы',
#   'галь',
#   'гадотнапомним',
#   'действие',
#   'нового',
#   'фильма',
#   'разворачивается',
#   'годы',
#   'времена',
#   'холодной',
#   'войны',
#   'главный',
#   'злодей',
#   'ленты',
#   'гепарда',
#   'одна',
#   'противниц',
#   'чудоженщины',
#   'комиксов',
#   'сыграла',
#   'актриса',
#   'кристен',
#   'уиг',
#   'роли',
#   'вернулся',
#   'крис',
#   'пайн',
#   'сыгравший',
#   'друга',
#   'дианы',
#   'стива',
#   'тревораизначально',
#   'чудоженщина',
#   'должна',
#   'выйти',
#   'ноябре',
#   'студия',
#   'отложила',
#   'картину',
#   'месяцев',
#   'музыку',
#   'фильму',
#   'напишет',
#   'композитор',
#   'ханс',
#   'циммер'],
#  ['настоящий',
#   'момент',
#   'студия',
#   'планирует',
#   'выпустить',
#   'будущем',
#   'кинокартинкомпания',
#   'disney',
#   'поделилась',
#   'списком',
#   'премьер',
#   'прошлом',
#   'кинокомпания',
#   'завоевала',
#   'четверти',
#   'американского',
#   'кинорынка',
#   'всей',
#   'видимости',
#   'планирует',
#   'останавливаться',
#   'сообщает',
#   'comicbookв',
#   'disney',
#   'планирует',
#   'выпустить',
#   'минимум',
#   'фильмов',
#   'среди',
#   'капитан',
#   'марвел',
#   'марта',
#   'дамбо',
#   'марта',
#   'фильм',
#   'пингвинов',
#   'апреля',
#   'новые',
#   'мстители',
#   'апрелятакже',
#   'disney',
#   'планирует',
#   'выпустить',
#   'нового',
#   'аладдина',
#   'мая',
#   'новую',
#   'историю',
#   'игрушек',
#   'июня',
#   'короля',
#   'льва',
#   'июля',
#   'фильм',
#   'артемис',
#   'фаул',
#   'августа',
#   'осенью',
#   'disney',
#   'выпустит',
#   'холодное',
#   'сердце',
#   'ноября',
#   'декабря',
#   'выйдут',
#   'новые',
#   'звёздные',
#   'войны'],
#  ['число',
#   'зрителей',
#   'кинотеатрах',
#   'страны',
#   'превысит',
#   'посетителейпосещаемость',
#   'кассовые',
#   'сборы',
#   'российских',
#   'фильмов',
#   'неделю',
#   'завершения',
#   'превысили',
#   'рекордные',
#   'значения',
#   'предыдущего',
#   'сообщает',
#   'фонд',
#   'кино',
#   'ссылкой',
#   'данные',
#   'единой',
#   'федеральной',
#   'автоматизированной',
#   'информационной',
#   'системы',
#   'сведений',
#   'показе',
#   'фильмовпо',
#   'состоянию',
#   'декабря',
#   'кассовые',
#   'сборы',
#   'отечественного',
#   'кино',
#   'превысили',
#   'миллиарда',
#   'рублей',
#   'число',
#   'зрителей',
#   'оказалось',
#   'выше',
#   'результаты',
#   'обновили',
#   'рекорды',
#   'зафиксированы',
#   'миллиардов',
#   'рублей',
#   'сборов',
#   'миллиона',
#   'зрителейэтот',
#   'непростым',
#   'рынка',
#   'кинопроката',
#   'сравнению',
#   'аналогичным',
#   'периодом',
#   'прошлого',
#   'объём',
#   'рынка',
#   'снизился',
#   'рублёвом',
#   'выражении',
#   'процента',
#   'фонд',
#   'считает',
#   'итогам',
#   'снижение',
#   'составит'],
#  ['актёр',
#   'звезда',
#   'сериалов',
#   'секретные',
#   'материалы',
#   'блудливая',
#   'калифорния',
#   'рассказал',
#   'знакомстве',
#   'российской',
#   'музыкойпо',
#   'словам',
#   'духовны',
#   'неплохо',
#   'знаком',
#   'популярной',
#   'музыкой',
#   'россии',
#   'брать',
#   'расчёт',
#   'классику',
#   'чайковского',
#   'прокофьева',
#   'актёр',
#   'рассказал',
#   'рбкактёр',
#   'секретных',
#   'материалов',
#   'заявил',
#   'съёмках',
#   'рекламы',
#   'россии',
#   'слушал',
#   'российскую',
#   'попмузыку',
#   'словам',
#   'дэвида',
#   'понимал',
#   'слова',
#   'мелодия',
#   'нравиласьчто',
#   'касается',
#   'группы',
#   'ленинград',
#   'духовны',
#   'заявил',
#   'названия',
#   'запомнил',
#   'планирует',
#   'попросить',
#   'актёра',
#   'райана',
#   'рейнольдса',
#   'перекинуть',
#   'песен',
#   'ленинграда',
#   'перспективе',
#   'записать',
#   'совместный',
#   'трек',
#   'группой',
#   'актёр',
#   'хочет',
#   'послушать',
#   'песни'],
#  ['сюжет',
#   'будущей',
#   'киноленты',
#   'должен',
#   'достаточно',
#   'серьёзно',
#   'отойти',
#   'канона',
#   'комиксовактёры',
#   'ленты',
#   'человекпаук',
#   'дома',
#   'джейк',
#   'джилленхол',
#   'джейкоб',
#   'баталон',
#   'раскрыли',
#   'подробности',
#   'будущего',
#   'фильма',
#   'сообщает',
#   'colliderджилленхол',
#   'заявил',
#   'главными',
#   'злодеями',
#   'будущего',
#   'фильма',
#   'элементали',
#   'существа',
#   'способные',
#   'управлять',
#   'водой',
#   'землёй',
#   'огнём',
#   'воздухом',
#   'вызывать',
#   'стихийные',
#   'бедствия',
#   'актёр',
#   'должен',
#   'сыграть',
#   'мистерио',
#   'врага',
#   'человекапаука',
#   'новом',
#   'фильме',
#   'внезапно',
#   'перейдёт',
#   'сторону',
#   'противника',
#   'вместе',
#   'паркером',
#   'бороться',
#   'элементалейджейкоб',
#   'баталон',
#   'исполняющий',
#   'роль',
#   'лучшего',
#   'друга',
#   'питера',
#   'паркера',
#   'неда',
#   'заявил',
#   'человекпаук',
#   'дома',
#   'фильм',
#   'ребятах',
#   'европейских',
#   'каникул',
#   'рассказал',
#   'картине',
#   'путешествий',
#   'моментов',
#   'связанных',
#   'отношениями',
#   'премьера',
#   'ленты',
#   'запланирована',
#   'июля'],
#  ['×обновление',
#   'пользовательского',
#   'соглашениямы',
#   'повышаем',
#   'качество',
#   'наших',
#   'пользовательских',
#   'служб',
#   'поэтому',
#   'обновляем',
#   'соглашение',
#   'использовании',
#   'служб',
#   'ооо',
#   'медиа',
#   'контент',
#   'далее',
#   'компания',
#   'издателем',
#   'сетевого',
#   'издания',
#   'телеканала',
#   'liferu',
#   'физическим',
#   'лицом',
#   'далее',
#   'пользователь',
#   'использованию',
#   'сайта',
#   'wwwliferu',
#   'далее',
#   'сайтознакомиться',
#   'данными',
#   'изменениями',
#   'можете',
#   'страницепользовательское',
#   'соглашение'],
#  ['×обновление',
#   'пользовательского',
#   'соглашениямы',
#   'повышаем',
#   'качество',
#   'наших',
#   'пользовательских',
#   'служб',
#   'поэтому',
#   'обновляем',
#   'соглашение',
#   'использовании',
#   'служб',
#   'ооо',
#   'медиа',
#   'контент',
#   'далее',
#   'компания',
#   'издателем',
#   'сетевого',
#   'издания',
#   'телеканала',
#   'liferu',
#   'физическим',
#   'лицом',
#   'далее',
#   'пользователь',
#   'использованию',
#   'сайта',
#   'wwwliferu',
#   'далее',
#   'сайтознакомиться',
#   'данными',
#   'изменениями',
#   'можете',
#   'страницепользовательское',
#   'соглашение'],
#  ['аксессуар',
#   'распечатан',
#   'помощью',
#   'dпринтера',
#   'модель',
#   'блогер',
#   'скачал',
#   'сайта',
#   'thingiverseyoutubeблогер',
#   'kyleofasgard',
#   'выпустил',
#   'видео',
#   'пошаговой',
#   'инструкцией',
#   'сборке',
#   'самодельного',
#   'шлема',
#   'тора',
#   'аксессуар',
#   'делает',
#   'глаза',
#   'владельца',
#   'шлема',
#   'светилисьдля',
#   'добиться',
#   'эффекта',
#   'автору',
#   'гаджета',
#   'пришлось',
#   'использовать',
#   'линзы',
#   'светятся',
#   'ультрафиолетовым',
#   'излучением',
#   'блогеру',
#   'пришлось',
#   'использовать',
#   'уфлампу',
#   'которую',
#   'разместил',
#   'внутри',
#   'шлемашлем',
#   'kyleofasgard',
#   'распечатал',
#   'dпринтере',
#   'модель',
#   'скачал',
#   'сайта',
#   'thingiverse',
#   'цепь',
#   'питания',
#   'ledленты',
#   'состояла',
#   'преобразователя',
#   'напряжения',
#   'батарейки',
#   'переключателя',
#   'системы',
#   'дистанционного',
#   'включения',
#   'создатель',
#   'гаджета',
#   'заявил',
#   'носить',
#   'шлем',
#   'долгое',
#   'стоит',
#   'ультрафиолетовое',
#   'излучение',
#   'негативно',
#   'сказаться',
#   'зрении'],
#  ['лидирующую',
#   'позицию',
#   'количеству',
#   'номинаций',
#   'заняли',
#   'сразу',
#   'киноленты',
#   'лёд',
#   'движение',
#   'вверхэкспертный',
#   'совет',
#   'национальной',
#   'академии',
#   'кинематографических',
#   'искусств',
#   'наук',
#   'российской',
#   'федерации',
#   'определения',
#   'лауреатом',
#   'премии',
#   'золотой',
#   'орёл',
#   'нынешний',
#   'предложил',
#   'полнометражный',
#   'игровой',
#   'фильм',
#   'неигровых',
#   'короткометражных',
#   'лент',
#   'прессслужба',
#   'академии',
#   'объявила',
#   'номинантовлидерами',
#   'числу',
#   'номинаций',
#   'стали',
#   'фильмы',
#   'возглавляли',
#   'список',
#   'самых',
#   'кассовых',
#   'отечественных',
#   'лент',
#   'среди',
#   'лёд',
#   'олега',
#   'трофима',
#   'номинаций',
#   'движение',
#   'антона',
#   'мегердичева',
#   'номинаций',
#   'претендентами',
#   'разные',
#   'призы',
#   'стали',
#   'история',
#   'назначения',
#   'авдотьи',
#   'смирновой',
#   'война',
#   'анны',
#   'алексея',
#   'федорченко',
#   'спитак',
#   'александра',
#   'коттапри',
#   'лучшей',
#   'актрисой',
#   'стать',
#   'марта',
#   'козлова',
#   'аглая',
#   'тарасова',
#   'светлана',
#   'ходченкова',
#   'ирина',
#   'горбачёва',
#   'лучшим',
#   'актёром',
#   'александр',
#   'петров',
#   'отличился',
#   'сразу',
#   'трёх',
#   'фильмах',
#   'владимир',
#   'машков',
#   'олег',
#   'меньшиков',
#   'андрей',
#   'смоляков',
#   'звание',
#   'популярного',
#   'сериала',
#   'сражаются',
#   'обычная',
#   'женщина',
#   'хождение',
#   'мукам',
#   'мост',
#   'берёзканапомним',
#   'торжественное',
#   'награждение',
#   'победителей',
#   'проходить',
#   'января'],
#  ['спор',
#   'двумя',
#   'авторами',
#   'популярных',
#   'американских',
#   'кинолент',
#   'состоялся',
#   'годурежиссёр',
#   'эдгар',
#   'райт',
#   'малыш',
#   'драйве',
#   'проиграл',
#   'оскар',
#   'своему',
#   'коллеге',
#   'джеймсу',
#   'вану',
#   'аквамен',
#   'поспорили',
#   'социальной',
#   'сети',
#   'twitter',
#   'ван',
#   'сможет',
#   'оставить',
#   'фильме',
#   'отсылку',
#   'сериалу',
#   'стингрей',
#   'райт',
#   'отдаст',
#   'свой',
#   'трофейджеймс',
#   'ван',
#   'заявил',
#   'настоящий',
#   'момент',
#   'ждёт',
#   'коллега',
#   'посмотрит',
#   'ленту',
#   'вспомнит',
#   'той',
#   'публикации',
#   'райт',
#   'рассказал',
#   'видел',
#   'фильм',
#   'насколько',
#   'понимает',
#   'должен',
#   'оскар',
#   'ванунапомним',
#   'мировом',
#   'прокате',
#   'фильм',
#   'аквамен',
#   'собрал',
#   'долларов',
#   'сша',
#   'лента',
#   'вышла',
#   'прокат',
#   'декабря',
#   'собрала',
#   'порядка',
#   'долларов'],
#  ['добиться',
#   'удалось',
#   'благодаря',
#   'аквамену',
#   'продажи',
#   'сеансы',
#   'настоящий',
#   'момент',
#   'зашкаливают',
#   'сшав',
#   'кассовые',
#   'сборы',
#   'продажи',
#   'билетов',
#   'кино',
#   'канаде',
#   'сша',
#   'превысят',
#   'миллиарда',
#   'долларов',
#   'таким',
#   'образом',
#   'голливуд',
#   'побил',
#   'рекорд',
#   'общая',
#   'сумма',
#   'поступлений',
#   'составила',
#   'миллиарда',
#   'долларовна',
#   'рост',
#   'продаж',
#   'повлияли',
#   'аквамен',
#   'чёрная',
#   'пантера',
#   'мстители',
#   'война',
#   'бесконечности',
#   'дэдпул',
#   'мир',
#   'юрского',
#   'периода',
#   'прошлом',
#   'отмечался',
#   'спад',
#   'посещаемости',
#   'кинотеатров',
#   'связи',
#   'голливуде',
#   'опасались',
#   'перестанут',
#   'ходить',
#   'кино',
#   'смотреть',
#   'фильмы',
#   'помощью',
#   'netflix',
#   'amazon',
#   'стримингсервисовтакже',
#   'аналитики',
#   'сообщили',
#   'цены',
#   'билеты',
#   'кино',
#   'увеличились',
#   'повлияло',
#   'увеличение',
#   'кассовых',
#   'сборов',
#   'таким',
#   'образом',
#   'канаде',
#   'сша',
#   'продано',
#   'миллиарда',
#   'билетов'],
#  ['чад',
#   'стахелски',
#   'очередной',
#   'решил',
#   'подтвердить',
#   'журналистам',
#   'намерения',
#   'поводу',
#   'съёмокрежиссёр',
#   'чад',
#   'стахелски',
#   'джон',
#   'уик',
#   'теряет',
#   'надежды',
#   'снимет',
#   'ремейк',
#   'фильма',
#   'горец',
#   'сообщает',
#   'ewстахелски',
#   'заявил',
#   'хочет',
#   'работать',
#   'проектом',
#   'предполагается',
#   'режиссёр',
#   'сможет',
#   'заняться',
#   'сразу',
#   'полностью',
#   'завершит',
#   'работу',
#   'третьей',
#   'частью',
#   'ленты',
#   'джон',
#   'уик',
#   'стахелски',
#   'заявлял',
#   'проектов',
#   'общегонапомним',
#   'проект',
#   'перезапуска',
#   'горца',
#   'появился',
#   'права',
#   'экранизацию',
#   'купила',
#   'фирма',
#   'summit',
#   'entertainment',
#   'выкупила',
#   'студия',
#   'lionsgate',
#   'работу',
#   'сценарием',
#   'закончили',
#   'марте',
#   'писал',
#   'райан',
#   'кондал',
#   'рэмпейдж',
#   'геракл'],
#  ['спустя',
#   'стало',
#   'известно',
#   'чёрнобелый',
#   'фильм',
#   'ангелы',
#   'грязными',
#   'душами',
#   'выходилфанатов',
#   'фильма',
#   'дома',
#   'шокировал',
#   'факт',
#   'известная',
#   'фраза',
#   'ленты',
#   'оказалось',
#   'фейком',
#   'рассказал',
#   'актёр',
#   'сценарист',
#   'сет',
#   'рогенречь',
#   'идёт',
#   'фразе',
#   'сдачу',
#   'оставь',
#   'грязное',
#   'животное',
#   'стала',
#   'мемом',
#   'частью',
#   'популярной',
#   'культуры',
#   'звучит',
#   'гангстерском',
#   'фильме',
#   'ангелы',
#   'грязными',
#   'душами',
#   'сцен',
#   'дома',
#   'смотрит',
#   'кевин',
#   'маккаллистеркак',
#   'удалось',
#   'выяснить',
#   'деле',
#   'фильма',
#   'существует',
#   'режиссёр',
#   'крис',
#   'коламбус',
#   'снял',
#   'таких',
#   'чёрнобелых',
#   'роликов',
#   'специально',
#   'производства',
#   'фильмов',
#   'дома',
#   'дома'],
#  ['×обновление',
#   'пользовательского',
#   'соглашениямы',
#   'повышаем',
#   'качество',
#   'наших',
#   'пользовательских',
#   'служб',
#   'поэтому',
#   'обновляем',
#   'соглашение',
#   'использовании',
#   'служб',
#   'ооо',
#   'медиа',
#   'контент',
#   'далее',
#   'компания',
#   'издателем',
#   'сетевого',
#   'издания',
#   'телеканала',
#   'liferu',
#   'физическим',
#   'лицом',
#   'далее',
#   'пользователь',
#   'использованию',
#   'сайта',
#   'wwwliferu',
#   'далее',
#   'сайтознакомиться',
#   'данными',
#   'изменениями',
#   'можете',
#   'страницепользовательское',
#   'соглашение'],
#  ['каждой',
#   'трансляцией',
#   'сериала',
#   'должна',
#   'появляться',
#   'информация',
#   'персонажи',
#   'вымышленысуд',
#   'польского',
#   'кракова',
#   'обязал',
#   'немецкий',
#   'телеканал',
#   'zdf',
#   'иском',
#   'выступил',
#   'ветеран',
#   'армии',
#   'крайовой',
#   'збигнев',
#   'радловский',
#   'извиниться',
#   'показ',
#   'сериала',
#   'матери',
#   'отцыфильм',
#   'вызвал',
#   'польше',
#   'недовольство',
#   'связи',
#   'бойцы',
#   'армии',
#   'крайовой',
#   'нём',
#   'показаны',
#   'антисемиты',
#   'вина',
#   'немцев',
#   'преступлениях',
#   'евреев',
#   'замалчиваетсясогласно',
#   'постановлению',
#   'каждой',
#   'трансляцией',
#   'сериала',
#   'должна',
#   'появляться',
#   'информация',
#   'персонажи',
#   'вымышлены',
#   'поляки',
#   'мировой',
#   'помогали',
#   'евреям',
#   'немцы',
#   'оккупировали',
#   'польшусуд',
#   'обязал',
#   'телеканал',
#   'выплатить',
#   'злотых',
#   'тысячи',
#   'долларов',
#   'компенсации',
#   'капитану',
#   'армии',
#   'краевой',
#   'збигневу',
#   'радловскомуюристы',
#   'представляли',
#   'суде',
#   'немецкий',
#   'канал',
#   'производителя',
#   'сериала',
#   'просили',
#   'прекращении',
#   'процесса',
#   'заявляли',
#   'авторы',
#   'пользовались',
#   'свободой',
#   'творчества',
#   'производя',
#   'исторический',
#   'художественный',
#   'фильм'],
#  ['личный',
#   'рейтинг',
#   'экспрезидента',
#   'сша',
#   'вошло',
#   'книг',
#   'фильмов',
#   'песен',
#   'заставляющих',
#   'думать',
#   'вдохновляющих',
#   'любимыхбывший',
#   'глава',
#   'белого',
#   'дома',
#   'барак',
#   'обама',
#   'опубликовал',
#   'фейсбуке',
#   'список',
#   'любимых',
#   'произведений',
#   'литературы',
#   'фильмов',
#   'песен',
#   'годав',
#   'вошли',
#   'числе',
#   'книга',
#   'американская',
#   'тюрьма',
#   'шейна',
#   'бауэра',
#   'ленты',
#   'чёрная',
#   'пантера',
#   'смерть',
#   'сталина',
#   'песни',
#   'карди',
#   'би',
#   'легенды',
#   'джаза',
#   'нэнси',
#   'уилсон',
#   'певца',
#   'принсаотдельно',
#   'обама',
#   'упомянул',
#   'произведения',
#   'включал',
#   'аналогичные',
#   'рейтинги',
#   'прошлых',
#   'отметил',
#   'удовольствием',
#   'читал',
#   'смотрел',
#   'слушал',
#   'уходящем',
#   'годуна',
#   'первой',
#   'строчке',
#   'книга',
#   'супруги',
#   'мишель',
#   'обамы',
#   'становление',
#   'которую',
#   'экспрезидент',
#   'назвал',
#   'очевидно',
#   'любимой',
#   'перечитывал',
#   'долгий',
#   'путь',
#   'свободе',
#   'нельсона',
#   'манделы',
#   'многие',
#   'книги'],
#  ['мегафон',
#   'проанализировал',
#   'данные',
#   'количеству',
#   'просмотров',
#   'онлайнкинотеатре',
#   'мегафон',
#   'tv',
#   'подготовил',
#   'рейтинг',
#   'самых',
#   'популярных',
#   'фильмов',
#   'сериалов',
#   'абонентовв',
#   'тройку',
#   'лидеров',
#   'среди',
#   'художественных',
#   'фильмов',
#   'попали',
#   'ленты',
#   'собибор',
#   'худею',
#   'мстители',
#   'война',
#   'бесконечности',
#   'топ',
#   'вошли',
#   'картины',
#   'первому',
#   'игроку',
#   'приготовиться',
#   'гоголь',
#   'страшная',
#   'месть',
#   'бегущий',
#   'лезвию',
#   'ремпейдж',
#   'джуманджи',
#   'зов',
#   'джунглей',
#   'тор',
#   'рагнарёк',
#   'геоштормрейтинг',
#   'сериалов',
#   'возглавила',
#   'игра',
#   'престолов',
#   'второе',
#   'третье',
#   'место',
#   'заняли',
#   'российских',
#   'сериала',
#   'ивановыивановы',
#   'полицейский',
#   'рублёвки',
#   'соответственно',
#   'десятку',
#   'попали',
#   'отель',
#   'элеон',
#   'гранд',
#   'универ',
#   'улица',
#   'хороший',
#   'докторв',
#   'декабре',
#   'январе',
#   'мегафон',
#   'tv',
#   'всей',
#   'семьи',
#   'работать',
#   'телеканал',
#   'деда',
#   'мороза',
#   'подборкой',
#   'праздничных',
#   'кино',
#   'мультипликационных',
#   'фильмов',
#   'сериалов',
#   'шоу',
#   'познавательных',
#   'программ',
#   'сервисом',
#   'мегафон',
#   'tv',
#   'пользоваться',
#   'смартфонах',
#   'планшетах',
#   'smartтелевизорах',
#   'компьютерах',
#   'выходом',
#   'интернет',
#   'тв',
#   'фильмы',
#   'доступны',
#   'дороге',
#   'парках',
#   'кафе',
#   'даче',
#   'метро',
#   'оплате',
#   'фильмов',
#   'банковской',
#   'картой',
#   'мегафона',
#   'онлайнкинотеатре',
#   'оператор',
#   'вернёт',
#   'стоимости',
#   'счёт',
#   'мобильного'],
#  ['прославленный',
#   'кинорежиссёр',
#   'сценарист',
#   'марлен',
#   'хуциев',
#   'госпитализирован',
#   'москве',
#   'сообщает',
#   'канал',
#   'подробности',
#   'состояния',
#   'летнего',
#   'народного',
#   'артиста',
#   'ссср',
#   'раскрываются',
#   'известно',
#   'категорически',
#   'отказался',
#   'ехать',
#   'больницу',
#   'женыпожилых',
#   'супругов',
#   'госпитализировали',
#   'вместе',
#   'поместили',
#   'одну',
#   'палату',
#   'обследуют',
#   'медикимарлен',
#   'хуциев',
#   'широко',
#   'известен',
#   'отечественному',
#   'зрителю',
#   'своими',
#   'работами',
#   'весна',
#   'заречной',
#   'улице',
#   'фёдора',
#   'застава',
#   'ильича',
#   'многими',
#   'другими'],
#  ['сайтагрегатор',
#   'metacritic',
#   'специализирующийся',
#   'сборе',
#   'анализе',
#   'отзывов',
#   'зрителей',
#   'опубликовал',
#   'список',
#   'лучших',
#   'сериалов',
#   'дебютировавших',
#   'годупервое',
#   'место',
#   'заняла',
#   'гениальная',
#   'подруга',
#   'сериал',
#   'основанный',
#   'одноимённом',
#   'произведении',
#   'элены',
#   'ферранте',
#   'примечательно',
#   'продюсером',
#   'проекта',
#   'выступил',
#   'знаменитый',
#   'итальянский',
#   'режиссёр',
#   'паоло',
#   'соррентиновторой',
#   'стала',
#   'чёрная',
#   'комедия',
#   'барри',
#   'биллом',
#   'хейдером',
#   'главной',
#   'роли',
#   'история',
#   'киллеренеудачнике',
#   'неожиданно',
#   'находит',
#   'своё',
#   'истинное',
#   'призвание',
#   'убийстве',
#   'людей',
#   'театральной',
#   'сценена',
#   'третьем',
#   'месте',
#   'оказался',
#   'драматический',
#   'сериал',
#   'убивая',
#   'еву',
#   'рассказывающий',
#   'историю',
#   'аналитика',
#   'британской',
#   'контрразведки',
#   'mi',
#   'евы',
#   'поластри',
#   'охотится',
#   'наёмного',
#   'убийцу',
#   'вилланель',
#   'сериал',
#   'основан',
#   'серии',
#   'романов',
#   'люка',
#   'дженнингса',
#   'адаптированных',
#   'актрисой',
#   'фиби',
#   'уоллербриджпомимо',
#   'топ',
#   'вошли',
#   'свободном',
#   'улёте',
#   'возвращение',
#   'домой',
#   'джулией',
#   'робертс',
#   'главной',
#   'роли',
#   'соболезную',
#   'вашей',
#   'утрате',
#   'конец',
#   'нарко',
#   'мексика',
#   'телохранитель',
#   'чёрная',
#   'молния'],
#  ['мнению',
#   'священнослужителя',
#   'фильм',
#   'транслирует',
#   'идею',
#   'чуда',
#   'достаточно',
#   'встретиться',
#   'напитьсяактёр',
#   'андрей',
#   'мягков',
#   'сыграл',
#   'роль',
#   'евгения',
#   'лукашина',
#   'фильме',
#   'ирония',
#   'судьбы',
#   'лёгким',
#   'паром',
#   'резко',
#   'отреагировал',
#   'критику',
#   'картины',
#   'стороны',
#   'митрополита',
#   'рязанского',
#   'михайловского',
#   'маркасвященнослужитель',
#   'ранее',
#   'заявил',
#   'кинолента',
#   'наполняет',
#   'человеческую',
#   'душу',
#   'ложными',
#   'несбыточными',
#   'мечтаниями',
#   'транслирует',
#   'идею',
#   'произошло',
#   'чудо',
#   'достаточно',
#   'встретиться',
#   'напитьсяисполнитель',
#   'главных',
#   'ролей',
#   'фильме',
#   'счёл',
#   'митрополита',
#   'недалёким',
#   'думаю',
#   'рязанский',
#   'митрополит',
#   'недалёк',
#   'умом',
#   'говорить',
#   'приводит',
#   'слова',
#   'актёра',
#   'радиостанция',
#   'москвакак',
#   'писал',
#   'лайф',
#   'своём',
#   'новогоднем',
#   'обращении',
#   'митрополит',
#   'подчеркнул',
#   'церковь',
#   'призывает',
#   'людей',
#   'труду',
#   'постоянной',
#   'работе',
#   'данная',
#   'кинолента',
#   'мнению',
#   'установке',
#   'противоречит'],
#  ['втором',
#   'месте',
#   'оказалась',
#   'кинолента',
#   'ёлки',
#   'последние',
#   'третье',
#   'место',
#   'занял',
#   'мультфильм',
#   'гринчроссийская',
#   'комедия',
#   'названием',
#   'полицейский',
#   'рублёвки',
#   'новогодний',
#   'беспредел',
#   'собрала',
#   'российском',
#   'прокате',
#   'миллиона',
#   'рублей',
#   'итогам',
#   'выходных',
#   'благодаря',
#   'фильм',
#   'сохранил',
#   'лидерство',
#   'прокателента',
#   'ильи',
#   'куликова',
#   'вышла',
#   'прокат',
#   'декабря',
#   'фильм',
#   'основан',
#   'телевизионном',
#   'сериале',
#   'названием',
#   'полицейский',
#   'рублёвки',
#   'рассказывает',
#   'сотрудника',
#   'отделения',
#   'полиции',
#   'пытается',
#   'спасти',
#   'свой',
#   'отдел',
#   'расформированияна',
#   'втором',
#   'месте',
#   'оказалась',
#   'одна',
#   'отечественная',
#   'кинокартина',
#   'ёлки',
#   'последние',
#   'комедии',
#   'удалось',
#   'собрать',
#   'миллиона',
#   'рублей',
#   'третье',
#   'место',
#   'занял',
#   'мультфильм',
#   'гринч',
#   'собрал',
#   'миллиона',
#   'рублей',
#   'прошедшие',
#   'выходные'],
#  ['компания',
#   'netflix',
#   'поделилась',
#   'тизером',
#   'постером',
#   'продолжения',
#   'популярного',
#   'американского',
#   'шоув',
#   'сети',
#   'появилась',
#   'информация',
#   'касается',
#   'даты',
#   'выхода',
#   'нового',
#   'сезона',
#   'сериала',
#   'странные',
#   'дела',
#   'новые',
#   'эпизоды',
#   'доступны',
#   'просмотра',
#   'июля',
#   'годадействие',
#   'будущего',
#   'сезона',
#   'разворачивается',
#   'опубликованном',
#   'тизере',
#   'популярный',
#   'американский',
#   'ведущий',
#   'дик',
#   'кларк',
#   'отсчитывает',
#   'последние',
#   'секунды',
#   'уходящего',
#   'вёл',
#   'передачу',
#   'dick',
#   'clarks',
#   'new',
#   'years',
#   'rocking',
#   'eve',
#   'рок',
#   'новый',
#   'диком',
#   'кларком',
#   'шоу',
#   'показывали',
#   'ньюйоркской',
#   'таймссквер',
#   'телеведущий',
#   'умер',
#   'годучто',
#   'касается',
#   'шоу',
#   'рассказывает',
#   'подростков',
#   'годы',
#   'штате',
#   'индиана',
#   'события',
#   'разворачиваются',
#   'вымышленном',
#   'городе',
#   'хоукинсе'],
#  ['соответствующий',
#   'список',
#   'составлен',
#   'сайтом',
#   'fandango',
#   'традиционно',
#   'делает',
#   'прогнозы',
#   'будущий',
#   'годфильмы',
#   'студии',
#   'marvel',
#   'стали',
#   'самыми',
#   'ожидаемыми',
#   'среди',
#   'выходят',
#   'сообщает',
#   'fandangoпервое',
#   'место',
#   'заняла',
#   'четвёртая',
#   'часть',
#   'мстителей',
#   'позиции',
#   'оказался',
#   'фильм',
#   'капитан',
#   'марвел',
#   'третье',
#   'место',
#   'досталось',
#   'девятому',
#   'эпизоду',
#   'звёздных',
#   'войн',
#   'пятёрку',
#   'лидеров',
#   'вошли',
#   'человекпаук',
#   'дома',
#   'история',
#   'игрушек',
#   'остальные',
#   'места',
#   'первой',
#   'десятке',
#   'заняли',
#   'следующие',
#   'ленты',
#   'стекло',
#   'король',
#   'лев',
#   'аладдин',
#   'дамбо',
#   'джокер',
#   'касается',
#   'капитана',
#   'марвела',
#   'фильм',
#   'возглавил',
#   'список',
#   'самых',
#   'ожидаемых',
#   'сольных',
#   'лент',
#   'супергероях'],
#  ['соответствующее',
#   'заявление',
#   'автор',
#   'американской',
#   'киноленты',
#   'решил',
#   'сделать',
#   'собственном',
#   'микроблоге',
#   'twitterджеймс',
#   'ван',
#   'режиссёр',
#   'аквамена',
#   'обратился',
#   'фанатам',
#   'фильма',
#   'просьбой',
#   'оскорблять',
#   'людей',
#   'которым',
#   'понравилась',
#   'лента',
#   'рассказал',
#   'странице',
#   'персонального',
#   'twitterаккаунтая',
#   'узнал',
#   'которым',
#   'понравился',
#   'аквамен',
#   'подвергаются',
#   'насмешкам',
#   'оскорблениям',
#   'стороны',
#   'фанатов',
#   'ленты',
#   'делать',
#   'нужна',
#   'поддержка',
#   'проявляйте',
#   'уважение',
#   'джеймс',
#   'вантакже',
#   'ван',
#   'заявил',
#   'предосудительного',
#   'любить',
#   'фильм',
#   'вместе',
#   'режиссёр',
#   'попросил',
#   'переходить',
#   'личности',
#   'изза',
#   'этогонапомним',
#   'джеймс',
#   'ван',
#   'решил',
#   'заниматься',
#   'продолжением',
#   'фильма',
#   'аквамен',
#   'режиссёр',
#   'ранее',
#   'заявлял',
#   'хочет',
#   'вернуться',
#   'масштабным',
#   'проектам'],
#  ['соболезнования',
#   'выразили',
#   'друзья',
#   'коллеги',
#   'актёра',
#   'режиссёры',
#   'анна',
#   'меликян',
#   'григорий',
#   'константинопольский',
#   'александр',
#   'атанасян',
#   'актриса',
#   'юлия',
#   'ауг',
#   'кинокритики',
#   'андрей',
#   'плахов',
#   'мария',
#   'кувшинова',
#   'другиеактёр',
#   'владимир',
#   'дыховичный',
#   'сын',
#   'режиссёра',
#   'ивана',
#   'дыховичного',
#   'скончался',
#   'возрасте',
#   'странице',
#   'фейсбуке',
#   'сообщила',
#   'вдова',
#   'режиссёра',
#   'ольга',
#   'rip',
#   'написала',
#   'прикрепив',
#   'публикации',
#   'фотографию',
#   'владимирапричины',
#   'смерти',
#   'уточняются',
#   'записью',
#   'соболезнования',
#   'оставляют',
#   'друзья',
#   'коллеги',
#   'дыховичного',
#   'среди',
#   'режиссёры',
#   'анна',
#   'меликян',
#   'григорий',
#   'константинопольский',
#   'александр',
#   'атанасян',
#   'актриса',
#   'юлия',
#   'ауг',
#   'кинокритики',
#   'андрей',
#   'плахов',
#   'мария',
#   'кувшинова',
#   'другиедыховичный',
#   'родился',
#   'апреля',
#   'окончил',
#   'вгик',
#   'мастерскую',
#   'народного',
#   'артиста',
#   'рф',
#   'сергея',
#   'соловьёва',
#   'известен',
#   'ролям',
#   'таких',
#   'фильмах',
#   'невидимки',
#   'сергея',
#   'комарова',
#   'лето',
#   'кирилла',
#   'серебренникова',
#   'сериала',
#   'бессоница'],
#  ['популярный',
#   'американский',
#   'актёр',
#   'появится',
#   'экране',
#   'роли',
#   'капитана',
#   'пиратов',
#   'джека',
#   'воробьякомпания',
#   'walt',
#   'disney',
#   'сэкономила',
#   'порядка',
#   'долларов',
#   'благодаря',
#   'решила',
#   'приглашать',
#   'популярного',
#   'голливудского',
#   'актёра',
#   'джонни',
#   'деппа',
#   'сниматься',
#   'новой',
#   'части',
#   'фильма',
#   'пираты',
#   'карибского',
#   'моря',
#   'сообщил',
#   'американский',
#   'журнал',
#   'forbesв',
#   'настоящий',
#   'момент',
#   'информации',
#   'должен',
#   'заменить',
#   'экране',
#   'капитана',
#   'джека',
#   'воробья',
#   'специалисты',
#   'считают',
#   'либо',
#   'студия',
#   'рассматривала',
#   'претендентов',
#   'либо',
#   'другого',
#   'персонажа',
#   'вовсе',
#   'будеттакже',
#   'следует',
#   'добавить',
#   'увольнение',
#   'актёра',
#   'деппа',
#   'серии',
#   'принести',
#   'убытки',
#   'кинокомпании',
#   'дело',
#   'несмотря',
#   'многие',
#   'личные',
#   'проблемы',
#   'актёра',
#   'последние',
#   'годы',
#   'остаётся',
#   'талантливым',
#   'вместе',
#   'специалисты',
#   'считают',
#   'представить',
#   'пиратский',
#   'фильм',
#   'деппа',
#   'достаточно',
#   'сложно'],
#  ['сериал',
#   'зомби',
#   'вышел',
#   'лидер',
#   'связи',
#   'отсутствием',
#   'новых',
#   'эпизодов',
#   'популярного',
#   'шоу',
#   'игра',
#   'престоловиздание',
#   'torrentfreaks',
#   'опубликовало',
#   'ежегодный',
#   'итоговый',
#   'топ',
#   'сериалов',
#   'скачивают',
#   'интернете',
#   'рейтинг',
#   'основан',
#   'данных',
#   'загрузках',
#   'сервис',
#   'bittorrentлидером',
#   'сериал',
#   'ходячие',
#   'мертвецы',
#   'шоу',
#   'протяжении',
#   'последних',
#   'шести',
#   'занимало',
#   'второе',
#   'место',
#   'уступая',
#   'игре',
#   'престолов',
#   'популярность',
#   'сериала',
#   'hbo',
#   'среди',
#   'пиратов',
#   'снизилась',
#   'телеканал',
#   'выпустил',
#   'новый',
#   'сезон',
#   'связи',
#   'сериал',
#   'попал',
#   'первую',
#   'десяткусреди',
#   'лидеров',
#   'помимо',
#   'ходячих',
#   'оказались',
#   'сериалы',
#   'флэш',
#   'теория',
#   'большого',
#   'взрыва',
#   'идут',
#   'викинги',
#   'титаны',
#   'стрела',
#   'сверхъестественное',
#   'мир',
#   'дикого',
#   'запада',
#   'легенды',
#   'завтрашнего',
#   'дня',
#   'форсмажоры'],
#  ['таким',
#   'образом',
#   'популярная',
#   'американская',
#   'актриса',
#   'решила',
#   'прокомментировать',
#   'популярность',
#   'deepfakeгазета',
#   'the',
#   'washington',
#   'post',
#   'опубликовала',
#   'материал',
#   'росте',
#   'популярности',
#   'deepfake',
#   'видео',
#   'лица',
#   'знаменитостей',
#   'помощью',
#   'нейросетей',
#   'переносят',
#   'видео',
#   'другими',
#   'актёрами',
#   'числе',
#   'порнографическиеодной',
#   'жертв',
#   'опубликованном',
#   'материале',
#   'выступила',
#   'актриса',
#   'скарлетт',
#   'йоханссон',
#   'видео',
#   'набирают',
#   'миллионы',
#   'просмотров',
#   'словам',
#   'звезды',
#   'фильма',
#   'мстители',
#   'вести',
#   'борьбу',
#   'данным',
#   'явлением',
#   'смысла',
#   'считает',
#   'принципе',
#   'невозможноэто',
#   'влияет',
#   'сильно',
#   'предполагают',
#   'всётаки',
#   'порно',
#   'думаю',
#   'преследовать',
#   'закону',
#   'бессмысленно',
#   'интернет',
#   'гигантская',
#   'тёмная',
#   'кротовая',
#   'нора',
#   'пожирает',
#   'скарлетт',
#   'йоханссонактриса',
#   'добавила',
#   'защищать',
#   'фотографии',
#   'авторским',
#   'правом',
#   'означать',
#   'стране',
#   'правило',
#   'распространяться',
#   'сша',
#   'йоханссон',
#   'считает',
#   'попытки',
#   'защититься',
#   'интернета',
#   'развращённости',
#   'являются',
#   'заведомо',
#   'проигранной',
#   'битвой'],
#  ['сравнению',
#   'результатом',
#   'продемонстрирован',
#   'прошлом',
#   'сумма',
#   'увеличилась',
#   'суммарные',
#   'сборы',
#   'кинотеатров',
#   'российской',
#   'федерации',
#   'стран',
#   'снг',
#   'января',
#   'увеличились',
#   'сравнению',
#   'показателем',
#   'прошлого',
#   'кинотеатры',
#   'получили',
#   'рублей',
#   'рублейэтот',
#   'показатель',
#   'рекордным',
#   'российских',
#   'кинотеатров',
#   'предыдущий',
#   'самый',
#   'большой',
#   'показатель',
#   'составлял',
#   'миллиона',
#   'рублей',
#   'зафиксирована',
#   'сумма',
#   'января',
#   'годасогласно',
#   'предварительной',
#   'информации',
#   'лидером',
#   'проката',
#   'стала',
#   'военная',
#   'драма',
#   'фильм',
#   'заработал',
#   'рублей',
#   'января',
#   'втором',
#   'месте',
#   'идёт',
#   'фильм',
#   'полицейский',
#   'рублёвки',
#   'новогодний',
#   'беспредел',
#   'следом',
#   'комедия',
#   'ёлки',
#   'последние'],
#  ['произошло',
#   'изза',
#   'команда',
#   'работала',
#   'интерактивным',
#   'эпизодом',
#   'шоу',
#   'премьера',
#   'продолжения',
#   'запланирована',
#   'годсоздатель',
#   'чёрного',
#   'зеркала',
#   'чарли',
#   'брукер',
#   'рассказал',
#   'создание',
#   'интерактивного',
#   'эпизода',
#   'bandersnatch',
#   'ощущалось',
#   'работа',
#   'четырьмя',
#   'сериями',
#   'шоу',
#   'одновременно',
#   'команда',
#   'осознавала',
#   'поставлена',
#   'непростая',
#   'задача',
#   'равно',
#   'недооценила',
#   'сообщает',
#   'thrодна',
#   'проблем',
#   'заключалась',
#   'чарли',
#   'брукер',
#   'начал',
#   'писать',
#   'сценарий',
#   'интерактивного',
#   'эпизода',
#   'месяцев',
#   'распоряжении',
#   'netflix',
#   'появился',
#   'необходимый',
#   'инструмент',
#   'реализации',
#   'разветвлённого',
#   'повествования',
#   'сюжетной',
#   'линии',
#   'механизм',
#   'получил',
#   'название',
#   'branch',
#   'manager',
#   'использовать',
#   'онлайнкинотеатры',
#   'интерактивных',
#   'проектахв',
#   'настоящий',
#   'момент',
#   'какихлибо',
#   'подробностей',
#   'относительно',
#   'пятого',
#   'сезона',
#   'чёрного',
#   'зеркала',
#   'чарли',
#   'брукер',
#   'вёл',
#   'работу',
#   'эпизодами',
#   'пятого',
#   'сезона',
#   'bandersnatch',
#   'параллельно',
#   'интерактивный',
#   'эпизод',
#   'никак',
#   'связан',
#   'будущими',
#   'эпизодами'],
#  ['одним',
#   'последних',
#   'творцов',
#   'золотого',
#   'века',
#   'кинокомпании',
#   'disney',
#   'сотрудничал',
#   'непосредственно',
#   'уолтом',
#   'диснеемв',
#   'возрасте',
#   'умер',
#   'американский',
#   'художниканиматор',
#   'дон',
#   'ласк',
#   'произошло',
#   'декабря',
#   'информация',
#   'поступила',
#   'исследовательской',
#   'библиотеки',
#   'disney',
#   'animationласк',
#   'одним',
#   'последних',
#   'творцов',
#   'золотого',
#   'века',
#   'disney',
#   'сотрудничал',
#   'непосредственно',
#   'уолтом',
#   'диснеем',
#   'ласк',
#   'присоединился',
#   'компании',
#   'работал',
#   'следующими',
#   'фильмами',
#   'белоснежка',
#   'гномов',
#   'пиноккио',
#   'бэмбиласк',
#   'покинул',
#   'компанию',
#   'работал',
#   'тв',
#   'частности',
#   'принимал',
#   'участие',
#   'создании',
#   'мультсериалов',
#   'смурфики',
#   'джерри',
#   'семейка',
#   'адамс',
#   'проектов'],
#  ['словам',
#   'авторов',
#   'шоу',
#   'бандерснэтч',
#   'считать',
#   'рождественским',
#   'специальным',
#   'эпизодом',
#   'белое',
#   'рождество',
#   'годуодин',
#   'авторов',
#   'сериала',
#   'чёрное',
#   'зеркало',
#   'аннабель',
#   'джонс',
#   'рассказала',
#   'бандерснэтч',
#   'специальный',
#   'рождественский',
#   'эпизод',
#   'шоу',
#   'потребовал',
#   'команды',
#   'огромных',
#   'усилий',
#   'связи',
#   'выход',
#   'го',
#   'сезона',
#   'задерживается',
#   'сообщает',
#   'thrпродолжение',
#   'популярного',
#   'шоу',
#   'выйдет',
#   'авторы',
#   'сериала',
#   'чёрное',
#   'зеркало',
#   'уточняют',
#   'дату',
#   'премьеры',
#   'новых',
#   'эпизодоввместе',
#   'стало',
#   'известно',
#   'пятом',
#   'сезоне',
#   'зрителей',
#   'ждёт',
#   'оптимистичных',
#   'серий',
#   'авторы',
#   'шоу',
#   'решили',
#   'отойти',
#   'негативных',
#   'антиутопичных',
#   'историй',
#   'появилась',
#   'информация',
#   'количество',
#   'эпизодов',
#   'будущем',
#   'сезоне',
#   'снижено'],
#  ['словам',
#   'режиссёра',
#   'специального',
#   'эпизода',
#   'нём',
#   'пасхалки',
#   'возможно',
#   'никто',
#   'найдётрежиссёр',
#   'дэвид',
#   'слэйд',
#   'заявил',
#   'нескольких',
#   'концовок',
#   'разветвлений',
#   'сюжета',
#   'бандерснэтче',
#   'золотые',
#   'яйца',
#   'словам',
#   'трудно',
#   'обнаружить',
#   'поэтому',
#   'возможно',
#   'никто',
#   'узнает',
#   'сообщает',
#   'thrво',
#   'проведения',
#   'предварительных',
#   'показов',
#   'журналистов',
#   'проходили',
#   'штабквартире',
#   'netflix',
#   'режиссёр',
#   'шутку',
#   'заявил',
#   'фильме',
#   'сцена',
#   'спрятана',
#   'знает',
#   'добраться',
#   'словам',
#   'слэйда',
#   'авторы',
#   'шоу',
#   'убедились',
#   'устраиваетнапомним',
#   'бандерснэтч',
#   'является',
#   'первым',
#   'интерактивным',
#   'фильмом',
#   'netflix',
#   'фильм',
#   'вселенной',
#   'чёрного',
#   'зеркала',
#   'полный',
#   'хронометраж',
#   'фильма',
#   'составляет',
#   'пяти',
#   'часов',
#   'связано',
#   'фильма',
#   'концовок',
#   'множество',
#   'разветвлений',
#   'сюжета'],
#  ['исполнитель',
#   'роли',
#   'рона',
#   'уизли',
#   'популярной',
#   'серии',
#   'кинолент',
#   'признался',
#   'нравятся',
#   'новые',
#   'частиактёр',
#   'руперт',
#   'гринт',
#   'заявил',
#   'смотреть',
#   'роли',
#   'рона',
#   'уизли',
#   'третьей',
#   'части',
#   'фильмов',
#   'гарри',
#   'поттер',
#   'сообщает',
#   'издание',
#   'the',
#   'sunгринт',
#   'рассказал',
#   'смотрел',
#   'первую',
#   'часть',
#   'серии',
#   'артисту',
#   'приятно',
#   'оглянуться',
#   'новым',
#   'фильмам',
#   'обращатьсяя',
#   'пытаюсь',
#   'вспомнить',
#   'сыграл',
#   'рона',
#   'уизли',
#   'потерял',
#   'руперт',
#   'гринтпо',
#   'словам',
#   'руперта',
#   'гринта',
# ...
#  ['популярный',
#   'футболист',
#   'заявлял',
#   'планирует',
#   'вернуться',
#   'сборную',
#   'португалиинападающий',
#   'футбольного',
#   'клуба',
#   'ювентус',
#   'сборной',
#   'португалии',
#   'криштиану',
#   'роналду',
#   'поставил',
#   'рекорд',
#   'числу',
#   'подписчиков',
#   'социальной',
#   'сети',
#   'инстаграм',
#   'настоящий',
#   'момент',
#   'спортсменом',
#   'следит',
#   'человекследом',
#   'роналду',
#   'идёт',
#   'американская',
#   'поппевица',
#   'селена',
#   'гомес',
#   'счету',
#   'звезды',
#   'эстрады',
#   'миллиона',
#   'подписчиков',
#   'сравнения',
#   'телезвезды',
#   'ким',
#   'кардашьян',
#   'настоящий',
#   'момент',
#   'миллиона',
#   'подписчиков',
#   'инстаграметакже',
#   'среди',
#   'спортсменов',
#   'футболисты',
#   'похвастаться',
#   'большим',
#   'количеством',
#   'подписчиков',
#   'социальной',
#   'сети',
#   'например',
#   'нападающего',
#   'сборной',
#   'бразилии',
#   'неймара',
#   'настоящий',
#   'момент',
#   'подписчиков',
#   'третьем',
#   'месте',
#   'находится',
#   'нападающий',
#   'барселоны',
#   'лионель',
#   'месси',
#   'подписчиков',
#   'инстаграме'],
#  ['брендом',
#   'mi',
#   'выходить',
#   'гаджеты',
#   'премиумкласса',
#   'redmi',
#   'бюджетные',
#   'смартфонылинейка',
#   'смартфонов',
#   'redmi',
#   'принадлежит',
#   'китайской',
#   'фирме',
#   'xiaomi',
#   'станет',
#   'отдельным',
#   'брендом',
#   'сообщает',
#   'издание',
#   'gizmochinaгенеральный',
#   'директор',
#   'японской',
#   'компании',
#   'лэй',
#   'цзюнь',
#   'заявил',
#   'xiaomi',
#   'хочет',
#   'разделить',
#   'выпускаемые',
#   'смартфоны',
#   'бренда',
#   'таким',
#   'образом',
#   'именем',
#   'mi',
#   'выходить',
#   'гаджеты',
#   'премиумкласса',
#   'брендом',
#   'redmi',
#   'увидим',
#   'бюджетные',
#   'смартфоныпомимо',
#   'прочего',
#   'бренды',
#   'отличаться',
#   'подходами',
#   'продажам',
#   'частности',
#   'redmi',
#   'компания',
#   'планирует',
#   'сделать',
#   'акцент',
#   'каналы',
#   'электронной',
#   'коммерции',
#   'подобной',
#   'стратегии',
#   'настоящий',
#   'момент',
#   'придерживается',
#   'китайская',
#   'фирма',
#   'huawei',
#   'выпускает',
#   'бюджетные',
#   'смартфоны',
#   'брендом',
#   'honor'],
#  ['популярный',
#   'китайский',
#   'бренд',
#   'готовит',
#   'гибкое',
#   'мобильное',
#   'устройство',
#   'особенность',
#   'складывается',
#   'сторонинсайдер',
#   'эван',
#   'бласс',
#   'странице',
#   'твиттереопубликовал',
#   'видео',
#   'первым',
#   'складным',
#   'смартфоном',
#   'xiaomicant',
#   'speak',
#   'to',
#   'the',
#   'authenticity',
#   'of',
#   'this',
#   'video',
#   'or',
#   'device',
#   'but',
#   'its',
#   'allegedly',
#   'made',
#   'by',
#   'xiaomi',
#   'im',
#   'told',
#   'hot',
#   'new',
#   'phone',
#   'or',
#   'gadget',
#   'porn',
#   'deepfake',
#   'pictwittercomqwfogwief',
#   'evan',
#   'blass',
#   'evleaks',
#   'января',
#   'гв',
#   'ролике',
#   'показано',
#   'меняется',
#   'интерфейс',
#   'устройство',
#   'разложено',
#   'сложено',
#   'первом',
#   'случае',
#   'смартфон',
#   'отображает',
#   'интерфейс',
#   'планшет',
#   'втором',
#   'обычный',
#   'смартфон',
#   'ранее',
#   'google',
#   'анонсировала',
#   'такую',
#   'оптимизацию',
#   'android',
#   'складные',
#   'смартфоныособенность',
#   'аппарата',
#   'складывается',
#   'сторон',
#   'книжка',
#   'название',
#   'характеристики',
#   'девайса',
#   'неизвестны',
#   'ранее',
#   'складном',
#   'устройстве',
#   'xiaomi',
#   'сообщалось',
#   'известно',
#   'смартфоны',
#   'готовят',
#   'samsung',
#   'huawei',
#   'lgsamsung',
#   'показала',
#   'складной',
#   'дисплей',
#   'infinity',
#   'flex',
#   'прототип',
#   'гибкого',
#   'мобильного',
#   'устройства',
#   'производитель',
#   'позиционирует',
#   'планшетом',
#   'положить',
#   'карман'],
#  ['исследователи',
#   'выяснили',
#   'срубленных',
#   'праздник',
#   'деревьев',
#   'извлечь',
#   'пользуучёные',
#   'шеффилдского',
#   'университета',
#   'предложили',
#   'утилизировать',
#   'срубленные',
#   'новый',
#   'ёлкиисследователи',
#   'нашли',
#   'хвое',
#   'деревьев',
#   'вещества',
#   'помогут',
#   'производстве',
#   'краски',
#   'уксуса',
#   'сладостей',
#   'отметим',
#   'срубленные',
#   'ёлки',
#   'выбрасываются',
#   'предоставленным',
#   'данным',
#   'великобритании',
#   'новый',
#   'срубается',
#   'семи',
#   'ёлокпутём',
#   'подогрева',
#   'хвою',
#   'разделить',
#   'твёрдые',
#   'жидкие',
#   'вещества',
#   'жидких',
#   'создавать',
#   'сахара',
#   'утверждают',
#   'исследователи',
#   'твёрдые',
#   'использовать',
#   'производства',
#   'биоугля'],
#  ['журналисты',
#   'обнаружили',
#   'посещения',
#   'сайта',
#   'устройств',
#   'новой',
#   'операционной',
#   'системе',
#   'appleapple',
#   'занимается',
#   'разработкой',
#   'ios',
#   'сообщило',
#   'издание',
#   'macrumorsресурс',
#   'представил',
#   'статистику',
#   'посещений',
#   'выяснилось',
#   'сайт',
#   'заходили',
#   'ios',
#   'визит',
#   'сделан',
#   'октябре',
#   'ресурс',
#   'посещали',
#   'таких',
#   'устройств',
#   'ноябре',
#   'концу',
#   'декабря',
#   'показатель',
#   'упалточной',
#   'информации',
#   'нововведениях',
#   'следующей',
#   'операционной',
#   'системе',
#   'ожидается',
#   'разработчики',
#   'первую',
#   'очередь',
#   'усовершенствуют',
#   'ipad',
#   'примеру',
#   'переделают',
#   'приложение',
#   'файлов',
#   'добавят',
#   'возможность',
#   'открывать',
#   'сразу',
#   'окон',
#   'приложения',
#   'режиме',
#   'многозадачностиверсия',
#   'ios',
#   'вышла',
#   'сентября',
#   'производитель',
#   'внимания',
#   'уделил',
#   'удобности',
#   'пользования',
#   'одно',
#   'нововведений',
#   'возможность',
#   'контролировать',
#   'отведённое',
#   'мобильное',
#   'устройство'],
#  ['полученной',
#   'информации',
#   'производитель',
#   'электрокаров',
#   'договаривается',
#   'евросоюзом',
#   'получении',
#   'необходимых',
#   'лицензийtesla',
#   'планирует',
#   'начать',
#   'продажи',
#   'model',
#   'европе',
#   'первом',
#   'квартале',
#   'сообщает',
#   'bloomberg',
#   'ссылкой',
#   'источник',
#   'пожелавший',
#   'остаться',
#   'неизвестнымкомпания',
#   'надеется',
#   'получить',
#   'лицензию',
#   'евросоюза',
#   'продажу',
#   'электромобиля',
#   'ожидается',
#   'сделка',
#   'завершена',
#   'ближайшее',
#   'важных',
#   'сотрудников',
#   'автоконцерна',
#   'выйдут',
#   'отпуска',
#   'доведут',
#   'дело',
#   'концаранее',
#   'владелец',
#   'компании',
#   'илон',
#   'маск',
#   'сообщал',
#   'планах',
#   'начать',
#   'продажи',
#   'европе',
#   'китае',
#   'приоритетная',
#   'задача',
#   'предприниматель',
#   'беспокоиться',
#   'насчёт',
#   'налогов',
#   'сшаранее',
#   'model',
#   'поставил',
#   'рекорд',
#   'гоночном',
#   'треке',
#   'электрокар',
#   'вторым',
#   'laguna',
#   'seca',
#   'показав',
#   'результат',
#   'мин',
#   'сек',
#   'секунды',
#   'быстрее',
#   'заезд',
#   'tesla',
#   'model',
#   's',
#   'pd'],
#  ['компания',
#   'ожидает',
#   'прибыль',
#   'ожидаемого',
#   'сообщает',
#   'слабых',
#   'продажах',
#   'смартфонов',
#   'прямо',
#   'повлияло',
#   'стоимость',
#   'биржеакции',
#   'apple',
#   'упали',
#   'открытии',
#   'торгов',
#   'сообщает',
#   'bloomberg',
#   'причиной',
#   'стало',
#   'ухудшение',
#   'прогноза',
#   'выручке',
#   'изза',
#   'снижения',
#   'спроса',
#   'продукцию',
#   'компанииранее',
#   'тим',
#   'кук',
#   'разослал',
#   'письма',
#   'инвесторам',
#   'предупредил',
#   'снижении',
#   'прибыли',
#   'изза',
#   'неудовлетворительных',
#   'показателей',
#   'продаж',
#   'apple',
#   'скорректировала',
#   'ожидаемый',
#   'доход',
#   'квартал',
#   'миллиардов',
#   'долларов',
#   'миллиардовглавной',
#   'причиной',
#   'снижения',
#   'доходов',
#   'топменеджер',
#   'apple',
#   'назвал',
#   'торговую',
#   'войну',
#   'китаем',
#   'отметил',
#   'нежелание',
#   'пользователей',
#   'обновлять',
#   'смартфон',
#   'выбор',
#   'замены',
#   'аккумулятора',
#   'напомним',
#   'процедура',
#   'устраняет',
#   'баги'],
#  ['ранее',
#   'чипмейкер',
#   'выиграл',
#   'компании',
#   'купертино',
#   'дело',
#   'нарушении',
#   'патентных',
#   'прав',
#   'германиипроизводитель',
#   'процессоров',
#   'смартфонов',
#   'qualcomm',
#   'внёс',
#   'обеспечительный',
#   'платёж',
#   'размере',
#   'миллиарда',
#   'евро',
#   'вступления',
#   'силу',
#   'запрета',
#   'продажи',
#   'iphone',
#   'x',
#   'германии',
#   'сообщается',
#   'прессрелизе',
#   'компании',
#   'официальном',
#   'сайтеранее',
#   'apple',
#   'проиграла',
#   'суд',
#   'чипмейкером',
#   'стране',
#   'суд',
#   'признал',
#   'производителя',
#   'смартфонов',
#   'виновным',
#   'нарушении',
#   'патента',
#   'qualcomm',
#   'принял',
#   'решение',
#   'запретить',
#   'продажи',
#   'некоторых',
#   'моделей',
#   'территории',
#   'странысообщается',
#   'купертино',
#   'нарушили',
#   'патента',
#   'чипмейкера',
#   'связан',
#   'возможностью',
#   'редактирования',
#   'фото',
#   'управлением',
#   'приложениями',
#   'помощью',
#   'сенсоров',
#   'экранав',
#   'купертино',
#   'признают',
#   'вину',
#   'намерены',
#   'подать',
#   'апелляцию',
#   'компания',
#   'согласилась',
#   'прекратить',
#   'продажи',
#   'указанных',
#   'моделей',
#   'официальных',
#   'магазинах',
#   'германиипатентное',
#   'разбирательство',
#   'apple',
#   'qualcomm',
#   'главных',
#   'скандалов',
#   'ранее',
#   'лайф',
#   'вспомнил',
#   'самых',
#   'важных',
#   'конфликтов',
#   'индустрии',
#   'технологий',
#   'минувшем'],
#  ['эксперты',
#   'усомнились',
#   'снижение',
#   'спроса',
#   'iphone',
#   'вызвано',
#   'торговой',
#   'войной',
#   'конкуренты',
#   'китая',
#   'стали',
#   'привлекательнымианалитики',
#   'назвали',
#   'причины',
#   'падения',
#   'акций',
#   'apple',
#   'сообщает',
#   'bbc',
#   'напомним',
#   'цена',
#   'компании',
#   'бирже',
#   'обвалилась',
#   'открытии',
#   'торговв',
#   'первую',
#   'очередь',
#   'эксперты',
#   'усомнились',
#   'причинах',
#   'снижения',
#   'акций',
#   'ранее',
#   'генеральный',
#   'директор',
#   'компании',
#   'тим',
#   'кук',
#   'послужили',
#   'торговая',
#   'война',
#   'нежелание',
#   'пользователей',
#   'обновляться',
#   'старых',
#   'моделей',
#   'связывал',
#   'проблемами',
#   'американской',
#   'китайской',
#   'экономик',
#   'торговой',
#   'войной',
#   'apple',
#   'настали',
#   'новые',
#   'времена',
#   'аналитик',
#   'сектора',
#   'высоких',
#   'технологий',
#   'сэм',
#   'рейнольдснапряжённые',
#   'отношения',
#   'сша',
#   'китаем',
#   'обострили',
#   'ситуацию',
#   'главной',
#   'причиной',
#   'снижения',
#   'спроса',
#   'стало',
#   'развитие',
#   'китайских',
#   'производителей',
#   'смартфонов',
#   'oppo',
#   'xiaomi',
#   'huawei',
#   'главное',
#   'преимущество',
#   'устройств',
#   'идеальное',
#   'соотношение',
#   'цены',
#   'качествапо',
#   'словам',
#   'собеседников',
#   'bbc',
#   'падение',
#   'акций',
#   'связать',
#   'неудачной',
#   'ценовой',
#   'политикой',
#   'apple',
#   'смартфоны',
#   'стоят',
#   'дороже',
#   'прямых',
#   'конкурентов',
#   'являются',
#   'незначительно',
#   'улучшенными',
#   'вариантами',
#   'предшественников',
#   'предлагают',
#   'радикальных',
#   'инноваций',
#   'инвесторы',
#   'попробуют',
#   'понять',
#   'насколько',
#   'сильно',
#   'агрессивная',
#   'ценовая',
#   'политика',
#   'apple',
#   'усугубила',
#   'ситуацию',
#   'повлияет',
#   'долгосрочные',
#   'перспективы',
#   'компании',
#   'удерживать',
#   'высокие',
#   'цены',
#   'iphone',
#   'аналитик',
#   'atlantic',
#   'equities',
#   'джеймс',
#   'кордуэллсамый',
#   'дорогой',
#   'iphone',
#   'xs',
#   'max',
#   'минимальная',
#   'стоимость',
#   'россии',
#   'руб',
#   'указывается',
#   'сайте',
#   'apple',
#   'максимальная',
#   'цена',
#   'модификацию',
#   'гб'],
#  ['мнению',
#   'эксперта',
#   'следующий',
#   'смартфон',
#   'apple',
#   'удивит',
#   'новыми',
#   'возможностями',
#   'попрежнему',
#   'стоить',
#   'гораздо',
#   'дороже',
#   'androidконкурентованалитик',
#   'atherton',
#   'research',
#   'джин',
#   'баптист',
#   'надеется',
#   'iphone',
#   'получит',
#   'внутриэкранный',
#   'сканер',
#   'отпечатка',
#   'порт',
#   'usbc',
#   'быстрой',
#   'зарядкой',
#   'уменьшенную',
#   'чёлку',
#   'сообщил',
#   'forbesпо',
#   'данным',
#   'эксперта',
#   'дизайн',
#   'нового',
#   'смартфона',
#   'apple',
#   'создан',
#   'основе',
#   'iphone',
#   'x',
#   'изменения',
#   'отличие',
#   'серии',
#   'xs',
#   'отмечается',
#   'новый',
#   'смартфон',
#   'apple',
#   'дороже',
#   'конкурентов',
#   'androidнапомним',
#   'apple',
#   'отказалась',
#   'сканера',
#   'отпечатка',
#   'iphone',
#   'x',
#   'заменив',
#   'сканер',
#   'лица',
#   'face',
#   'id',
#   'внутриэкранный',
#   'датчик',
#   'стоит',
#   'некоторых',
#   'androidсмартфонах',
#   'отличается',
#   'надёжностью',
#   'оптический',
#   'сканер',
#   'ультразвуковой',
#   'представила',
#   'qualcomm',
#   'подобный',
#   'датчик',
#   'стоять',
#   'galaxy',
#   'sакции',
#   'apple',
#   'упали',
#   'бирже',
#   'слов',
#   'тима',
#   'кука',
#   'компания',
#   'получит',
#   'выручку',
#   'ожидаемого',
#   'первом',
#   'квартале',
#   'мнению',
#   'аналитиков',
#   'основная',
#   'причина',
#   'снижения',
#   'спроса',
#   'завышенные',
#   'цены',
#   'iphone',
#   'самый',
#   'дорогой',
#   'iphone',
#   'xs',
#   'max',
#   'минимальная',
#   'стоимость',
#   'россии',
#   'руб',
#   'указывается',
#   'сайте',
#   'apple',
#   'максимальная',
#   'цена',
#   'руб',
#   'модификацию',
#   'гб'],
#  ['windows', 'появятся', 'смайлики', 'иероглифов'],
#  ['мире', 'вебсайт', 'запустили'],
#  ['steam', 'перестанет', 'работать', 'старых', 'mac'],
#  ['появилось',
#   'пятно',
#   'пользователи',
#   'ipad',
#   'pro',
#   'жалуются',
#   'дефект',
#   'экрана'],
#  ['смартфоны',
#   'одежда',
#   'фастфуд',
#   'названы',
#   'любимых',
#   'брендов',
#   'россиян'],
#  ['обновление', 'пользовательского', 'соглашения'],
#  ['facebook', 'начал', 'делить', 'сми', 'фейковые', 'нефейковые'],
#  ['названо', 'какие', 'ipad', 'apple', 'выпустит'],
#  ['нормально',
#   'apple',
#   'прокомментировали',
#   'ситуацию',
#   'гнущимися',
#   'ipad',
#   'pro'],
#  ['xiaomi',
#   'представила',
#   'молодёжный',
#   'смартфон',
#   'c',
#   'градиентным',
#   'корпусом'],
#  ['google', 'стала', 'обжаловать', 'штраф', 'роскомнадзора'],
#  ['матвиенко', 'объяснила', 'необходимость', 'закона', 'суверенном', 'рунете'],
#  ['samsung', 'galaxy', 'note', 'получит', 'увеличенный', 'дисплей'],
#  ['хакеры',
#   'выводят',
#   'строя',
#   'компьютеры',
#   'windows',
#   'помощью',
#   'ошибки',
#   'chrome'],
#  ['яндекс', 'выяснил', 'покупают', 'россияне', 'новому'],
#  ['одноклассники', 'назвали', 'главные', 'события'],
#  ['fortnite', 'стала', 'обсуждаемой', 'игрой', 'twitter'],
#  ['цена', 'playstation', 'pro', 'рухнула', 'россии'],
#  ['названы',
#   'причины',
#   'выпуска',
#   'декабре',
#   'большинства',
#   'мобильных',
#   'игр'],
#  ['вконтакте', 'выплатила', 'млрд', 'рублей', 'разработчикам', 'игр'],
#  ['названы', 'самые', 'высокооплачиваемые', 'российские', 'youtubeблогеры'],
#  ['мстители',
#   'конечностей',
#   'названы',
#   'самые',
#   'смешные',
#   'запросы',
#   'яндексе'],
#  ['яндекс', 'удалил', 'telegram', 'поисковой', 'выдачи'],
#  ['эксперты',
#   'россияне',
#   'заинтересованы',
#   'iphone',
#   'покупают',
#   'китайские',
#   'смартфоны'],
#  ['ikea', 'выпустила', 'инструкцию', 'сборке', 'салата', 'оливье'],
#  ['смартфоны',
#   'планшеты',
#   'умные',
#   'часы',
#   'названы',
#   'лучшие',
#   'подарки',
#   'новый'],
#  ['москвичи', 'стали', 'заказывать', 'еду', 'дом'],
#  ['снег', 'замри', 'советов', 'сделать', 'снежный', 'фотошедевр'],
#  ['названы', 'самые', 'популярные', 'среди', 'интернетпиратов', 'фильмы'],
#  ['вконтакте', 'иван', 'ургант', 'переформатируют', 'клевер'],
#  ['запрет',
#   'iphone',
#   'утечка',
#   'данных',
#   'главные',
#   'скандалы',
#   'индустрии',
#   'технологий'],
#  ['путин', 'мстители', 'элджей', 'названы', 'главные', 'темы', 'вконтакте'],
#  ['nokia', 'пятью', 'камерами', 'появился', 'видео'],
#  ['huawei', 'представила', 'бюджетный', 'смартфон', 'сканера', 'отпечатка'],
#  ['неймар', 'променял', 'празднование', 'нового', 'игру', 'fortnite'],
#  ['whatsapp', 'перестанет', 'работать', 'некоторых', 'телефонах'],
#  ['цукерберг',
#   'продал',
#   'акции',
#   'facebook',
#   'лечить',
#   'эпилепсию',
#   'болезнь',
#   'паркинсона'],
#  ['обновление', 'пользовательского', 'соглашения'],
#  ['apple',
#   'предупредила',
#   'инвесторов',
#   'замедлении',
#   'темпов',
#   'продаж',
#   'iphone'],
#  ['steam', 'поддерживает', 'старые', 'версии', 'windows'],
#  ['роналду', 'рекордсменом', 'числу', 'подписчиков', 'instagram'],
#  ['смартфоны',
#   'redmi',
#   'компании',
#   'xiaomi',
#   'станут',
#   'отдельным',
#   'брендом'],
#  ['складной', 'xiaomi', 'появился', 'видео'],
#  ['учёные', 'нашли', 'способ', 'превращать', 'новогодние', 'ёлки', 'сладости'],
#  ['подтверждения', 'apple', 'занимается', 'разработкой', 'ios'],
#  ['tesla',
#   'готовится',
#   'начать',
#   'продажи',
#   'электромобиля',
#   'model',
#   'европе'],
#  ['акции',
#   'apple',
#   'упали',
#   'изза',
#   'провально',
#   'низких',
#   'продаж',
#   'iphone'],
#  ['qualcomm', 'заплатила', 'млрд', 'евро', 'запрет', 'продаж', 'iphone'],
#  ['настали',
#   'новые',
#   'времена',
#   'аналитики',
#   'назвали',
#   'причину',
#   'падения',
#   'акций',
#   'apple'],
#  ['touch',
#   'id',
#   'экране',
#   'usbc',
#   'аналитик',
#   'назвал',
#   'нововведения',
#   'iphone']]

# %%
perp = []

for category in data.columns.levels[0]:
    for key in data.columns.levels[1]:
        tmp = []
        for i, item in enumerate(data[category][key]):
            frequencies_empirical = {}

            for word in item:
                if frequencies_empirical.get(word, None) is None:
                    frequencies_empirical[word] = 1
                else:
                    frequencies_empirical[word] += 1
            perp.append(frequencies_empirical)

# %%
perp
# Out:
# [{'сети': 1,
#   'появилось': 1,
#   'великолепное': 1,
#   'видео': 2,
#   'которое': 1,
#   'позволит': 1,
#   'каждому': 1,
#   'зрителей': 1,
#   'поднять': 1,
#   'рождественское': 2,
#   'настроениепопулярный': 1,
#   'американский': 1,
#   'видеоблогер': 1,
#   'the': 1,
#   'angry': 1,
#   'video': 1,
#   'game': 1,
#   'nerd': 1,
#   'джеймс': 2,
#   'рольф': 3,
#   'записал': 1,
#   'рождественский': 1,
#   'й': 1,
#   'эпизод': 1,
#   'шоу': 1,
#   'компанию': 1,
#   'составил': 1,
#   'актёр': 2,
#   'маколей': 3,
#   'калкин': 3,
#   'известный': 1,
#   'ролям': 1,
#   'частях': 1,
#   'фильма': 1,
#   'домакалкин': 1,
#   'поиграли': 1,
#   'обсудили': 1,
#   'игровые': 1,
#   'адаптации': 1,
#   'фильмов': 1,
#   'дома': 2,
#   'остался': 1,
#   'доволен': 1,
#   'провёл': 1,
#   'блогером': 1,
#   'сюжету': 1,
#   'появился': 1,
#   'экране': 1,
#   'роли': 1,
#   'доставщика': 1,
#   'пиццы': 1,
#   'пришёл': 1,
#   'рольфу': 1,
#   'коробкой': 1,
#   'игр': 1,
#   'разных': 1,
#   'игровых': 1,
#   'консолей': 1,
#   'предложил': 1,
#   'сделать': 1,
#   'обзор': 1,
#   'ходу': 1,
#   'игры': 2,
#   'комментировали': 1,
#   'расхождения': 1,
#   'сюжетом': 1,
#   'отмечали': 1,
#   'достоинства': 1,
#   'недостатки': 1,
#   'той': 1,
#   'иной': 1,
#   'игрыв': 1,
#   'итоге': 1,
#   'блогеру': 1,
#   'удалось': 1,
#   'создать': 1,
#   'отличное': 1,
#   'вырос': 1,
#   'любит': 1,
#   'творчество': 1,
#   'калкина': 1},
#  {'×обновление': 1,
#   'пользовательского': 1,
#   'соглашениямы': 1,
#   'повышаем': 1,
#   'качество': 1,
#   'наших': 1,
#   'пользовательских': 1,
#   'служб': 2,
#   'поэтому': 1,
#   'обновляем': 1,
#   'соглашение': 2,
#   'использовании': 1,
#   'ооо': 1,
#   'медиа': 1,
#   'контент': 1,
#   'далее': 3,
#   'компания': 1,
#   'издателем': 1,
#   'сетевого': 1,
#   'издания': 1,
#   'телеканала': 1,
#   'liferu': 1,
#   'физическим': 1,
#   'лицом': 1,
#   'пользователь': 1,
#   'использованию': 1,
#   'сайта': 1,
#   'wwwliferu': 1,
#   'сайтознакомиться': 1,
#   'данными': 1,
#   'изменениями': 1,
#   'можете': 1,
#   'страницепользовательское': 1},
#  {'фанаты': 1,
#   'популярного': 1,
#   'актёра': 3,
#   'выбирает': 1,
#   'брутальные': 1,
#   'образы': 1,
#   'удивились': 1,
#   'такому': 1,
#   'поступкупопулярный': 1,
#   'американский': 1,
#   'актёр': 2,
#   'джейсон': 1,
#   'момоа': 3,
#   'появился': 1,
#   'публике': 1,
#   'достаточно': 1,
#   'необычной': 1,
#   'причёской': 1,
#   'школьницы': 2,
#   'длинные': 1,
#   'вьющиеся': 1,
#   'волосы': 1,
#   'решил': 2,
#   'связать': 1,
#   'розовыми': 1,
#   'резинками': 1,
#   'хвоста': 1,
#   'притом': 1,
#   'звезда': 1,
#   'аквамена': 1,
#   'отличается': 1,
#   'брутальным': 1,
#   'внешним': 1,
#   'видом': 1,
#   'подчёркивает': 1,
#   'творческое': 1,
#   'амплуасвой': 1,
#   'образ': 1,
#   'артист': 1,
#   'дополнить': 1,
#   'гавайским': 1,
#   'венком': 1,
#   'шее': 1,
#   'предмет': 1,
#   'знаком': 1,
#   'детства': 1,
#   'летний': 1,
#   'родился': 1,
#   'гонолулу': 1,
#   'гавайях': 1,
#   'таком': 2,
#   'образе': 2,
#   'пришёл': 1,
#   'шоу': 1,
#   'the': 1,
#   'project': 1,
#   'tvвыбор': 1,
#   'причёски': 1,
#   'непонятен': 1,
#   'фанатам': 1,
#   'отметил': 1,
#   'дети': 1,
#   'неплохо': 1,
#   'получается': 1,
#   'заплетать': 1,
#   'косички': 1,
#   'словам': 1,
#   'поклонников': 1,
#   'равно': 1,
#   'выглядел': 1,
#   'уверенно': 1,
#   'мужественно': 1},
#  {'проекта': 2,
#   'отказался': 2,
#   'шон': 2,
#   'леви': 2,
#   'ранее': 2,
#   'работал': 1,
#   'популярным': 1,
#   'сериалом': 2,
#   'странные': 2,
#   'деластудия': 1,
#   'sony': 2,
#   'ищет': 1,
#   'нового': 1,
#   'режиссёра': 1,
#   'экранизации': 1,
#   'игры': 2,
#   'uncharted': 2,
#   'пишет': 1,
#   'eurogamer': 1,
#   'кресло': 1,
#   'постановщика': 1,
#   'освободил': 1,
#   'работавший': 1,
#   'дела': 1,
#   'режиссёр': 1,
#   'планирует': 1,
#   'вместо': 1,
#   'снимать': 1,
#   'фильм': 2,
#   'свободный': 1,
#   'главную': 1,
#   'роль': 1,
#   'котором': 1,
#   'исполнит': 1,
#   'райан': 1,
#   'рейнольдскомпания': 1,
#   'пытается': 1,
#   'экранизировать': 1,
#   'разное': 1,
#   'проекту': 1,
#   'присматривались': 1,
#   'сет': 1,
#   'гордон': 1,
#   'нил': 1,
#   'бёргер': 1,
#   'джо': 1,
#   'карнахан': 1,
#   'экранизация': 1,
#   'вновь': 2,
#   'оказывается': 1,
#   'режиссёрасогласно': 1,
#   'слухам': 1,
#   'неизведанное': 1,
#   'удача': 1,
#   'дрейка': 2,
#   'должен': 1,
#   'стать': 1,
#   'приквелом': 1,
#   'рассказать': 1,
#   'первом': 1,
#   'приключении': 1,
#   'бесстрашного': 1,
#   'искателя': 1,
#   'сокровищ': 1,
#   'нейтана': 1,
#   'исполнителем': 1,
#   'главной': 1,
#   'роли': 1,
#   'значится': 1,
#   'холланд': 1,
#   'новый': 1,
#   'человекпаук': 1,
#   'настоящий': 1,
#   'момент': 1,
#   'сложно': 1,
#   'останется': 1,
#   'актёр': 1,
#   'картиной': 1},
#  {'новый': 1,
#   'комикс': 1,
#   'звёздным': 1,
#   'войнам': 1,
#   'darth': 1,
#   'vader': 1,
#   'no': 1,
#   'подтвердил': 1,
#   'давнюю': 1,
#   'фанатскую': 1,
#   'теорию': 1,
#   'происхождении': 1,
#   'энакина': 3,
#   'скайуокерасогласно': 1,
#   'сюжету': 1,
#   'ленты': 1,
#   'скрытая': 1,
#   'угроза': 1,
#   'шми': 1,
#   'мать': 1,
#   'родила': 1,
#   'мальчика': 1,
#   'чудесного': 1,
#   'непорочного': 1,
#   'зачатия': 2,
#   'квайгон': 1,
#   'считал': 1,
#   'произошло': 1,
#   'благодаря': 1,
#   'воле': 1,
#   'силы': 3,
#   'фанаты': 1,
#   'спекулировали': 1,
#   'чудо': 1,
#   'случайным': 1,
#   'ситуацию': 1,
#   'ктото': 2,
#   'подстроилиз': 1,
#   'нового': 1,
#   'комикса': 1,
#   'стало': 1,
#   'известно': 1,
#   'отец': 2,
#   'палпатин': 2,
#   'дарт': 2,
#   'сидиус': 1,
#   'будущий': 1,
#   'император': 1,
#   'манипулировал': 1,
#   'потоками': 1,
#   'создать': 1,
#   'могущественного': 1,
#   'тёмного': 1,
#   'джедая': 1,
#   'утробе': 1,
#   'шмисамо': 1,
#   'секса': 1,
#   'манипуляций': 1,
#   'сидиуса': 1,
#   'вполне': 1,
#   'достаточно': 1,
#   'считать': 1,
#   'палпатина': 1,
#   'отцом': 1,
#   'дарта': 1,
#   'вейдера': 1,
#   'сцену': 1,
#   'видит': 1,
#   'вейдер': 1,
#   'погружается': 1,
#   'медитацию': 1,
#   'наблюдает': 1,
#   'собственную': 1,
#   'возможно': 1,
#   'дальнейшем': 1,
#   'использовано': 1,
#   'сценаристами': 1,
#   'подано': 1,
#   'вейдеру': 1,
#   'внушил': 1},
#  {'×обновление': 1,
#   'пользовательского': 1,
#   'соглашениямы': 1,
#   'повышаем': 1,
#   'качество': 1,
#   'наших': 1,
#   'пользовательских': 1,
#   'служб': 2,
#   'поэтому': 1,
#   'обновляем': 1,
#   'соглашение': 2,
#   'использовании': 1,
#   'ооо': 1,
#   'медиа': 1,
#   'контент': 1,
#   'далее': 3,
#   'компания': 1,
#   'издателем': 1,
#   'сетевого': 1,
#   'издания': 1,
#   'телеканала': 1,
#   'liferu': 1,
#   'физическим': 1,
#   'лицом': 1,
#   'пользователь': 1,
#   'использованию': 1,
#   'сайта': 1,
#   'wwwliferu': 1,
#   'сайтознакомиться': 1,
#   'данными': 1,
#   'изменениями': 1,
#   'можете': 1,
#   'страницепользовательское': 1},
#  {'×обновление': 1,
#   'пользовательского': 1,
#   'соглашениямы': 1,
#   'повышаем': 1,
#   'качество': 1,
#   'наших': 1,
#   'пользовательских': 1,
#   'служб': 2,
#   'поэтому': 1,
#   'обновляем': 1,
#   'соглашение': 2,
#   'использовании': 1,
#   'ооо': 1,
#   'медиа': 1,
#   'контент': 1,
#   'далее': 3,
#   'компания': 1,
#   'издателем': 1,
#   'сетевого': 1,
#   'издания': 1,
#   'телеканала': 1,
#   'liferu': 1,
#   'физическим': 1,
#   'лицом': 1,
#   'пользователь': 1,
#   'использованию': 1,
#   'сайта': 1,
#   'wwwliferu': 1,
#   'сайтознакомиться': 1,
#   'данными': 1,
#   'изменениями': 1,
#   'можете': 1,
#   'страницепользовательское': 1},
#  {'сценарий': 1,
#   'новому': 1,
#   'фильму': 1,
#   'должны': 1,
#   'написать': 1,
#   'комики': 1,
#   'шоу': 1,
#   'субботним': 2,
#   'вечером': 2,
#   'прямом': 2,
#   'эфире': 2,
#   'майки': 2,
#   'дэй': 2,
#   'стритер': 2,
#   'сейделстудии': 1,
#   'disney': 1,
#   'fox': 1,
#   'планируют': 1,
#   'вернуть': 1,
#   'экраны': 1,
#   'комедию': 1,
#   'дома': 1,
#   'настоящий': 2,
#   'момент': 2,
#   'проект': 1,
#   'находится': 1,
#   'огромном': 1,
#   'приоритете': 1,
#   'компаний': 1,
#   'сообщает': 1,
#   'splashreportнад': 1,
#   'сценарием': 1,
#   'фильма': 1,
#   'работают': 1,
#   'сейдел': 1,
#   'музыкальноюмористическая': 1,
#   'передача': 1,
#   'касается': 1,
#   'режиссёра': 1,
#   'студии': 1,
#   'занимаются': 1,
#   'поисками': 1,
#   'человекапо': 1,
#   'словам': 1,
#   'источника': 1,
#   'передал': 1,
#   'информацию': 1,
#   'журналистам': 1,
#   'зрителей': 1,
#   'ждёт': 1,
#   'ремейк': 1,
#   'прямое': 1,
#   'продолжение': 1,
#   'серии': 1,
#   'новыми': 1,
#   'героями': 1,
#   'аналогичная': 1,
#   'ситуация': 1,
#   'произошла': 1,
#   'фильмом': 1,
#   'джуманджи': 1},
#  {'кинокритики': 1,
#   'журнала': 1,
#   'the': 2,
#   'hollywood': 2,
#   'reporter': 2,
#   'выбрали': 1,
#   'худших': 2,
#   'фильмов': 3,
#   'уходящего': 1,
#   'годана': 1,
#   'первом': 1,
#   'месте': 2,
#   'антирейтинга': 1,
#   'оказалась': 1,
#   'криминальная': 1,
#   'драма': 1,
#   'названием': 1,
#   'кодекс': 1,
#   'готти': 1,
#   'режиссёр': 1,
#   'кевин': 1,
#   'коннолли': 1,
#   'ленте': 1,
#   'главного': 1,
#   'американского': 1,
#   'мафиози': 1,
#   'сыграл': 1,
#   'джон': 1,
#   'траволта': 1,
#   'сайте': 1,
#   'rotten': 1,
#   'tomatoes': 1,
#   'агрегирующем': 1,
#   'отзывы': 1,
#   'рецензии': 1,
#   'картина': 1,
#   'получила': 1,
#   'рейтинг': 1,
#   'процентовна': 1,
#   'втором': 1,
#   'списка': 1,
#   'самых': 1,
#   'провальных': 1,
#   'оказался': 1,
#   'боевик': 1,
#   'робин': 1,
#   'гуд': 1,
#   'начало': 1,
#   'снятый': 1,
#   'отто': 1,
#   'батхёрстом': 1,
#   'главный': 1,
#   'кинокритик': 1,
#   'тодд': 1,
#   'маккарти': 1,
#   'заявил': 1,
#   'вовлечён': 1,
#   'работу': 1,
#   'фильмом': 1,
#   'должен': 1,
#   'совершить': 1,
#   'публичное': 1,
#   'покаяние': 1,
#   'замыкает': 1,
#   'тройку': 1,
#   'фильм': 1,
#   'пятьдесят': 1,
#   'оттенков': 1,
#   'свободы': 1,
#   'джеймса': 1,
#   'фолитакже': 1,
#   'десятку': 1,
#   'вошли': 1,
#   'веном': 1,
#   'щелкунчик': 1,
#   'королевства': 1,
#   'лосанджелес': 1,
#   'огне': 1,
#   'операция': 1,
#   'шаровая': 1,
#   'молния': 1,
#   'излом': 1,
#   'суспирия': 1},
#  {'северной': 1,
#   'америке': 1,
#   'фантастический': 1,
#   'боевик': 1,
#   'вышел': 1,
#   'российской': 1,
#   'федерации': 1,
#   'китаефильм': 1,
#   'аквамен': 2,
#   'завершил': 1,
#   'первые': 1,
#   'выходные': 2,
#   'американском': 1,
#   'прокате': 1,
#   'внушительной': 1,
#   'суммой': 1,
#   'миллиона': 2,
#   'долларов': 3,
#   'всём': 1,
#   'мире': 1,
#   'лента': 1,
#   'собрала': 1,
#   'сообщает': 1,
#   'varietyдля': 1,
#   'сравнения': 1,
#   'веном': 1,
#   'обогнал': 1,
#   'выручке': 1,
#   'чудоженщину': 1,
#   'недель': 1,
#   'дебютные': 1,
#   'заработал': 1,
#   'следует': 1,
#   'отметить': 1,
#   'китае': 1,
#   'сделал': 1,
#   'наибольшую': 1,
#   'кассу': 2,
#   'аквамена': 1,
#   'фильм': 1,
#   'оказался': 1,
#   'экранах': 1,
#   'неделю': 1,
#   'америкеаналитики': 1,
#   'считают': 1,
#   'неделя': 1,
#   'рождеством': 1,
#   'сша': 1,
#   'правило': 1,
#   'достаточно': 2,
#   'тихая': 1,
#   'праздника': 1,
#   'количество': 1,
#   'посетителей': 1,
#   'кинотеатров': 1,
#   'сильно': 1,
#   'вырастет': 1,
#   'таким': 1,
#   'образом': 1,
#   'собрать': 1,
#   'большую': 1},
#  {'беспризорники': 2,
#   'станут': 1,
#   'новыми': 1,
#   'главными': 1,
#   'героями': 1,
#   'сериала': 2,
#   'произведениям': 1,
#   'артура': 2,
#   'конана': 2,
#   'дойлакомпания': 1,
#   'netflix': 1,
#   'снимет': 1,
#   'сериал': 1,
#   'книгам': 1,
#   'дойла': 1,
#   'детективе': 1,
#   'шерлоке': 1,
#   'холмсе': 2,
#   'центре': 1,
#   'сюжета': 1,
#   'расследование': 2,
#   'сыщик': 1,
#   'докладывали': 1,
#   'холмсу': 1,
#   'происходящем': 1,
#   'улицах': 2,
#   'лондонасогласно': 1,
#   'циклу': 1,
#   'рассказов': 1,
#   'детектив': 1,
#   'периодически': 1,
#   'просил': 1,
#   'мальчиков': 1,
#   'помощи': 1,
#   'слежке': 1,
#   'поиске': 1,
#   'улик': 1,
#   'называли': 1,
#   'глазами': 1,
#   'холмса': 2,
#   'предыдущих': 1,
#   'экранизациях': 1,
#   'переднем': 1,
#   'плане': 1,
#   'напарника': 1,
#   'ватсонасценарий': 1,
#   'нового': 2,
#   'напишет': 1,
#   'бидвелл': 1,
#   'закончил': 1,
#   'работу': 1,
#   'экранизацией': 1,
#   'опаснейшего': 1,
#   'путешествия': 1,
#   'даты': 1,
#   'премьеры': 1,
#   'шоу': 1},
#  {'актриса': 1,
#   'театра': 1,
#   'кино': 1,
#   'галина': 1,
#   'тихонова': 2,
#   'умерла': 1,
#   'жизни': 2,
#   'скоропостижной': 1,
#   'кончине': 1,
#   'сообщил': 1,
#   'портал': 1,
#   'sakha': 1,
#   'life': 1,
#   'предварительным': 1,
#   'данным': 1,
#   'артистка': 1,
#   'ушла': 1,
#   'изза': 1,
#   'тяжёлой': 1,
#   'болезни': 1,
#   'подробности': 1,
#   'известныдата': 1,
#   'прощания': 1,
#   'похорон': 1,
#   'уточняетсягалина': 1,
#   'известна': 1,
#   'крупным': 1,
#   'якутским': 1,
#   'кинопроектам': 1,
#   'снялась': 1,
#   'белом': 1,
#   'ягеле': 1,
#   'заблудившихся': 1,
#   'моём': 1,
#   'убийце': 1,
#   'дороге': 1,
#   'тд': 1},
#  {'лучшей': 1,
#   'оказалась': 2,
#   'кинодрама': 1,
#   'названием': 1,
#   'билборда': 2,
#   'границе': 2,
#   'эббинга': 2,
#   'миссурипользователи': 1,
#   'сервиса': 1,
#   'кинопоиск': 1,
#   'выбрали': 1,
#   'лучший': 1,
#   'полнометражный': 1,
#   'художественный': 1,
#   'фильм': 2,
#   'лента': 2,
#   'миссурирейтинг': 1,
#   'фильма': 1,
#   'кинопоиске': 1,
#   'составляет': 1,
#   'балла': 1,
#   'главным': 2,
#   'российским': 1,
#   'фильмом': 1,
#   'стала': 1,
#   'картина': 1,
#   'движение': 1,
#   'антона': 1,
#   'мегердичева': 1,
#   'рейтингом': 1,
#   'возглавил': 1,
#   'список': 1,
#   'российского': 1,
#   'проката': 1,
#   'собрала': 1,
#   'миллиарда': 1,
#   'рублейсамыми': 1,
#   'популярными': 1,
#   'российскими': 1,
#   'актёрами': 1,
#   'стали': 1,
#   'александр': 2,
#   'петров': 2,
#   'любовь': 1,
#   'аксёнова': 1,
#   'итогам': 1,
#   'возглавлял': 1,
#   'рейтинг': 1,
#   'самых': 1,
#   'популярных': 1,
#   'отечественных': 1,
#   'актёров': 1,
#   'сериалом': 1,
#   'выбран': 1,
#   'видоизменённый': 1,
#   'углерод': 1,
#   'netflix': 1,
#   'среди': 1,
#   'российских': 1,
#   'сериалов': 1,
#   'лидирует': 1,
#   'домашний': 1,
#   'арест': 1},
#  {'первое': 1,
#   'публичное': 1,
#   'высказывание': 1,
#   'звезды': 1,
#   'карточного': 1,
#   'домика': 1,
#   'спустя': 1,
#   'обвинений': 2,
#   'домогательствах': 2,
#   'декабря': 1,
#   'голливудский': 1,
#   'актёр': 1,
#   'кевин': 2,
#   'спейси': 3,
#   'записал': 1,
#   'видеообращение': 2,
#   'названием': 1,
#   'let': 1,
#   'me': 1,
#   'be': 1,
#   'frank': 1,
#   'позвольте': 1,
#   'побыть': 1,
#   'искреннимфрэнком': 1,
#   'игра': 1,
#   'слов': 1,
#   'трёхминутном': 1,
#   'видео': 1,
#   'лица': 1,
#   'фрэнка': 1,
#   'андервуда': 1,
#   'главных': 1,
#   'персонажей': 1,
#   'шоу': 1,
#   'карточный': 1,
#   'домик': 1,
#   'netflix': 2,
#   'решил': 1,
#   'впервые': 1,
#   'публично': 1,
#   'высказаться': 1,
#   'домогательствахвы': 1,
#   'доверяли': 1,
#   'знали': 1,
#   'должны': 1,
#   'закончили': 1,
#   'знаю': 1,
#   'хотите': 2,
#   'вернулся': 1,
#   'спейсикевин': 1,
#   'опубликовал': 1,
#   'ссылку': 1,
#   'социальных': 1,
#   'сетях': 1,
#   'забросил': 1,
#   'октябре': 1,
#   'отказался': 1,
#   'сотрудничать': 1,
#   'актёром': 1,
#   'обвинили': 1,
#   'сексуальных': 1,
#   'летнему': 1,
#   'подросткунапомним': 1,
#   'сентябре': 1,
#   'прокуратура': 1,
#   'стала': 1,
#   'возбуждать': 1,
#   'уголовное': 1,
#   'дело': 1,
#   'отношении': 1,
#   'актёра': 1,
#   'изза': 1,
#   'истекшего': 1,
#   'срока': 1,
#   'давности': 1},
#  {'крис': 2,
#   'пайн': 2,
#   'озвучивший': 1,
#   'картине': 1,
#   'питера': 2,
#   'паркера': 2,
#   'исполнил': 2,
#   'композицию': 1,
#   'spideybells': 2,
#   'a': 4,
#   'hero': 2,
#   's': 2,
#   'lament': 2,
#   'паучью': 1,
#   'пародию': 1,
#   'jingle': 1,
#   'bellsкомпания': 1,
#   'sony': 1,
#   'опубликовала': 1,
#   'композиции': 1,
#   'специального': 1,
#   'альбома': 1,
#   'very': 2,
#   'spidey': 2,
#   'christmas': 3,
#   'звёзды': 1,
#   'мультфильма': 1,
#   'человекпаук': 2,
#   'вселенные': 1,
#   'поют': 1,
#   'классические': 1,
#   'рождественские': 1,
#   'песни': 1,
#   'одну': 1,
#   'озвучивал': 1,
#   'играл': 1,
#   'фильме': 1,
#   'чудоженщинапри': 1,
#   'джейк': 1,
#   'джонсон': 1,
#   'подарил': 1,
#   'голос': 1,
#   'циничному': 1,
#   'уставшему': 1,
#   'питеру': 1,
#   'б': 1,
#   'паркеру': 1,
#   'спел': 1,
#   'deck': 1,
#   'the': 4,
#   'halls': 1,
#   'добавил': 1,
#   'текст': 1,
#   'шутки': 1,
#   'супергеройскую': 1,
#   'жизньпомимо': 1,
#   'представленных': 1,
#   'песен': 1,
#   'входят': 1,
#   'joy': 1,
#   'to': 1,
#   'world': 1,
#   'шамеика': 1,
#   'мура': 1,
#   'up': 1,
#   'on': 1,
#   'house': 1,
#   'top': 1,
#   'пайна': 1,
#   'night': 1,
#   'before': 1,
#   'spoken': 1,
#   'word': 1,
#   'которую': 1,
#   'йорма': 1,
#   'такконе': 1,
#   'зачитывает': 1,
#   'мультсериала': 1,
#   'альбом': 1,
#   'послушать': 1,
#   'itunes': 1},
#  {'фильм': 1,
#   'главную': 1,
#   'роль': 1,
#   'котором': 1,
#   'сыграет': 1,
#   'актриса': 3,
#   'галь': 3,
#   'гадот': 2,
#   'выйдет': 1,
#   'прокат': 1,
#   'июне': 1,
#   'годапопулярная': 1,
#   'instagram': 1,
#   'опубликовала': 1,
#   'поздравление': 1,
#   'съёмочной': 2,
#   'команды': 1,
#   'звезда': 1,
#   'чудоженщины': 3,
#   'поздравила': 1,
#   'команду': 1,
#   'последним': 1,
#   'днём': 1,
#   'площадкемы': 1,
#   'сделали': 1,
#   'съёмки': 1,
#   'первой': 1,
#   'части': 1,
#   'невероятны': 1,
#   'получилось': 1,
#   'уникальным': 1,
#   'особенным': 1,
#   'снимали': 1,
#   'четырёх': 1,
#   'разных': 1,
#   'местах': 1,
#   'трёх': 1,
#   'странах': 1,
#   'горжусь': 1,
#   'тысячу': 1,
#   'членов': 1,
#   'группы': 1,
#   'гадотнапомним': 1,
#   'действие': 1,
#   'нового': 1,
#   'фильма': 1,
#   'разворачивается': 1,
#   'годы': 1,
#   'времена': 1,
#   'холодной': 1,
#   'войны': 1,
#   'главный': 1,
#   'злодей': 1,
#   'ленты': 1,
#   'гепарда': 1,
#   'одна': 1,
#   'противниц': 1,
#   'комиксов': 1,
#   'сыграла': 1,
#   'кристен': 1,
#   'уиг': 1,
#   'роли': 1,
#   'вернулся': 1,
#   'крис': 1,
#   'пайн': 1,
#   'сыгравший': 1,
#   'друга': 1,
#   'дианы': 1,
#   'стива': 1,
#   'тревораизначально': 1,
#   'чудоженщина': 1,
#   'должна': 1,
#   'выйти': 1,
#   'ноябре': 1,
#   'студия': 1,
#   'отложила': 1,
#   'картину': 1,
#   'месяцев': 1,
#   'музыку': 1,
#   'фильму': 1,
#   'напишет': 1,
#   'композитор': 1,
#   'ханс': 1,
#   'циммер': 1},
#  {'настоящий': 1,
#   'момент': 1,
#   'студия': 1,
#   'планирует': 4,
#   'выпустить': 3,
#   'будущем': 1,
#   'кинокартинкомпания': 1,
#   'disney': 4,
#   'поделилась': 1,
#   'списком': 1,
#   'премьер': 1,
#   'прошлом': 1,
#   'кинокомпания': 1,
#   'завоевала': 1,
#   'четверти': 1,
#   'американского': 1,
#   'кинорынка': 1,
#   'всей': 1,
#   'видимости': 1,
#   'останавливаться': 1,
#   'сообщает': 1,
#   'comicbookв': 1,
#   'минимум': 1,
#   'фильмов': 1,
#   'среди': 1,
#   'капитан': 1,
#   'марвел': 1,
#   'марта': 2,
#   'дамбо': 1,
#   'фильм': 2,
#   'пингвинов': 1,
#   'апреля': 1,
#   'новые': 2,
#   'мстители': 1,
#   'апрелятакже': 1,
#   'нового': 1,
#   'аладдина': 1,
#   'мая': 1,
#   'новую': 1,
#   'историю': 1,
#   'игрушек': 1,
#   'июня': 1,
#   'короля': 1,
#   'льва': 1,
#   'июля': 1,
#   'артемис': 1,
#   'фаул': 1,
#   'августа': 1,
#   'осенью': 1,
#   'выпустит': 1,
#   'холодное': 1,
#   'сердце': 1,
#   'ноября': 1,
#   'декабря': 1,
#   'выйдут': 1,
#   'звёздные': 1,
#   'войны': 1},
#  {'число': 2,
#   'зрителей': 2,
#   'кинотеатрах': 1,
#   'страны': 1,
#   'превысит': 1,
#   'посетителейпосещаемость': 1,
#   'кассовые': 2,
#   'сборы': 2,
#   'российских': 1,
#   'фильмов': 1,
#   'неделю': 1,
#   'завершения': 1,
#   'превысили': 2,
#   'рекордные': 1,
#   'значения': 1,
#   'предыдущего': 1,
#   'сообщает': 1,
#   'фонд': 2,
#   'кино': 2,
#   'ссылкой': 1,
#   'данные': 1,
#   'единой': 1,
#   'федеральной': 1,
#   'автоматизированной': 1,
#   'информационной': 1,
#   'системы': 1,
#   'сведений': 1,
#   'показе': 1,
#   'фильмовпо': 1,
#   'состоянию': 1,
#   'декабря': 1,
#   'отечественного': 1,
#   'миллиарда': 1,
#   'рублей': 2,
#   'оказалось': 1,
#   'выше': 1,
#   'результаты': 1,
#   'обновили': 1,
#   'рекорды': 1,
#   'зафиксированы': 1,
#   'миллиардов': 1,
#   'сборов': 1,
#   'миллиона': 1,
#   'зрителейэтот': 1,
#   'непростым': 1,
#   'рынка': 2,
#   'кинопроката': 1,
#   'сравнению': 1,
#   'аналогичным': 1,
#   'периодом': 1,
#   'прошлого': 1,
#   'объём': 1,
#   'снизился': 1,
#   'рублёвом': 1,
#   'выражении': 1,
#   'процента': 1,
#   'считает': 1,
#   'итогам': 1,
#   'снижение': 1,
#   'составит': 1},
#  {'актёр': 3,
#   'звезда': 1,
#   'сериалов': 1,
#   'секретные': 1,
#   'материалы': 1,
#   'блудливая': 1,
#   'калифорния': 1,
#   'рассказал': 2,
#   'знакомстве': 1,
#   'российской': 1,
#   'музыкойпо': 1,
#   'словам': 2,
#   'духовны': 2,
#   'неплохо': 1,
#   'знаком': 1,
#   'популярной': 1,
#   'музыкой': 1,
#   'россии': 2,
#   'брать': 1,
#   'расчёт': 1,
#   'классику': 1,
#   'чайковского': 1,
#   'прокофьева': 1,
#   'рбкактёр': 1,
#   'секретных': 1,
#   'материалов': 1,
#   'заявил': 2,
#   'съёмках': 1,
#   'рекламы': 1,
#   'слушал': 1,
#   'российскую': 1,
#   'попмузыку': 1,
#   'дэвида': 1,
#   'понимал': 1,
#   'слова': 1,
#   'мелодия': 1,
#   'нравиласьчто': 1,
#   'касается': 1,
#   'группы': 1,
#   'ленинград': 1,
#   'названия': 1,
#   'запомнил': 1,
#   'планирует': 1,
#   'попросить': 1,
#   'актёра': 1,
#   'райана': 1,
#   'рейнольдса': 1,
#   'перекинуть': 1,
#   'песен': 1,
#   'ленинграда': 1,
#   'перспективе': 1,
#   'записать': 1,
#   'совместный': 1,
#   'трек': 1,
#   'группой': 1,
#   'хочет': 1,
#   'послушать': 1,
#   'песни': 1},
#  {'сюжет': 1,
#   'будущей': 1,
#   'киноленты': 1,
#   'должен': 2,
#   'достаточно': 1,
#   'серьёзно': 1,
#   'отойти': 1,
#   'канона': 1,
#   'комиксовактёры': 1,
#   'ленты': 2,
#   'человекпаук': 2,
#   'дома': 2,
#   'джейк': 1,
#   'джилленхол': 1,
#   'джейкоб': 1,
#   'баталон': 2,
#   'раскрыли': 1,
#   'подробности': 1,
#   'будущего': 2,
#   'фильма': 2,
#   'сообщает': 1,
#   'colliderджилленхол': 1,
#   'заявил': 2,
#   'главными': 1,
#   'злодеями': 1,
#   'элементали': 1,
#   'существа': 1,
#   'способные': 1,
#   'управлять': 1,
#   'водой': 1,
#   'землёй': 1,
#   'огнём': 1,
#   'воздухом': 1,
#   'вызывать': 1,
#   'стихийные': 1,
#   'бедствия': 1,
#   'актёр': 1,
#   'сыграть': 1,
#   'мистерио': 1,
#   'врага': 1,
#   'человекапаука': 1,
#   'новом': 1,
#   'фильме': 1,
#   'внезапно': 1,
#   'перейдёт': 1,
#   'сторону': 1,
#   'противника': 1,
#   'вместе': 1,
#   'паркером': 1,
#   'бороться': 1,
#   'элементалейджейкоб': 1,
#   'исполняющий': 1,
#   'роль': 1,
#   'лучшего': 1,
#   'друга': 1,
#   'питера': 1,
#   'паркера': 1,
#   'неда': 1,
#   'фильм': 1,
#   'ребятах': 1,
#   'европейских': 1,
#   'каникул': 1,
#   'рассказал': 1,
#   'картине': 1,
#   'путешествий': 1,
#   'моментов': 1,
#   'связанных': 1,
#   'отношениями': 1,
#   'премьера': 1,
#   'запланирована': 1,
#   'июля': 1},
#  {'×обновление': 1,
#   'пользовательского': 1,
#   'соглашениямы': 1,
#   'повышаем': 1,
#   'качество': 1,
#   'наших': 1,
#   'пользовательских': 1,
#   'служб': 2,
#   'поэтому': 1,
#   'обновляем': 1,
#   'соглашение': 2,
#   'использовании': 1,
#   'ооо': 1,
#   'медиа': 1,
#   'контент': 1,
#   'далее': 3,
#   'компания': 1,
#   'издателем': 1,
#   'сетевого': 1,
#   'издания': 1,
#   'телеканала': 1,
#   'liferu': 1,
#   'физическим': 1,
#   'лицом': 1,
#   'пользователь': 1,
#   'использованию': 1,
#   'сайта': 1,
#   'wwwliferu': 1,
#   'сайтознакомиться': 1,
#   'данными': 1,
#   'изменениями': 1,
#   'можете': 1,
#   'страницепользовательское': 1},
#  {'×обновление': 1,
#   'пользовательского': 1,
#   'соглашениямы': 1,
#   'повышаем': 1,
#   'качество': 1,
#   'наших': 1,
#   'пользовательских': 1,
#   'служб': 2,
#   'поэтому': 1,
#   'обновляем': 1,
#   'соглашение': 2,
#   'использовании': 1,
#   'ооо': 1,
#   'медиа': 1,
#   'контент': 1,
#   'далее': 3,
#   'компания': 1,
#   'издателем': 1,
#   'сетевого': 1,
#   'издания': 1,
#   'телеканала': 1,
#   'liferu': 1,
#   'физическим': 1,
#   'лицом': 1,
#   'пользователь': 1,
#   'использованию': 1,
#   'сайта': 1,
#   'wwwliferu': 1,
#   'сайтознакомиться': 1,
#   'данными': 1,
#   'изменениями': 1,
#   'можете': 1,
#   'страницепользовательское': 1},
#  {'аксессуар': 2,
#   'распечатан': 1,
#   'помощью': 1,
#   'dпринтера': 1,
#   'модель': 2,
#   'блогер': 1,
#   'скачал': 2,
#   'сайта': 2,
#   'thingiverseyoutubeблогер': 1,
#   'kyleofasgard': 2,
#   'выпустил': 1,
#   'видео': 1,
#   'пошаговой': 1,
#   'инструкцией': 1,
#   'сборке': 1,
#   'самодельного': 1,
#   'шлема': 2,
#   'тора': 1,
#   'делает': 1,
#   'глаза': 1,
#   'владельца': 1,
#   'светилисьдля': 1,
#   'добиться': 1,
#   'эффекта': 1,
#   'автору': 1,
#   'гаджета': 2,
#   'пришлось': 2,
#   'использовать': 2,
#   'линзы': 1,
#   'светятся': 1,
#   'ультрафиолетовым': 1,
#   'излучением': 1,
#   'блогеру': 1,
#   'уфлампу': 1,
#   'которую': 1,
#   'разместил': 1,
#   'внутри': 1,
#   'шлемашлем': 1,
#   'распечатал': 1,
#   'dпринтере': 1,
#   'thingiverse': 1,
#   'цепь': 1,
#   'питания': 1,
#   'ledленты': 1,
#   'состояла': 1,
#   'преобразователя': 1,
#   'напряжения': 1,
#   'батарейки': 1,
#   'переключателя': 1,
#   'системы': 1,
#   'дистанционного': 1,
#   'включения': 1,
#   'создатель': 1,
#   'заявил': 1,
#   'носить': 1,
#   'шлем': 1,
#   'долгое': 1,
#   'стоит': 1,
#   'ультрафиолетовое': 1,
#   'излучение': 1,
#   'негативно': 1,
#   'сказаться': 1,
#   'зрении': 1},
#  {'лидирующую': 1,
#   'позицию': 1,
#   'количеству': 1,
#   'номинаций': 4,
#   'заняли': 1,
#   'сразу': 2,
#   'киноленты': 1,
#   'лёд': 2,
#   'движение': 2,
#   'вверхэкспертный': 1,
#   'совет': 1,
#   'национальной': 1,
#   'академии': 2,
#   'кинематографических': 1,
#   'искусств': 1,
#   'наук': 1,
#   'российской': 1,
#   'федерации': 1,
#   'определения': 1,
#   'лауреатом': 1,
#   'премии': 1,
#   'золотой': 1,
#   'орёл': 1,
#   'нынешний': 1,
#   'предложил': 1,
#   'полнометражный': 1,
#   'игровой': 1,
#   'фильм': 1,
#   'неигровых': 1,
#   'короткометражных': 1,
#   'лент': 2,
#   'прессслужба': 1,
#   'объявила': 1,
#   'номинантовлидерами': 1,
#   'числу': 1,
#   'стали': 2,
#   'фильмы': 1,
#   'возглавляли': 1,
#   'список': 1,
#   'самых': 1,
#   'кассовых': 1,
#   'отечественных': 1,
#   'среди': 1,
#   'олега': 1,
#   'трофима': 1,
#   'антона': 1,
#   'мегердичева': 1,
#   'претендентами': 1,
#   'разные': 1,
#   'призы': 1,
#   'история': 1,
#   'назначения': 1,
#   'авдотьи': 1,
#   'смирновой': 1,
#   'война': 1,
#   'анны': 1,
#   'алексея': 1,
#   'федорченко': 1,
#   'спитак': 1,
#   'александра': 1,
#   'коттапри': 1,
#   'лучшей': 1,
#   'актрисой': 1,
#   'стать': 1,
#   'марта': 1,
#   'козлова': 1,
#   'аглая': 1,
#   'тарасова': 1,
#   'светлана': 1,
#   'ходченкова': 1,
#   'ирина': 1,
#   'горбачёва': 1,
#   'лучшим': 1,
#   'актёром': 1,
#   'александр': 1,
#   'петров': 1,
#   'отличился': 1,
#   'трёх': 1,
#   'фильмах': 1,
#   'владимир': 1,
#   'машков': 1,
#   'олег': 1,
#   'меньшиков': 1,
#   'андрей': 1,
#   'смоляков': 1,
#   'звание': 1,
#   'популярного': 1,
#   'сериала': 1,
#   'сражаются': 1,
#   'обычная': 1,
#   'женщина': 1,
#   'хождение': 1,
#   'мукам': 1,
#   'мост': 1,
#   'берёзканапомним': 1,
#   'торжественное': 1,
#   'награждение': 1,
#   'победителей': 1,
#   'проходить': 1,
#   'января': 1},
#  {'спор': 1,
#   'двумя': 1,
#   'авторами': 1,
#   'популярных': 1,
#   'американских': 1,
#   'кинолент': 1,
#   'состоялся': 1,
#   'годурежиссёр': 1,
#   'эдгар': 1,
#   'райт': 3,
#   'малыш': 1,
#   'драйве': 1,
#   'проиграл': 1,
#   'оскар': 2,
#   'своему': 1,
#   'коллеге': 1,
#   'джеймсу': 1,
#   'вану': 1,
#   'аквамен': 2,
#   'поспорили': 1,
#   'социальной': 1,
#   'сети': 1,
#   'twitter': 1,
#   'ван': 2,
#   'сможет': 1,
#   'оставить': 1,
#   'фильме': 1,
#   'отсылку': 1,
#   'сериалу': 1,
#   'стингрей': 1,
#   'отдаст': 1,
#   'свой': 1,
#   'трофейджеймс': 1,
#   'заявил': 1,
#   'настоящий': 1,
#   'момент': 1,
#   'ждёт': 1,
#   'коллега': 1,
#   'посмотрит': 1,
#   'ленту': 1,
#   'вспомнит': 1,
#   'той': 1,
#   'публикации': 1,
#   'рассказал': 1,
#   'видел': 1,
#   'фильм': 2,
#   'насколько': 1,
#   'понимает': 1,
#   'должен': 1,
#   'ванунапомним': 1,
#   'мировом': 1,
#   'прокате': 1,
#   'собрал': 1,
#   'долларов': 2,
#   'сша': 1,
#   'лента': 1,
#   'вышла': 1,
#   'прокат': 1,
#   'декабря': 1,
#   'собрала': 1,
#   'порядка': 1},
#  {'добиться': 1,
#   'удалось': 1,
#   'благодаря': 1,
#   'аквамену': 1,
#   'продажи': 2,
#   'сеансы': 1,
#   'настоящий': 1,
#   'момент': 1,
#   'зашкаливают': 1,
#   'сшав': 1,
#   'кассовые': 1,
#   'сборы': 1,
#   'билетов': 2,
#   'кино': 3,
#   'канаде': 2,
#   'сша': 2,
#   'превысят': 1,
#   'миллиарда': 3,
#   'долларов': 1,
#   'таким': 2,
#   'образом': 2,
#   'голливуд': 1,
#   'побил': 1,
#   'рекорд': 1,
#   'общая': 1,
#   'сумма': 1,
#   'поступлений': 1,
#   'составила': 1,
#   'долларовна': 1,
#   'рост': 1,
#   'продаж': 1,
#   'повлияли': 1,
#   'аквамен': 1,
#   'чёрная': 1,
#   'пантера': 1,
#   'мстители': 1,
#   'война': 1,
#   'бесконечности': 1,
#   'дэдпул': 1,
#   'мир': 1,
#   'юрского': 1,
#   'периода': 1,
#   'прошлом': 1,
#   'отмечался': 1,
#   'спад': 1,
#   'посещаемости': 1,
#   'кинотеатров': 1,
#   'связи': 1,
#   'голливуде': 1,
#   'опасались': 1,
#   'перестанут': 1,
#   'ходить': 1,
#   'смотреть': 1,
#   'фильмы': 1,
#   'помощью': 1,
#   'netflix': 1,
#   'amazon': 1,
#   'стримингсервисовтакже': 1,
#   'аналитики': 1,
#   'сообщили': 1,
#   'цены': 1,
#   'билеты': 1,
#   'увеличились': 1,
#   'повлияло': 1,
#   'увеличение': 1,
#   'кассовых': 1,
#   'сборов': 1,
#   'продано': 1},
#  {'чад': 2,
#   'стахелски': 3,
#   'очередной': 1,
#   'решил': 1,
#   'подтвердить': 1,
#   'журналистам': 1,
#   'намерения': 1,
#   'поводу': 1,
#   'съёмокрежиссёр': 1,
#   'джон': 2,
#   'уик': 2,
#   'теряет': 1,
#   'надежды': 1,
#   'снимет': 1,
#   'ремейк': 1,
#   'фильма': 1,
#   'горец': 1,
#   'сообщает': 1,
#   'ewстахелски': 1,
#   'заявил': 1,
#   'хочет': 1,
#   'работать': 1,
#   'проектом': 1,
#   'предполагается': 1,
#   'режиссёр': 1,
#   'сможет': 1,
#   'заняться': 1,
#   'сразу': 1,
#   'полностью': 1,
#   'завершит': 1,
#   'работу': 2,
#   'третьей': 1,
#   'частью': 1,
#   'ленты': 1,
#   'заявлял': 1,
#   'проектов': 1,
#   'общегонапомним': 1,
#   'проект': 1,
#   'перезапуска': 1,
#   'горца': 1,
#   'появился': 1,
#   'права': 1,
#   'экранизацию': 1,
#   'купила': 1,
#   'фирма': 1,
#   'summit': 1,
#   'entertainment': 1,
#   'выкупила': 1,
#   'студия': 1,
#   'lionsgate': 1,
#   'сценарием': 1,
#   'закончили': 1,
#   'марте': 1,
#   'писал': 1,
#   'райан': 1,
#   'кондал': 1,
#   'рэмпейдж': 1,
#   'геракл': 1},
#  {'спустя': 1,
#   'стало': 1,
#   'известно': 1,
#   'чёрнобелый': 1,
#   'фильм': 1,
#   'ангелы': 2,
#   'грязными': 2,
#   'душами': 2,
#   'выходилфанатов': 1,
#   'фильма': 2,
#   'дома': 4,
#   'шокировал': 1,
#   'факт': 1,
#   'известная': 1,
#   'фраза': 1,
#   'ленты': 1,
#   'оказалось': 1,
#   'фейком': 1,
#   'рассказал': 1,
#   'актёр': 1,
#   'сценарист': 1,
#   'сет': 1,
#   'рогенречь': 1,
#   'идёт': 1,
#   'фразе': 1,
#   'сдачу': 1,
#   'оставь': 1,
#   'грязное': 1,
#   'животное': 1,
#   'стала': 1,
#   'мемом': 1,
#   'частью': 1,
#   'популярной': 1,
#   'культуры': 1,
#   'звучит': 1,
#   'гангстерском': 1,
#   'фильме': 1,
#   'сцен': 1,
#   'смотрит': 1,
#   'кевин': 1,
#   'маккаллистеркак': 1,
#   'удалось': 1,
#   'выяснить': 1,
#   'деле': 1,
#   'существует': 1,
#   'режиссёр': 1,
#   'крис': 1,
#   'коламбус': 1,
#   'снял': 1,
#   'таких': 1,
#   'чёрнобелых': 1,
#   'роликов': 1,
#   'специально': 1,
#   'производства': 1,
#   'фильмов': 1},
#  {'×обновление': 1,
#   'пользовательского': 1,
#   'соглашениямы': 1,
#   'повышаем': 1,
#   'качество': 1,
#   'наших': 1,
#   'пользовательских': 1,
#   'служб': 2,
#   'поэтому': 1,
#   'обновляем': 1,
#   'соглашение': 2,
#   'использовании': 1,
#   'ооо': 1,
#   'медиа': 1,
#   'контент': 1,
#   'далее': 3,
#   'компания': 1,
#   'издателем': 1,
#   'сетевого': 1,
#   'издания': 1,
#   'телеканала': 1,
#   'liferu': 1,
#   'физическим': 1,
#   'лицом': 1,
#   'пользователь': 1,
#   'использованию': 1,
#   'сайта': 1,
#   'wwwliferu': 1,
#   'сайтознакомиться': 1,
#   'данными': 1,
#   'изменениями': 1,
#   'можете': 1,
#   'страницепользовательское': 1},
#  {'каждой': 2,
#   'трансляцией': 2,
#   'сериала': 4,
#   'должна': 2,
#   'появляться': 2,
#   'информация': 2,
#   'персонажи': 2,
#   'вымышленысуд': 1,
#   'польского': 1,
#   'кракова': 1,
#   'обязал': 2,
#   'немецкий': 2,
#   'телеканал': 2,
#   'zdf': 1,
#   'иском': 1,
#   'выступил': 1,
#   'ветеран': 1,
#   'армии': 3,
#   'крайовой': 2,
#   'збигнев': 1,
#   'радловский': 1,
#   'извиниться': 1,
#   'показ': 1,
#   'матери': 1,
#   'отцыфильм': 1,
#   'вызвал': 1,
#   'польше': 1,
#   'недовольство': 1,
#   'связи': 1,
#   'бойцы': 1,
#   'нём': 1,
#   'показаны': 1,
#   'антисемиты': 1,
#   'вина': 1,
#   'немцев': 1,
#   'преступлениях': 1,
#   'евреев': 1,
#   'замалчиваетсясогласно': 1,
#   'постановлению': 1,
#   'вымышлены': 1,
#   'поляки': 1,
#   'мировой': 1,
#   'помогали': 1,
#   'евреям': 1,
#   'немцы': 1,
#   'оккупировали': 1,
#   'польшусуд': 1,
#   'выплатить': 1,
#   'злотых': 1,
#   'тысячи': 1,
#   'долларов': 1,
#   'компенсации': 1,
#   'капитану': 1,
#   'краевой': 1,
#   'збигневу': 1,
#   'радловскомуюристы': 1,
#   'представляли': 1,
#   'суде': 1,
#   'канал': 1,
#   'производителя': 1,
#   'просили': 1,
#   'прекращении': 1,
#   'процесса': 1,
#   'заявляли': 1,
#   'авторы': 1,
#   'пользовались': 1,
#   'свободой': 1,
#   'творчества': 1,
#   'производя': 1,
#   'исторический': 1,
#   'художественный': 1,
#   'фильм': 1},
#  {'личный': 1,
#   'рейтинг': 1,
#   'экспрезидента': 1,
#   'сша': 1,
#   'вошло': 1,
#   'книг': 1,
#   'фильмов': 2,
#   'песен': 2,
#   'заставляющих': 1,
#   'думать': 1,
#   'вдохновляющих': 1,
#   'любимыхбывший': 1,
#   'глава': 1,
#   'белого': 1,
#   'дома': 1,
#   'барак': 1,
#   'обама': 2,
#   'опубликовал': 1,
#   'фейсбуке': 1,
#   'список': 1,
#   'любимых': 1,
#   'произведений': 1,
#   'литературы': 1,
#   'годав': 1,
#   'вошли': 1,
#   'числе': 1,
#   'книга': 2,
#   'американская': 1,
#   'тюрьма': 1,
#   'шейна': 1,
#   'бауэра': 1,
#   'ленты': 1,
#   'чёрная': 1,
#   'пантера': 1,
#   'смерть': 1,
#   'сталина': 1,
#   'песни': 1,
#   'карди': 1,
#   'би': 1,
#   'легенды': 1,
#   'джаза': 1,
#   'нэнси': 1,
#   'уилсон': 1,
#   'певца': 1,
#   'принсаотдельно': 1,
#   'упомянул': 1,
#   'произведения': 1,
#   'включал': 1,
#   'аналогичные': 1,
#   'рейтинги': 1,
#   'прошлых': 1,
#   'отметил': 1,
#   'удовольствием': 1,
#   'читал': 1,
#   'смотрел': 1,
#   'слушал': 1,
#   'уходящем': 1,
#   'годуна': 1,
#   'первой': 1,
#   'строчке': 1,
#   'супруги': 1,
#   'мишель': 1,
#   'обамы': 1,
#   'становление': 1,
#   'которую': 1,
#   'экспрезидент': 1,
#   'назвал': 1,
#   'очевидно': 1,
#   'любимой': 1,
#   'перечитывал': 1,
#   'долгий': 1,
#   'путь': 1,
#   'свободе': 1,
#   'нельсона': 1,
#   'манделы': 1,
#   'многие': 1,
#   'книги': 1},
#  {'мегафон': 4,
#   'проанализировал': 1,
#   'данные': 1,
#   'количеству': 1,
#   'просмотров': 1,
#   'онлайнкинотеатре': 2,
#   'tv': 3,
#   'подготовил': 1,
#   'рейтинг': 1,
#   'самых': 1,
#   'популярных': 1,
#   'фильмов': 4,
#   'сериалов': 3,
#   'абонентовв': 1,
#   'тройку': 1,
#   'лидеров': 1,
#   'среди': 1,
#   'художественных': 1,
#   'попали': 2,
#   'ленты': 1,
#   'собибор': 1,
#   'худею': 1,
#   'мстители': 1,
#   'война': 1,
#   'бесконечности': 1,
#   'топ': 1,
#   'вошли': 1,
#   'картины': 1,
#   'первому': 1,
#   'игроку': 1,
#   'приготовиться': 1,
#   'гоголь': 1,
#   'страшная': 1,
#   'месть': 1,
#   'бегущий': 1,
#   'лезвию': 1,
#   'ремпейдж': 1,
#   'джуманджи': 1,
#   'зов': 1,
#   'джунглей': 1,
#   'тор': 1,
#   'рагнарёк': 1,
#   'геоштормрейтинг': 1,
#   'возглавила': 1,
#   'игра': 1,
#   'престолов': 1,
#   'второе': 1,
#   'третье': 1,
#   'место': 1,
#   'заняли': 1,
#   'российских': 1,
#   'сериала': 1,
#   'ивановыивановы': 1,
#   'полицейский': 1,
#   'рублёвки': 1,
#   'соответственно': 1,
#   'десятку': 1,
#   'отель': 1,
#   'элеон': 1,
#   'гранд': 1,
#   'универ': 1,
#   'улица': 1,
#   'хороший': 1,
#   'докторв': 1,
#   'декабре': 1,
#   'январе': 1,
#   'всей': 1,
#   'семьи': 1,
#   'работать': 1,
#   'телеканал': 1,
#   'деда': 1,
#   'мороза': 1,
#   'подборкой': 1,
#   'праздничных': 1,
#   'кино': 1,
#   'мультипликационных': 1,
#   'шоу': 1,
#   'познавательных': 1,
#   'программ': 1,
#   'сервисом': 1,
#   'пользоваться': 1,
#   'смартфонах': 1,
#   'планшетах': 1,
#   'smartтелевизорах': 1,
#   'компьютерах': 1,
#   'выходом': 1,
#   'интернет': 1,
#   'тв': 1,
#   'фильмы': 1,
#   'доступны': 1,
#   'дороге': 1,
#   'парках': 1,
#   'кафе': 1,
#   'даче': 1,
#   'метро': 1,
#   'оплате': 1,
#   'банковской': 1,
#   'картой': 1,
#   'мегафона': 1,
#   'оператор': 1,
#   'вернёт': 1,
#   'стоимости': 1,
#   'счёт': 1,
#   'мобильного': 1},
#  {'прославленный': 1,
#   'кинорежиссёр': 1,
#   'сценарист': 1,
#   'марлен': 1,
#   'хуциев': 2,
#   'госпитализирован': 1,
#   'москве': 1,
#   'сообщает': 1,
#   'канал': 1,
#   'подробности': 1,
#   'состояния': 1,
#   'летнего': 1,
#   'народного': 1,
#   'артиста': 1,
#   'ссср': 1,
#   'раскрываются': 1,
#   'известно': 1,
#   'категорически': 1,
#   'отказался': 1,
#   'ехать': 1,
#   'больницу': 1,
#   'женыпожилых': 1,
#   'супругов': 1,
#   'госпитализировали': 1,
#   'вместе': 1,
#   'поместили': 1,
#   'одну': 1,
#   'палату': 1,
#   'обследуют': 1,
#   'медикимарлен': 1,
#   'широко': 1,
#   'известен': 1,
#   'отечественному': 1,
#   'зрителю': 1,
#   'своими': 1,
#   'работами': 1,
#   'весна': 1,
#   'заречной': 1,
#   'улице': 1,
#   'фёдора': 1,
#   'застава': 1,
#   'ильича': 1,
#   'многими': 1,
#   'другими': 1},
#  {'сайтагрегатор': 1,
#   'metacritic': 1,
#   'специализирующийся': 1,
#   'сборе': 1,
#   'анализе': 1,
#   'отзывов': 1,
#   'зрителей': 1,
#   'опубликовал': 1,
#   'список': 1,
#   'лучших': 1,
#   'сериалов': 1,
#   'дебютировавших': 1,
#   'годупервое': 1,
#   'место': 1,
#   'заняла': 1,
#   'гениальная': 1,
#   'подруга': 1,
#   'сериал': 3,
#   'основанный': 1,
#   'одноимённом': 1,
#   'произведении': 1,
#   'элены': 1,
#   'ферранте': 1,
#   'примечательно': 1,
#   'продюсером': 1,
#   'проекта': 1,
#   'выступил': 1,
#   'знаменитый': 1,
#   'итальянский': 1,
#   'режиссёр': 1,
#   'паоло': 1,
#   'соррентиновторой': 1,
#   'стала': 1,
#   'чёрная': 2,
#   'комедия': 1,
#   'барри': 1,
#   'биллом': 1,
#   'хейдером': 1,
#   'главной': 2,
#   'роли': 2,
#   'история': 1,
#   'киллеренеудачнике': 1,
#   'неожиданно': 1,
#   'находит': 1,
#   'своё': 1,
#   'истинное': 1,
#   'призвание': 1,
#   'убийстве': 1,
#   'людей': 1,
#   'театральной': 1,
#   'сценена': 1,
#   'третьем': 1,
#   'месте': 1,
#   'оказался': 1,
#   'драматический': 1,
#   'убивая': 1,
#   'еву': 1,
#   'рассказывающий': 1,
#   'историю': 1,
#   'аналитика': 1,
#   'британской': 1,
#   'контрразведки': 1,
#   'mi': 1,
#   'евы': 1,
#   'поластри': 1,
#   'охотится': 1,
#   'наёмного': 1,
#   'убийцу': 1,
#   'вилланель': 1,
#   'основан': 1,
#   'серии': 1,
#   'романов': 1,
#   'люка': 1,
#   'дженнингса': 1,
#   'адаптированных': 1,
#   'актрисой': 1,
#   'фиби': 1,
#   'уоллербриджпомимо': 1,
#   'топ': 1,
#   'вошли': 1,
#   'свободном': 1,
#   'улёте': 1,
#   'возвращение': 1,
#   'домой': 1,
#   'джулией': 1,
#   'робертс': 1,
#   'соболезную': 1,
#   'вашей': 1,
#   'утрате': 1,
#   'конец': 1,
#   'нарко': 1,
#   'мексика': 1,
#   'телохранитель': 1,
#   'молния': 1},
#  {'мнению': 2,
#   'священнослужителя': 1,
#   'фильм': 1,
#   'транслирует': 2,
#   'идею': 2,
#   'чуда': 1,
#   'достаточно': 2,
#   'встретиться': 2,
#   'напитьсяактёр': 1,
#   'андрей': 1,
#   'мягков': 1,
#   'сыграл': 1,
#   'роль': 1,
#   'евгения': 1,
#   'лукашина': 1,
#   'фильме': 2,
#   'ирония': 1,
#   'судьбы': 1,
#   'лёгким': 1,
#   'паром': 1,
#   'резко': 1,
#   'отреагировал': 1,
#   'критику': 1,
#   'картины': 1,
#   'стороны': 1,
#   'митрополита': 2,
#   'рязанского': 1,
#   'михайловского': 1,
#   'маркасвященнослужитель': 1,
#   'ранее': 1,
#   'заявил': 1,
#   'кинолента': 2,
#   'наполняет': 1,
#   'человеческую': 1,
#   'душу': 1,
#   'ложными': 1,
#   'несбыточными': 1,
#   'мечтаниями': 1,
#   'произошло': 1,
#   'чудо': 1,
#   'напитьсяисполнитель': 1,
#   'главных': 1,
#   'ролей': 1,
#   'счёл': 1,
#   'недалёким': 1,
#   'думаю': 1,
#   'рязанский': 1,
#   'митрополит': 2,
#   'недалёк': 1,
#   'умом': 1,
#   'говорить': 1,
#   'приводит': 1,
#   'слова': 1,
#   'актёра': 1,
#   'радиостанция': 1,
#   'москвакак': 1,
#   'писал': 1,
#   'лайф': 1,
#   'своём': 1,
#   'новогоднем': 1,
#   'обращении': 1,
#   'подчеркнул': 1,
#   'церковь': 1,
#   'призывает': 1,
#   'людей': 1,
#   'труду': 1,
#   'постоянной': 1,
#   'работе': 1,
#   'данная': 1,
#   'установке': 1,
#   'противоречит': 1},
#  {'втором': 2,
#   'месте': 2,
#   'оказалась': 2,
#   'кинолента': 1,
#   'ёлки': 2,
#   'последние': 2,
#   'третье': 2,
#   'место': 2,
#   'занял': 2,
#   'мультфильм': 2,
#   'гринчроссийская': 1,
#   'комедия': 1,
#   'названием': 2,
#   'полицейский': 2,
#   'рублёвки': 2,
#   'новогодний': 1,
#   'беспредел': 1,
#   'собрала': 1,
#   'российском': 1,
#   'прокате': 1,
#   'миллиона': 3,
#   'рублей': 3,
#   'итогам': 1,
#   'выходных': 1,
#   'благодаря': 1,
#   'фильм': 2,
#   'сохранил': 1,
#   'лидерство': 1,
#   'прокателента': 1,
#   'ильи': 1,
#   'куликова': 1,
#   'вышла': 1,
#   'прокат': 1,
#   'декабря': 1,
#   'основан': 1,
#   'телевизионном': 1,
#   'сериале': 1,
#   'рассказывает': 1,
#   'сотрудника': 1,
#   'отделения': 1,
#   'полиции': 1,
#   'пытается': 1,
#   'спасти': 1,
#   'свой': 1,
#   'отдел': 1,
#   'расформированияна': 1,
#   'одна': 1,
#   'отечественная': 1,
#   'кинокартина': 1,
#   'комедии': 1,
#   'удалось': 1,
#   'собрать': 1,
#   'гринч': 1,
#   'собрал': 1,
#   'прошедшие': 1,
#   'выходные': 1},
#  {'компания': 1,
#   'netflix': 1,
#   'поделилась': 1,
#   'тизером': 1,
#   'постером': 1,
#   'продолжения': 1,
#   'популярного': 1,
#   'американского': 1,
#   'шоув': 1,
#   'сети': 1,
#   'появилась': 1,
#   'информация': 1,
#   'касается': 2,
#   'даты': 1,
#   'выхода': 1,
#   'нового': 1,
#   'сезона': 2,
#   'сериала': 1,
#   'странные': 1,
#   'дела': 1,
#   'новые': 1,
#   'эпизоды': 1,
#   'доступны': 1,
#   'просмотра': 1,
#   'июля': 1,
#   'годадействие': 1,
#   'будущего': 1,
#   'разворачивается': 1,
#   'опубликованном': 1,
#   'тизере': 1,
#   'популярный': 1,
#   'американский': 1,
#   'ведущий': 1,
#   'дик': 1,
#   'кларк': 1,
#   'отсчитывает': 1,
#   'последние': 1,
#   'секунды': 1,
#   'уходящего': 1,
#   'вёл': 1,
#   'передачу': 1,
#   'dick': 1,
#   'clarks': 1,
#   'new': 1,
#   'years': 1,
#   'rocking': 1,
#   'eve': 1,
#   'рок': 1,
#   'новый': 1,
#   'диком': 1,
#   'кларком': 1,
#   'шоу': 2,
#   'показывали': 1,
#   'ньюйоркской': 1,
#   'таймссквер': 1,
#   'телеведущий': 1,
#   'умер': 1,
#   'годучто': 1,
#   'рассказывает': 1,
#   'подростков': 1,
#   'годы': 1,
#   'штате': 1,
#   'индиана': 1,
#   'события': 1,
#   'разворачиваются': 1,
#   'вымышленном': 1,
#   'городе': 1,
#   'хоукинсе': 1},
#  {'соответствующий': 1,
#   'список': 2,
#   'составлен': 1,
#   'сайтом': 1,
#   'fandango': 1,
#   'традиционно': 1,
#   'делает': 1,
#   'прогнозы': 1,
#   'будущий': 1,
#   'годфильмы': 1,
#   'студии': 1,
#   'marvel': 1,
#   'стали': 1,
#   'самыми': 1,
#   'ожидаемыми': 1,
#   'среди': 1,
#   'выходят': 1,
#   'сообщает': 1,
#   'fandangoпервое': 1,
#   'место': 2,
#   'заняла': 1,
#   'четвёртая': 1,
#   'часть': 1,
#   'мстителей': 1,
#   'позиции': 1,
#   'оказался': 1,
#   'фильм': 2,
#   'капитан': 1,
#   'марвел': 1,
#   'третье': 1,
#   'досталось': 1,
#   'девятому': 1,
#   'эпизоду': 1,
#   'звёздных': 1,
#   'войн': 1,
#   'пятёрку': 1,
#   'лидеров': 1,
#   'вошли': 1,
#   'человекпаук': 1,
#   'дома': 1,
#   'история': 1,
#   'игрушек': 1,
#   'остальные': 1,
#   'места': 1,
#   'первой': 1,
#   'десятке': 1,
#   'заняли': 1,
#   'следующие': 1,
#   'ленты': 1,
#   'стекло': 1,
#   'король': 1,
#   'лев': 1,
#   'аладдин': 1,
#   'дамбо': 1,
#   'джокер': 1,
#   'касается': 1,
#   'капитана': 1,
#   'марвела': 1,
#   'возглавил': 1,
#   'самых': 1,
#   'ожидаемых': 1,
#   'сольных': 1,
#   'лент': 1,
#   'супергероях': 1},
#  {'соответствующее': 1,
#   'заявление': 1,
#   'автор': 1,
#   'американской': 1,
#   'киноленты': 1,
#   'решил': 2,
#   'сделать': 1,
#   'собственном': 1,
#   'микроблоге': 1,
#   'twitterджеймс': 1,
#   'ван': 3,
#   'режиссёр': 3,
#   'аквамена': 1,
#   'обратился': 1,
#   'фанатам': 1,
#   'фильма': 2,
#   'просьбой': 1,
#   'оскорблять': 1,
#   'людей': 1,
#   'которым': 2,
#   'понравилась': 1,
#   'лента': 1,
#   'рассказал': 1,
#   'странице': 1,
#   'персонального': 1,
#   'twitterаккаунтая': 1,
#   'узнал': 1,
#   'понравился': 1,
#   'аквамен': 2,
#   'подвергаются': 1,
#   'насмешкам': 1,
#   'оскорблениям': 1,
#   'стороны': 1,
#   'фанатов': 1,
#   'ленты': 1,
#   'делать': 1,
#   'нужна': 1,
#   'поддержка': 1,
#   'проявляйте': 1,
#   'уважение': 1,
#   'джеймс': 2,
#   'вантакже': 1,
#   'заявил': 1,
#   'предосудительного': 1,
#   'любить': 1,
#   'фильм': 1,
#   'вместе': 1,
#   'попросил': 1,
#   'переходить': 1,
#   'личности': 1,
#   'изза': 1,
#   'этогонапомним': 1,
#   'заниматься': 1,
#   'продолжением': 1,
#   'ранее': 1,
#   'заявлял': 1,
#   'хочет': 1,
#   'вернуться': 1,
#   'масштабным': 1,
#   'проектам': 1},
#  {'соболезнования': 2,
#   'выразили': 1,
#   'друзья': 2,
#   'коллеги': 2,
#   'актёра': 1,
#   'режиссёры': 2,
#   'анна': 2,
#   'меликян': 2,
#   'григорий': 2,
#   'константинопольский': 2,
#   'александр': 2,
#   'атанасян': 2,
#   'актриса': 2,
#   'юлия': 2,
#   'ауг': 2,
#   'кинокритики': 2,
#   'андрей': 2,
#   'плахов': 2,
#   'мария': 2,
#   'кувшинова': 2,
#   'другиеактёр': 1,
#   'владимир': 1,
#   'дыховичный': 1,
#   'сын': 1,
#   'режиссёра': 2,
#   'ивана': 1,
#   'дыховичного': 2,
#   'скончался': 1,
#   'возрасте': 1,
#   'странице': 1,
#   'фейсбуке': 1,
#   'сообщила': 1,
#   'вдова': 1,
#   'ольга': 1,
#   'rip': 1,
#   'написала': 1,
#   'прикрепив': 1,
#   'публикации': 1,
#   'фотографию': 1,
#   'владимирапричины': 1,
#   'смерти': 1,
#   'уточняются': 1,
#   'записью': 1,
#   'оставляют': 1,
#   'среди': 1,
#   'другиедыховичный': 1,
#   'родился': 1,
#   'апреля': 1,
#   'окончил': 1,
#   'вгик': 1,
#   'мастерскую': 1,
#   'народного': 1,
#   'артиста': 1,
#   'рф': 1,
#   'сергея': 2,
#   'соловьёва': 1,
#   'известен': 1,
#   'ролям': 1,
#   'таких': 1,
#   'фильмах': 1,
#   'невидимки': 1,
#   'комарова': 1,
#   'лето': 1,
#   'кирилла': 1,
#   'серебренникова': 1,
#   'сериала': 1,
#   'бессоница': 1},
#  {'популярный': 1,
#   'американский': 2,
#   'актёр': 1,
#   'появится': 1,
#   'экране': 2,
#   'роли': 1,
#   'капитана': 2,
#   'пиратов': 1,
#   'джека': 2,
#   'воробьякомпания': 1,
#   'walt': 1,
#   'disney': 1,
#   'сэкономила': 1,
#   'порядка': 1,
#   'долларов': 1,
#   'благодаря': 1,
#   'решила': 1,
#   'приглашать': 1,
#   'популярного': 1,
#   'голливудского': 1,
#   'актёра': 3,
#   'джонни': 1,
#   'деппа': 3,
#   'сниматься': 1,
#   'новой': 1,
#   'части': 1,
#   'фильма': 1,
#   'пираты': 1,
#   'карибского': 1,
#   'моря': 1,
#   'сообщил': 1,
#   'журнал': 1,
#   'forbesв': 1,
#   'настоящий': 1,
#   'момент': 1,
#   'информации': 1,
#   'должен': 1,
#   'заменить': 1,
#   'воробья': 1,
#   'специалисты': 2,
#   'считают': 2,
#   'либо': 2,
#   'студия': 1,
#   'рассматривала': 1,
#   'претендентов': 1,
#   'другого': 1,
#   'персонажа': 1,
#   'вовсе': 1,
#   'будеттакже': 1,
#   'следует': 1,
#   'добавить': 1,
#   'увольнение': 1,
#   'серии': 1,
#   'принести': 1,
#   'убытки': 1,
#   'кинокомпании': 1,
#   'дело': 1,
#   'несмотря': 1,
#   'многие': 1,
#   'личные': 1,
#   'проблемы': 1,
#   'последние': 1,
#   'годы': 1,
#   'остаётся': 1,
#   'талантливым': 1,
#   'вместе': 1,
#   'представить': 1,
#   'пиратский': 1,
#   'фильм': 1,
#   'достаточно': 1,
#   'сложно': 1},
#  {'сериал': 3,
#   'зомби': 1,
#   'вышел': 1,
#   'лидер': 1,
#   'связи': 2,
#   'отсутствием': 1,
#   'новых': 1,
#   'эпизодов': 1,
#   'популярного': 1,
#   'шоу': 2,
#   'игра': 1,
#   'престоловиздание': 1,
#   'torrentfreaks': 1,
#   'опубликовало': 1,
#   'ежегодный': 1,
#   'итоговый': 1,
#   'топ': 1,
#   'сериалов': 1,
#   'скачивают': 1,
#   'интернете': 1,
#   'рейтинг': 1,
#   'основан': 1,
#   'данных': 1,
#   'загрузках': 1,
#   'сервис': 1,
#   'bittorrentлидером': 1,
#   'ходячие': 1,
#   'мертвецы': 1,
#   'протяжении': 1,
#   'последних': 1,
#   'шести': 1,
#   'занимало': 1,
#   'второе': 1,
#   'место': 1,
#   'уступая': 1,
#   'игре': 1,
#   'престолов': 1,
#   'популярность': 1,
#   'сериала': 1,
#   'hbo': 1,
#   'среди': 1,
#   'пиратов': 1,
#   'снизилась': 1,
#   'телеканал': 1,
#   'выпустил': 1,
#   'новый': 1,
#   'сезон': 1,
#   'попал': 1,
#   'первую': 1,
#   'десяткусреди': 1,
#   'лидеров': 1,
#   'помимо': 1,
#   'ходячих': 1,
#   'оказались': 1,
#   'сериалы': 1,
#   'флэш': 1,
#   'теория': 1,
#   'большого': 1,
#   'взрыва': 1,
#   'идут': 1,
#   'викинги': 1,
#   'титаны': 1,
#   'стрела': 1,
#   'сверхъестественное': 1,
#   'мир': 1,
#   'дикого': 1,
#   'запада': 1,
#   'легенды': 1,
#   'завтрашнего': 1,
#   'дня': 1,
#   'форсмажоры': 1},
#  {'таким': 1,
#   'образом': 1,
#   'популярная': 1,
#   'американская': 1,
#   'актриса': 2,
#   'решила': 1,
#   'прокомментировать': 1,
#   'популярность': 1,
#   'deepfakeгазета': 1,
#   'the': 1,
#   'washington': 1,
#   'post': 1,
#   'опубликовала': 1,
#   'материал': 1,
#   'росте': 1,
#   'популярности': 1,
#   'deepfake': 1,
#   'видео': 3,
#   'лица': 1,
#   'знаменитостей': 1,
#   'помощью': 1,
#   'нейросетей': 1,
#   'переносят': 1,
#   'другими': 1,
#   'актёрами': 1,
#   'числе': 1,
#   'порнографическиеодной': 1,
#   'жертв': 1,
#   'опубликованном': 1,
#   'материале': 1,
#   'выступила': 1,
#   'скарлетт': 2,
#   'йоханссон': 2,
#   'набирают': 1,
#   'миллионы': 1,
#   'просмотров': 1,
#   'словам': 1,
#   'звезды': 1,
#   'фильма': 1,
#   'мстители': 1,
#   'вести': 1,
#   'борьбу': 1,
#   'данным': 1,
#   'явлением': 1,
#   'смысла': 1,
#   'считает': 2,
#   'принципе': 1,
#   'невозможноэто': 1,
#   'влияет': 1,
#   'сильно': 1,
#   'предполагают': 1,
#   'всётаки': 1,
#   'порно': 1,
#   'думаю': 1,
#   'преследовать': 1,
#   'закону': 1,
#   'бессмысленно': 1,
#   'интернет': 1,
#   'гигантская': 1,
#   'тёмная': 1,
#   'кротовая': 1,
#   'нора': 1,
#   'пожирает': 1,
#   'йоханссонактриса': 1,
#   'добавила': 1,
#   'защищать': 1,
#   'фотографии': 1,
#   'авторским': 1,
#   'правом': 1,
#   'означать': 1,
#   'стране': 1,
#   'правило': 1,
#   'распространяться': 1,
#   'сша': 1,
#   'попытки': 1,
#   'защититься': 1,
#   'интернета': 1,
#   'развращённости': 1,
#   'являются': 1,
#   'заведомо': 1,
#   'проигранной': 1,
#   'битвой': 1},
#  {'сравнению': 2,
#   'результатом': 1,
#   'продемонстрирован': 1,
#   'прошлом': 1,
#   'сумма': 2,
#   'увеличилась': 1,
#   'суммарные': 1,
#   'сборы': 1,
#   'кинотеатров': 2,
#   'российской': 1,
#   'федерации': 1,
#   'стран': 1,
#   'снг': 1,
#   'января': 3,
#   'увеличились': 1,
#   'показателем': 1,
#   'прошлого': 1,
#   'кинотеатры': 1,
#   'получили': 1,
#   'рублей': 3,
#   'рублейэтот': 1,
#   'показатель': 2,
#   'рекордным': 1,
#   'российских': 1,
#   'предыдущий': 1,
#   'самый': 1,
#   'большой': 1,
#   'составлял': 1,
#   'миллиона': 1,
#   'зафиксирована': 1,
#   'годасогласно': 1,
#   'предварительной': 1,
#   'информации': 1,
#   'лидером': 1,
#   'проката': 1,
#   'стала': 1,
#   'военная': 1,
#   'драма': 1,
#   'фильм': 2,
#   'заработал': 1,
#   'втором': 1,
#   'месте': 1,
#   'идёт': 1,
#   'полицейский': 1,
#   'рублёвки': 1,
#   'новогодний': 1,
#   'беспредел': 1,
#   'следом': 1,
#   'комедия': 1,
#   'ёлки': 1,
#   'последние': 1},
#  {'произошло': 1,
#   'изза': 1,
#   'команда': 2,
#   'работала': 1,
#   'интерактивным': 1,
#   'эпизодом': 1,
#   'шоу': 2,
#   'премьера': 1,
#   'продолжения': 1,
#   'запланирована': 1,
#   'годсоздатель': 1,
#   'чёрного': 2,
#   'зеркала': 2,
#   'чарли': 3,
#   'брукер': 3,
#   'рассказал': 1,
#   'создание': 1,
#   'интерактивного': 2,
#   'эпизода': 2,
#   'bandersnatch': 2,
#   'ощущалось': 1,
#   'работа': 1,
#   'четырьмя': 1,
#   'сериями': 1,
#   'одновременно': 1,
#   'осознавала': 1,
#   'поставлена': 1,
#   'непростая': 1,
#   'задача': 1,
#   'равно': 1,
#   'недооценила': 1,
#   'сообщает': 1,
#   'thrодна': 1,
#   'проблем': 1,
#   'заключалась': 1,
#   'начал': 1,
#   'писать': 1,
#   'сценарий': 1,
#   'месяцев': 1,
#   'распоряжении': 1,
# ...
#   'момент': 1,
#   'придерживается': 1,
#   'китайская': 1,
#   'фирма': 1,
#   'huawei': 1,
#   'выпускает': 1,
#   'honor': 1},
#  {'популярный': 1,
#   'китайский': 1,
#   'бренд': 1,
#   'готовит': 1,
#   'гибкое': 1,
#   'мобильное': 1,
#   'устройство': 2,
#   'особенность': 1,
#   'складывается': 2,
#   'сторонинсайдер': 1,
#   'эван': 1,
#   'бласс': 1,
#   'странице': 1,
#   'твиттереопубликовал': 1,
#   'видео': 1,
#   'первым': 1,
#   'складным': 1,
#   'смартфоном': 1,
#   'xiaomicant': 1,
#   'speak': 1,
#   'to': 1,
#   'the': 1,
#   'authenticity': 1,
#   'of': 1,
#   'this': 1,
#   'video': 1,
#   'or': 2,
#   'device': 1,
#   'but': 1,
#   'its': 1,
#   'allegedly': 1,
#   'made': 1,
#   'by': 1,
#   'xiaomi': 2,
#   'im': 1,
#   'told': 1,
#   'hot': 1,
#   'new': 1,
#   'phone': 1,
#   'gadget': 1,
#   'porn': 1,
#   'deepfake': 1,
#   'pictwittercomqwfogwief': 1,
#   'evan': 1,
#   'blass': 1,
#   'evleaks': 1,
#   'января': 1,
#   'гв': 1,
#   'ролике': 1,
#   'показано': 1,
#   'меняется': 1,
#   'интерфейс': 2,
#   'разложено': 1,
#   'сложено': 1,
#   'первом': 1,
#   'случае': 1,
#   'смартфон': 2,
#   'отображает': 1,
#   'планшет': 1,
#   'втором': 1,
#   'обычный': 1,
#   'ранее': 2,
#   'google': 1,
#   'анонсировала': 1,
#   'такую': 1,
#   'оптимизацию': 1,
#   'android': 1,
#   'складные': 1,
#   'смартфоныособенность': 1,
#   'аппарата': 1,
#   'сторон': 1,
#   'книжка': 1,
#   'название': 1,
#   'характеристики': 1,
#   'девайса': 1,
#   'неизвестны': 1,
#   'складном': 1,
#   'устройстве': 1,
#   'сообщалось': 1,
#   'известно': 1,
#   'смартфоны': 1,
#   'готовят': 1,
#   'samsung': 1,
#   'huawei': 1,
#   'lgsamsung': 1,
#   'показала': 1,
#   'складной': 1,
#   'дисплей': 1,
#   'infinity': 1,
#   'flex': 1,
#   'прототип': 1,
#   'гибкого': 1,
#   'мобильного': 1,
#   'устройства': 1,
#   'производитель': 1,
#   'позиционирует': 1,
#   'планшетом': 1,
#   'положить': 1,
#   'карман': 1},
#  {'исследователи': 2,
#   'выяснили': 1,
#   'срубленных': 1,
#   'праздник': 1,
#   'деревьев': 2,
#   'извлечь': 1,
#   'пользуучёные': 1,
#   'шеффилдского': 1,
#   'университета': 1,
#   'предложили': 1,
#   'утилизировать': 1,
#   'срубленные': 2,
#   'новый': 2,
#   'ёлкиисследователи': 1,
#   'нашли': 1,
#   'хвое': 1,
#   'вещества': 2,
#   'помогут': 1,
#   'производстве': 1,
#   'краски': 1,
#   'уксуса': 1,
#   'сладостей': 1,
#   'отметим': 1,
#   'ёлки': 1,
#   'выбрасываются': 1,
#   'предоставленным': 1,
#   'данным': 1,
#   'великобритании': 1,
#   'срубается': 1,
#   'семи': 1,
#   'ёлокпутём': 1,
#   'подогрева': 1,
#   'хвою': 1,
#   'разделить': 1,
#   'твёрдые': 2,
#   'жидкие': 1,
#   'жидких': 1,
#   'создавать': 1,
#   'сахара': 1,
#   'утверждают': 1,
#   'использовать': 1,
#   'производства': 1,
#   'биоугля': 1},
#  {'журналисты': 1,
#   'обнаружили': 1,
#   'посещения': 1,
#   'сайта': 1,
#   'устройств': 2,
#   'новой': 1,
#   'операционной': 2,
#   'системе': 2,
#   'appleapple': 1,
#   'занимается': 1,
#   'разработкой': 1,
#   'ios': 3,
#   'сообщило': 1,
#   'издание': 1,
#   'macrumorsресурс': 1,
#   'представил': 1,
#   'статистику': 1,
#   'посещений': 1,
#   'выяснилось': 1,
#   'сайт': 1,
#   'заходили': 1,
#   'визит': 1,
#   'сделан': 1,
#   'октябре': 1,
#   'ресурс': 1,
#   'посещали': 1,
#   'таких': 1,
#   'ноябре': 1,
#   'концу': 1,
#   'декабря': 1,
#   'показатель': 1,
#   'упалточной': 1,
#   'информации': 1,
#   'нововведениях': 1,
#   'следующей': 1,
#   'ожидается': 1,
#   'разработчики': 1,
#   'первую': 1,
#   'очередь': 1,
#   'усовершенствуют': 1,
#   'ipad': 1,
#   'примеру': 1,
#   'переделают': 1,
#   'приложение': 1,
#   'файлов': 1,
#   'добавят': 1,
#   'возможность': 2,
#   'открывать': 1,
#   'сразу': 1,
#   'окон': 1,
#   'приложения': 1,
#   'режиме': 1,
#   'многозадачностиверсия': 1,
#   'вышла': 1,
#   'сентября': 1,
#   'производитель': 1,
#   'внимания': 1,
#   'уделил': 1,
#   'удобности': 1,
#   'пользования': 1,
#   'одно': 1,
#   'нововведений': 1,
#   'контролировать': 1,
#   'отведённое': 1,
#   'мобильное': 1,
#   'устройство': 1},
#  {'полученной': 1,
#   'информации': 1,
#   'производитель': 1,
#   'электрокаров': 1,
#   'договаривается': 1,
#   'евросоюзом': 1,
#   'получении': 1,
#   'необходимых': 1,
#   'лицензийtesla': 1,
#   'планирует': 1,
#   'начать': 2,
#   'продажи': 2,
#   'model': 3,
#   'европе': 2,
#   'первом': 1,
#   'квартале': 1,
#   'сообщает': 1,
#   'bloomberg': 1,
#   'ссылкой': 1,
#   'источник': 1,
#   'пожелавший': 1,
#   'остаться': 1,
#   'неизвестнымкомпания': 1,
#   'надеется': 1,
#   'получить': 1,
#   'лицензию': 1,
#   'евросоюза': 1,
#   'продажу': 1,
#   'электромобиля': 1,
#   'ожидается': 1,
#   'сделка': 1,
#   'завершена': 1,
#   'ближайшее': 1,
#   'важных': 1,
#   'сотрудников': 1,
#   'автоконцерна': 1,
#   'выйдут': 1,
#   'отпуска': 1,
#   'доведут': 1,
#   'дело': 1,
#   'концаранее': 1,
#   'владелец': 1,
#   'компании': 1,
#   'илон': 1,
#   'маск': 1,
#   'сообщал': 1,
#   'планах': 1,
#   'китае': 1,
#   'приоритетная': 1,
#   'задача': 1,
#   'предприниматель': 1,
#   'беспокоиться': 1,
#   'насчёт': 1,
#   'налогов': 1,
#   'сшаранее': 1,
#   'поставил': 1,
#   'рекорд': 1,
#   'гоночном': 1,
#   'треке': 1,
#   'электрокар': 1,
#   'вторым': 1,
#   'laguna': 1,
#   'seca': 1,
#   'показав': 1,
#   'результат': 1,
#   'мин': 1,
#   'сек': 1,
#   'секунды': 1,
#   'быстрее': 1,
#   'заезд': 1,
#   'tesla': 1,
#   's': 1,
#   'pd': 1},
#  {'компания': 1,
#   'ожидает': 1,
#   'прибыль': 1,
#   'ожидаемого': 1,
#   'сообщает': 2,
#   'слабых': 1,
#   'продажах': 1,
#   'смартфонов': 1,
#   'прямо': 1,
#   'повлияло': 1,
#   'стоимость': 1,
#   'биржеакции': 1,
#   'apple': 3,
#   'упали': 1,
#   'открытии': 1,
#   'торгов': 1,
#   'bloomberg': 1,
#   'причиной': 2,
#   'стало': 1,
#   'ухудшение': 1,
#   'прогноза': 1,
#   'выручке': 1,
#   'изза': 2,
#   'снижения': 2,
#   'спроса': 1,
#   'продукцию': 1,
#   'компанииранее': 1,
#   'тим': 1,
#   'кук': 1,
#   'разослал': 1,
#   'письма': 1,
#   'инвесторам': 1,
#   'предупредил': 1,
#   'снижении': 1,
#   'прибыли': 1,
#   'неудовлетворительных': 1,
#   'показателей': 1,
#   'продаж': 1,
#   'скорректировала': 1,
#   'ожидаемый': 1,
#   'доход': 1,
#   'квартал': 1,
#   'миллиардов': 1,
#   'долларов': 1,
#   'миллиардовглавной': 1,
#   'доходов': 1,
#   'топменеджер': 1,
#   'назвал': 1,
#   'торговую': 1,
#   'войну': 1,
#   'китаем': 1,
#   'отметил': 1,
#   'нежелание': 1,
#   'пользователей': 1,
#   'обновлять': 1,
#   'смартфон': 1,
#   'выбор': 1,
#   'замены': 1,
#   'аккумулятора': 1,
#   'напомним': 1,
#   'процедура': 1,
#   'устраняет': 1,
#   'баги': 1},
#  {'ранее': 2,
#   'чипмейкер': 1,
#   'выиграл': 1,
#   'компании': 2,
#   'купертино': 3,
#   'дело': 1,
#   'нарушении': 2,
#   'патентных': 1,
#   'прав': 1,
#   'германиипроизводитель': 1,
#   'процессоров': 1,
#   'смартфонов': 2,
#   'qualcomm': 3,
#   'внёс': 1,
#   'обеспечительный': 1,
#   'платёж': 1,
#   'размере': 1,
#   'миллиарда': 1,
#   'евро': 1,
#   'вступления': 1,
#   'силу': 1,
#   'запрета': 1,
#   'продажи': 3,
#   'iphone': 1,
#   'x': 1,
#   'германии': 1,
#   'сообщается': 1,
#   'прессрелизе': 1,
#   'официальном': 1,
#   'сайтеранее': 1,
#   'apple': 2,
#   'проиграла': 1,
#   'суд': 2,
#   'чипмейкером': 1,
#   'стране': 1,
#   'признал': 1,
#   'производителя': 1,
#   'виновным': 1,
#   'патента': 2,
#   'принял': 1,
#   'решение': 1,
#   'запретить': 1,
#   'некоторых': 1,
#   'моделей': 2,
#   'территории': 1,
#   'странысообщается': 1,
#   'нарушили': 1,
#   'чипмейкера': 1,
#   'связан': 1,
#   'возможностью': 1,
#   'редактирования': 1,
#   'фото': 1,
#   'управлением': 1,
#   'приложениями': 1,
#   'помощью': 1,
#   'сенсоров': 1,
#   'экранав': 1,
#   'признают': 1,
#   'вину': 1,
#   'намерены': 1,
#   'подать': 1,
#   'апелляцию': 1,
#   'компания': 1,
#   'согласилась': 1,
#   'прекратить': 1,
#   'указанных': 1,
#   'официальных': 1,
#   'магазинах': 1,
#   'германиипатентное': 1,
#   'разбирательство': 1,
#   'главных': 1,
#   'скандалов': 1,
#   'лайф': 1,
#   'вспомнил': 1,
#   'самых': 1,
#   'важных': 1,
#   'конфликтов': 1,
#   'индустрии': 1,
#   'технологий': 1,
#   'минувшем': 1},
#  {'эксперты': 2,
#   'усомнились': 2,
#   'снижение': 1,
#   'спроса': 2,
#   'iphone': 3,
#   'вызвано': 1,
#   'торговой': 2,
#   'войной': 2,
#   'конкуренты': 1,
#   'китая': 1,
#   'стали': 1,
#   'привлекательнымианалитики': 1,
#   'назвали': 1,
#   'причины': 1,
#   'падения': 1,
#   'акций': 3,
#   'apple': 5,
#   'сообщает': 1,
#   'bbc': 2,
#   'напомним': 1,
#   'цена': 2,
#   'компании': 3,
#   'бирже': 1,
#   'обвалилась': 1,
#   'открытии': 1,
#   'торговв': 1,
#   'первую': 1,
#   'очередь': 1,
#   'причинах': 1,
#   'снижения': 2,
#   'ранее': 1,
#   'генеральный': 1,
#   'директор': 1,
#   'тим': 1,
#   'кук': 1,
#   'послужили': 1,
#   'торговая': 1,
#   'война': 1,
#   'нежелание': 1,
#   'пользователей': 1,
#   'обновляться': 1,
#   'старых': 1,
#   'моделей': 1,
#   'связывал': 1,
#   'проблемами': 1,
#   'американской': 1,
#   'китайской': 1,
#   'экономик': 1,
#   'настали': 1,
#   'новые': 1,
#   'времена': 1,
#   'аналитик': 2,
#   'сектора': 1,
#   'высоких': 1,
#   'технологий': 1,
#   'сэм': 1,
#   'рейнольдснапряжённые': 1,
#   'отношения': 1,
#   'сша': 1,
#   'китаем': 1,
#   'обострили': 1,
#   'ситуацию': 2,
#   'главной': 1,
#   'причиной': 1,
#   'стало': 1,
#   'развитие': 1,
#   'китайских': 1,
#   'производителей': 1,
#   'смартфонов': 1,
#   'oppo': 1,
#   'xiaomi': 1,
#   'huawei': 1,
#   'главное': 1,
#   'преимущество': 1,
#   'устройств': 1,
#   'идеальное': 1,
#   'соотношение': 1,
#   'цены': 2,
#   'качествапо': 1,
#   'словам': 1,
#   'собеседников': 1,
#   'падение': 1,
#   'связать': 1,
#   'неудачной': 1,
#   'ценовой': 1,
#   'политикой': 1,
#   'смартфоны': 1,
#   'стоят': 1,
#   'дороже': 1,
#   'прямых': 1,
#   'конкурентов': 1,
#   'являются': 1,
#   'незначительно': 1,
#   'улучшенными': 1,
#   'вариантами': 1,
#   'предшественников': 1,
#   'предлагают': 1,
#   'радикальных': 1,
#   'инноваций': 1,
#   'инвесторы': 1,
#   'попробуют': 1,
#   'понять': 1,
#   'насколько': 1,
#   'сильно': 1,
#   'агрессивная': 1,
#   'ценовая': 1,
#   'политика': 1,
#   'усугубила': 1,
#   'повлияет': 1,
#   'долгосрочные': 1,
#   'перспективы': 1,
#   'удерживать': 1,
#   'высокие': 1,
#   'atlantic': 1,
#   'equities': 1,
#   'джеймс': 1,
#   'кордуэллсамый': 1,
#   'дорогой': 1,
#   'xs': 1,
#   'max': 1,
#   'минимальная': 1,
#   'стоимость': 1,
#   'россии': 1,
#   'руб': 1,
#   'указывается': 1,
#   'сайте': 1,
#   'максимальная': 1,
#   'модификацию': 1,
#   'гб': 1},
#  {'мнению': 2,
#   'эксперта': 2,
#   'следующий': 1,
#   'смартфон': 2,
#   'apple': 6,
#   'удивит': 1,
#   'новыми': 1,
#   'возможностями': 1,
#   'попрежнему': 1,
#   'стоить': 1,
#   'гораздо': 1,
#   'дороже': 2,
#   'androidконкурентованалитик': 1,
#   'atherton': 1,
#   'research': 1,
#   'джин': 1,
#   'баптист': 1,
#   'надеется': 1,
#   'iphone': 5,
#   'получит': 2,
#   'внутриэкранный': 2,
#   'сканер': 3,
#   'отпечатка': 2,
#   'порт': 1,
#   'usbc': 1,
#   'быстрой': 1,
#   'зарядкой': 1,
#   'уменьшенную': 1,
#   'чёлку': 1,
#   'сообщил': 1,
#   'forbesпо': 1,
#   'данным': 1,
#   'дизайн': 1,
#   'нового': 1,
#   'смартфона': 1,
#   'создан': 1,
#   'основе': 1,
#   'x': 2,
#   'изменения': 1,
#   'отличие': 1,
#   'серии': 1,
#   'xs': 2,
#   'отмечается': 1,
#   'новый': 1,
#   'конкурентов': 1,
#   'androidнапомним': 1,
#   'отказалась': 1,
#   'сканера': 1,
#   'заменив': 1,
#   'лица': 1,
#   'face': 1,
#   'id': 1,
#   'датчик': 2,
#   'стоит': 1,
#   'некоторых': 1,
#   'androidсмартфонах': 1,
#   'отличается': 1,
#   'надёжностью': 1,
#   'оптический': 1,
#   'ультразвуковой': 1,
#   'представила': 1,
#   'qualcomm': 1,
#   'подобный': 1,
#   'стоять': 1,
#   'galaxy': 1,
#   'sакции': 1,
#   'упали': 1,
#   'бирже': 1,
#   'слов': 1,
#   'тима': 1,
#   'кука': 1,
#   'компания': 1,
#   'выручку': 1,
#   'ожидаемого': 1,
#   'первом': 1,
#   'квартале': 1,
#   'аналитиков': 1,
#   'основная': 1,
#   'причина': 1,
#   'снижения': 1,
#   'спроса': 1,
#   'завышенные': 1,
#   'цены': 1,
#   'самый': 1,
#   'дорогой': 1,
#   'max': 1,
#   'минимальная': 1,
#   'стоимость': 1,
#   'россии': 1,
#   'руб': 2,
#   'указывается': 1,
#   'сайте': 1,
#   'максимальная': 1,
#   'цена': 1,
#   'модификацию': 1,
#   'гб': 1},
#  {'windows': 1, 'появятся': 1, 'смайлики': 1, 'иероглифов': 1},
#  {'мире': 1, 'вебсайт': 1, 'запустили': 1},
#  {'steam': 1, 'перестанет': 1, 'работать': 1, 'старых': 1, 'mac': 1},
#  {'появилось': 1,
#   'пятно': 1,
#   'пользователи': 1,
#   'ipad': 1,
#   'pro': 1,
#   'жалуются': 1,
#   'дефект': 1,
#   'экрана': 1},
#  {'смартфоны': 1,
#   'одежда': 1,
#   'фастфуд': 1,
#   'названы': 1,
#   'любимых': 1,
#   'брендов': 1,
#   'россиян': 1},
#  {'обновление': 1, 'пользовательского': 1, 'соглашения': 1},
#  {'facebook': 1,
#   'начал': 1,
#   'делить': 1,
#   'сми': 1,
#   'фейковые': 1,
#   'нефейковые': 1},
#  {'названо': 1, 'какие': 1, 'ipad': 1, 'apple': 1, 'выпустит': 1},
#  {'нормально': 1,
#   'apple': 1,
#   'прокомментировали': 1,
#   'ситуацию': 1,
#   'гнущимися': 1,
#   'ipad': 1,
#   'pro': 1},
#  {'xiaomi': 1,
#   'представила': 1,
#   'молодёжный': 1,
#   'смартфон': 1,
#   'c': 1,
#   'градиентным': 1,
#   'корпусом': 1},
#  {'google': 1, 'стала': 1, 'обжаловать': 1, 'штраф': 1, 'роскомнадзора': 1},
#  {'матвиенко': 1,
#   'объяснила': 1,
#   'необходимость': 1,
#   'закона': 1,
#   'суверенном': 1,
#   'рунете': 1},
#  {'samsung': 1,
#   'galaxy': 1,
#   'note': 1,
#   'получит': 1,
#   'увеличенный': 1,
#   'дисплей': 1},
#  {'хакеры': 1,
#   'выводят': 1,
#   'строя': 1,
#   'компьютеры': 1,
#   'windows': 1,
#   'помощью': 1,
#   'ошибки': 1,
#   'chrome': 1},
#  {'яндекс': 1, 'выяснил': 1, 'покупают': 1, 'россияне': 1, 'новому': 1},
#  {'одноклассники': 1, 'назвали': 1, 'главные': 1, 'события': 1},
#  {'fortnite': 1, 'стала': 1, 'обсуждаемой': 1, 'игрой': 1, 'twitter': 1},
#  {'цена': 1, 'playstation': 1, 'pro': 1, 'рухнула': 1, 'россии': 1},
#  {'названы': 1,
#   'причины': 1,
#   'выпуска': 1,
#   'декабре': 1,
#   'большинства': 1,
#   'мобильных': 1,
#   'игр': 1},
#  {'вконтакте': 1,
#   'выплатила': 1,
#   'млрд': 1,
#   'рублей': 1,
#   'разработчикам': 1,
#   'игр': 1},
#  {'названы': 1,
#   'самые': 1,
#   'высокооплачиваемые': 1,
#   'российские': 1,
#   'youtubeблогеры': 1},
#  {'мстители': 1,
#   'конечностей': 1,
#   'названы': 1,
#   'самые': 1,
#   'смешные': 1,
#   'запросы': 1,
#   'яндексе': 1},
#  {'яндекс': 1, 'удалил': 1, 'telegram': 1, 'поисковой': 1, 'выдачи': 1},
#  {'эксперты': 1,
#   'россияне': 1,
#   'заинтересованы': 1,
#   'iphone': 1,
#   'покупают': 1,
#   'китайские': 1,
#   'смартфоны': 1},
#  {'ikea': 1,
#   'выпустила': 1,
#   'инструкцию': 1,
#   'сборке': 1,
#   'салата': 1,
#   'оливье': 1},
#  {'смартфоны': 1,
#   'планшеты': 1,
#   'умные': 1,
#   'часы': 1,
#   'названы': 1,
#   'лучшие': 1,
#   'подарки': 1,
#   'новый': 1},
#  {'москвичи': 1, 'стали': 1, 'заказывать': 1, 'еду': 1, 'дом': 1},
#  {'снег': 1,
#   'замри': 1,
#   'советов': 1,
#   'сделать': 1,
#   'снежный': 1,
#   'фотошедевр': 1},
#  {'названы': 1,
#   'самые': 1,
#   'популярные': 1,
#   'среди': 1,
#   'интернетпиратов': 1,
#   'фильмы': 1},
#  {'вконтакте': 1, 'иван': 1, 'ургант': 1, 'переформатируют': 1, 'клевер': 1},
#  {'запрет': 1,
#   'iphone': 1,
#   'утечка': 1,
#   'данных': 1,
#   'главные': 1,
#   'скандалы': 1,
#   'индустрии': 1,
#   'технологий': 1},
#  {'путин': 1,
#   'мстители': 1,
#   'элджей': 1,
#   'названы': 1,
#   'главные': 1,
#   'темы': 1,
#   'вконтакте': 1},
#  {'nokia': 1, 'пятью': 1, 'камерами': 1, 'появился': 1, 'видео': 1},
#  {'huawei': 1,
#   'представила': 1,
#   'бюджетный': 1,
#   'смартфон': 1,
#   'сканера': 1,
#   'отпечатка': 1},
#  {'неймар': 1,
#   'променял': 1,
#   'празднование': 1,
#   'нового': 1,
#   'игру': 1,
#   'fortnite': 1},
#  {'whatsapp': 1,
#   'перестанет': 1,
#   'работать': 1,
#   'некоторых': 1,
#   'телефонах': 1},
#  {'цукерберг': 1,
#   'продал': 1,
#   'акции': 1,
#   'facebook': 1,
#   'лечить': 1,
#   'эпилепсию': 1,
#   'болезнь': 1,
#   'паркинсона': 1},
#  {'обновление': 1, 'пользовательского': 1, 'соглашения': 1},
#  {'apple': 1,
#   'предупредила': 1,
#   'инвесторов': 1,
#   'замедлении': 1,
#   'темпов': 1,
#   'продаж': 1,
#   'iphone': 1},
#  {'steam': 1, 'поддерживает': 1, 'старые': 1, 'версии': 1, 'windows': 1},
#  {'роналду': 1,
#   'рекордсменом': 1,
#   'числу': 1,
#   'подписчиков': 1,
#   'instagram': 1},
#  {'смартфоны': 1,
#   'redmi': 1,
#   'компании': 1,
#   'xiaomi': 1,
#   'станут': 1,
#   'отдельным': 1,
#   'брендом': 1},
#  {'складной': 1, 'xiaomi': 1, 'появился': 1, 'видео': 1},
#  {'учёные': 1,
#   'нашли': 1,
#   'способ': 1,
#   'превращать': 1,
#   'новогодние': 1,
#   'ёлки': 1,
#   'сладости': 1},
#  {'подтверждения': 1, 'apple': 1, 'занимается': 1, 'разработкой': 1, 'ios': 1},
#  {'tesla': 1,
#   'готовится': 1,
#   'начать': 1,
#   'продажи': 1,
#   'электромобиля': 1,
#   'model': 1,
#   'европе': 1},
#  {'акции': 1,
#   'apple': 1,
#   'упали': 1,
#   'изза': 1,
#   'провально': 1,
#   'низких': 1,
#   'продаж': 1,
#   'iphone': 1},
#  {'qualcomm': 1,
#   'заплатила': 1,
#   'млрд': 1,
#   'евро': 1,
#   'запрет': 1,
#   'продаж': 1,
#   'iphone': 1},
#  {'настали': 1,
#   'новые': 1,
#   'времена': 1,
#   'аналитики': 1,
#   'назвали': 1,
#   'причину': 1,
#   'падения': 1,
#   'акций': 1,
#   'apple': 1},
#  {'touch': 1,
#   'id': 1,
#   'экране': 1,
#   'usbc': 1,
#   'аналитик': 1,
#   'назвал': 1,
#   'нововведения': 1,
#   'iphone': 1}]

# %%
def perplexity(do, frequencies_empirical):
    out_of_dict = []

    tmp_sum_docs = 0.0
    N = 0.0
    docs = np.array(do)
    for i, doc in enumerate(docs):
        tmp_sum_words = 0.0
        for word in doc:
            freq = frequencies.get(word, TOL)
            freq_empirical = frequencies_empirical[i].get(word, 0.0)
            N += freq_empirical
            if freq == TOL:
                out_of_dict.append(word)
            tmp_sum_words += freq_empirical * np.log(freq)
        tmp_sum_docs += tmp_sum_words

    return np.exp(-tmp_sum_docs / N), out_of_dict

# %%
perp, ood = perplexity(docs_, perp)

print(perp)
# Out:
# 48372406.7414305

# %%
print(np.unique(ood))
# Out:
# ['academeg' 'albums' 'allegedly' ... 'японороссийского'
#  'ёлкиисследователи' 'ёлокпутём']

# %%
for i in np.unique(ood):
    print(i)
# Out:
# academeg
# albums
# allegedly
# alliances
# amazon
# amd
# amoledэкранов
# analityca
# android
# androidконкурентованалитик
# androidнапомним
# androidсмартфонах
# anesthetic
# animationласк
# app
# apple
# appleapple
# applequalcomm
# appleкомпания
# appsflyerотмечается
# asus
# atherton
# atlantic
# authenticity
# award
# aсмартфон
# bafta
# bandersnatch
# bbc
# bellsкомпания
# birdboxchallenge
# bittorrentлидером
# blass
# bleeping
# bloomberg
# bluray
# bmw
# bosch
# branch
# bros
# bustleпевица
# cambridge
# capitan
# cartoonbrewновый
# cern
# chanel
# chinaсмартфон
# christmas
# chrome
# clarks
# cnbcпо
# cnnдаалдер
# cocacola
# cohesion
# colliderджилленхол
# comicbookв
# competition
# computerзлоумышленники
# confidence
# darth
# dataсервисы
# dedicates
# deepfake
# deepfakeгазета
# device
# dick
# disney
# dups
# dupsпопулярная
# dпринтера
# dпринтере
# emui
# equities
# estado
# eurogamer
# evan
# eve
# evleaks
# ewстахелски
# exact
# facebook
# fandango
# fandangoпервое
# flex
# forbes
# forbesв
# forbesпо
# fortnite
# frank
# freddie
# gadget
# galaxy
# gddr
# giz
# gizmochinaгенеральный
# godгитарист
# goldenglobes
# gps
# groupизвестно
# gsmarenaвнешне
# gta
# halls
# hbo
# hd
# hdr
# helio
# hermitage
# hitech
# hmd
# hollywood
# horizons
# httpinfocernchhypertextwwwtheprojecthtml
# huawei
# ikea
# imac
# inches
# inchesnote
# inchess
# infinity
# infocernch
# instagram
# institutional
# integrity
# ios
# ipad
# iphone
# iphoneapple
# iphoneв
# ipадреса
# itunes
# jaguar
# jingle
# joy
# kyleofasgard
# kyodo
# laguna
# lamb
# lament
# lcdсмартфон
# ledленты
# lgsamsung
# liferu
# linkin
# lionsgate
# lite
# mac
# macbook
# macos
# macrumorsна
# macrumorsресурс
# mailru
# malek
# malwarebytes
# mario
# marvel
# mavericks
# mcdonald
# mediascope
# mediatek
# medvedevrussia
# melodies
# mercedes
# mercury
# metacritic
# microsd
# microsoft
# microusb
# mirrorизвестность
# mountain
# mozilla
# mtvnews
# nerd
# netflix
# newsoneв
# newsru
# nike
# ninja
# ninjaсогласно
# nokia
# noodlecake
# oppo
# oreo
# otakaraинформации
# overwatch
# pandao
# patriot
# pauloсообщается
# pd
# pencil
# philips
# phone
# pictwittercomdlwwwwas
# pictwittercomqwfogwief
# pieожидается
# playstation
# pokemon
# polities
# porn
# puma
# puredisplay
# pureview
# qhd
# qualcomm
# radeon
# redmi
# reebok
# reporter
# reporterиздание
# rip
# rocking
# rotten
# russiaкомпанию
# ryan
# sakha
# samsung
# sao
# scmpречь
# screenrantпри
# screens
# script
# seca
# shallow
# sheena
# smartтелевизорах
# sms
# snapdragon
# sony
# sonyисследователи
# spice
# spidey
# spideybells
# splashreportнад
# spoken
# staying
# steam
# stin
# studios
# summit
# sunгринт
# supa
# sакции
# tamaras
# telecom
# telegram
# telegramorg
# telegramru
# telegramэто
# tesla
# thingiverse
# thingiverseyoutubeблогер
# thrво
# thrодна
# thrпродолжение
# thrфайги
# thule
# tomatoes
# torrentfreaks
# toysreview
# tvвыбор
# twitch
# twitter
# twitterаккаунтая
# twitterджеймс
# unchained
# uncharted
# undercut
# universeice
# url
# usbc
# vader
# varietyдля
# varietyсамой
# vergeразработчики
# vinci
# vista
# walt
# wannabe
# warner
# washington
# whatsapp
# wide
# wwwliferu
# wylsacom
# xiaomi
# xiaomicant
# xiaomiтреть
# xp
# xs
# xserve
# xxiii
# york
# yosemiteединственным
# youtube
# youtubeблогеры
# youtubeканале
# zara
# zdf
# zeiss
# zte
# ×обновление
# абонентовв
# абонентоводнозначное
# абэ
# авдотьи
# авторранее
# аглая
# аграрнопромышленного
# агрегирующем
# адамс
# адель
# адиль
# азимутах
# академиейсписки
# аквамен
# аквамена
# аквамену
# акимов
# акинфеева
# аккаунта
# аккаунты
# аккаунтымессенджер
# аксёнова
# актёромлучшей
# аладдин
# аладдина
# албин
# албина
# алекс
# александра
# александром
# алексея
# алехандро
# алиэкспресс
# алоизиу
# альбертхолле
# альваргонсалес
# альфонсо
# альянсах
# альянсомизвестный
# америкеаналитики
# амиран
# амплуасвой
# анатолийское
# андервуда
# андерс
# андрей
# анимационным
# анкара
# аннабель
# анны
# антикиллер
# антирейтинга
# антисемитах
# антиутопичных
# антон
# антона
# антоне
# апексимова
# апрелятакже
# араужу
# арби
# армен
# армении
# армения
# артемис
# арттеатра
# арттеатре
# артура
# артём
# артёме
# атанасян
# атим
# ауг
# аудиоколонки
# аудиооборудованиемчисло
# аудиториюрежиссёры
# аудиториясоцсеть
# аэс
# бабичев
# багом
# баллок
# бандерснэтч
# бандерснэтче
# барбилэнд
# барри
# барселоны
# басковна
# баталон
# батхёрстом
# беглов
# безрукова
# безрукову
# бейл
# бекмамбетов
# беларусь
# белоруссии
# белоруссию
# белоруссия
# бельгия
# беннингтон
# беннингтона
# беннингтоном
# берлину
# бернерсли
# берра
# берром
# берёзканапомним
# бесконечностисогласно
# беспредметныранее
# бешаный
# бибисиальбом
# бидвелл
# бизнеследи
# билайн
# билайна
# билал
# билан
# билана
# биланом
# билану
# биллом
# биомедицинскими
# биоугля
# биржеакции
# битвысоциальная
# биткоина
# бласс
# блогер
# блогеров
# блогером
# блогеру
# блогеры
# блокбастером
# блоковые
# богатыряглавным
# богемская
# болсонару
# больницыюрий
# бонда
# бондаренкомихаил
# борис
# бортником
# бразилии
# бразилию
# бразилия
# брайан
# брайана
# браудер
# браудера
# брендах
# бродвеев
# брукер
# будеттакже
# бузоважители
# бутиной
# бутину
# бэмбиласк
# бёргер
# бёрнетт
# вадим
# вакарчук
# валентин
# валентина
# вампилова
# вантакже
# ванунапомним
# ваньчжоу
# варежкилучше
# ватсонасценарий
# ваттдевайс
# вашингтон
# вашингтона
# вверхфонд
# вверхэкспертный
# ввязал
# вгик
# вебверсии
# вебсайт
# вебстранице
# вебстраницы
# вейдер
# вейдера
# вейдеру
# великобритании
# вендора
# венесуэлой
# венома
# версииранее
# весныроссийский
# видеоблогер
# видеообращение
# видеообращении
# видоизменённый
# визитомглава
# виктор
# вилланель
# виталий
# виталия
# вицегубернатор
# вицегубернаторов
# вицегубернаторы
# вицепрезидент
# вицепремьер
# вицепремьерами
# вконтакте
# вконтактевконтакте
# вконтактеосновным
# влагина
# владивостоке
# владимира
# владимирапричины
# владимирович
# владимиром
# владимиру
# внесённым
# внимательнонапример
# внутриэкранный
# военновоздушных
# военноисторического
# возмущённую
# возмущённым
# волнуютзеленский
# волнуютизвестный
# володин
# воплощениетаким
# вопросовбольшая
# воробьякомпания
# врагавсего
# времениfacebook
# времянапомним
# вспышкувстроенная
# встречуранее
# вциом
# выдержкуснежинки
# вымышленысуд
# выходанапомним
# выходилфанатов
# вышесамо
# вьетнама
# вьетнамаhuawei
# вэф
# вячеслав
# гавайях
# гаджета
# гадот
# гадотнапомним
# галина
# ганна
# гарри
# гаспарян
# гаспарянпо
# гб
# гбайт
# гблогер
# геймеровтакже
# генриха
# генсекретаря
# геоштормрейтинг
# геракл
# германииapple
# германиипатентное
# германиипроизводитель
# гироскутеры
# гиф
# гифок
# гленн
# глучшим
# годав
# годадействие
# годаинформацию
# годакомпания
# годана
# годапо
# годапопулярная
# годасогласно
# годасреди
# годасъёмки
# годкомпания
# годсоздатель
# годуapple
# годув
# годувместе
# годуна
# годуодин
# годуожидается
# годупервое
# годупредположительно
# годурежиссёр
# годуресурс
# годуроссийское
# годучто
# годфильмы
# голливуд
# голливуде
# голосовчто
# гомес
# гонолулу
# горбачёва
# гордоном
# городаигорь
# городецком
# госдуме
# госдуму
# госизмену
# государствакак
# государстваокружной
# госуправлением
# готти
# григорий
# григория
# григоровича
# гриндевальда
# гринт
# гринта
# гринтпо
# гринч
# гринчроссийская
# гришки
# грязичернышов
# губернаторамикроме
# гурцкая
# гурцкаяглава
# даалдер
# давыдов
# дамбо
# дании
# данилин
# данныемарк
# дарт
# дарта
# дартаньян
# дартаньяна
# дебютировавших
# действийтот
# действияпока
# декабряпосвящённый
# декстер
# деластудия
# денис
# дениса
# деньгизапреты
# деппа
# деппе
# десктопной
# десяткусреди
# джабаров
# джавад
# джедая
# джейк
# джейкоб
# джейми
# джеймс
# джеймса
# джеймсу
# джейсон
# дженнингса
# джеремайя
# джессика
# джея
# джилленхол
# джо
# джоанна
# джона
# джонни
# джонс
# джонсон
# джордан
# джорджа
# джорджи
# джулией
# джуманджи
# дианы
# дикси
# дима
# диме
# диму
# димы
# динамичнойбыло
# диснеем
# диснеемв
# диспетчере
# дмитрием
# дмитрий
# добрыгин
# добрыгина
# добрыгиналента
# довериес
# дойла
# дойлакомпания
# докторв
# долларованалитики
# долларовна
# долларовспециалисты
# домакалкин
# домогательствахвы
# дональда
# дональде
# дональдом
# донбасс
# дорожающую
# доставщика
# достоинствунапомним
# дрейка
# дроздова
# дроздованапомним
# дрсмд
# другиеактёр
# другиедыховичный
# другиекроме
# дудь
# дуров
# дуровапри
# дуровы
# дыховичного
# дыховичный
# дэвид
# дэвида
# дэдпул
# дэдпула
# дюймаранее
# еаэс
# евгения
# евразэс
# евровидение
# европа
# евросоюз
# евросоюза
# евросоюзом
# екатеринбурга
# елизаветы
# ереван
# есминистр
# естьтем
# жаир
# женеве
# женойкинорежиссёр
# женыпожилых
# жером
# животнымипоисковик
# жизнипрощание
# жизньпомимо
# жилбыл
# жуковпо
# журналовкак
# зависимостинапомним
# зависимостироссийский
# загрузках
# задорнов
# задорнова
# законодательствеотмечается
# замалчиваетсясогласно
# занимаютсяещё
# записейнапомним
# запретовнапомним
# запросовв
# зариф
# заставляетнапомним
# збигнев
# збигневу
# зеленский
# зеленского
# зидан
# зинаид
# зрителейв
# зрителейэтот
# зрителямтакже
# зрк
# зубкак
# иванно
# ивановыивановы
# игорь
# игоря
# игрыв
# игрытакже
# известнонапомним
# известныдата
# изогнутымитопменеджер
# израиле
# илон
# ильдар
# ильи
# ильича
# индиана
# инсайдер
# инстаграм
# инстаграмах
# инстаграме
# инстаграметакже
# интереснойэксперты
# интереснымпро
# интернетапервый
# интернетепо
# интернетероскомнадзор
# интернетмагазинамотмечается
# интернетмагазинов
# интернетмагазины
# интернетпиратов
# интернетпортал
# интернетресурс
# интернетсайтов
# интерфаксу
# интригановизбрание
# информациюранее
# ираке
# ирана
# иране
# ираном
# искоренитьлоза
# искреннимфрэнком
# йоргоса
# йорма
# йоханссон
# йоханссонактриса
# каваикак
# какимилибо
# какихлибо
# какихто
# какоголибо
# какомто
# калинин
# калинина
# калининграде
# калининым
# калкин
# калкина
# камерамисудя
# канаде
# каналапо
# каналароли
# каомодзи
# кардашьян
# карди
# карнахан
# категорияхбританская
# кацуюки
# качегарки
# качествапо
# квайгон
# квинн
# кевин
# кевина
# келли
# кельми
# кемерове
# кемеровскую
# керченском
# керчи
# кеше
# кибератак
# кибератакам
# кибератаках
# кибератакой
# кибербезопасности
# кибервозможности
# киберкомандования
# кибернападения
# кибероперациями
# киберпростанстве
# киберспорту
# киберугроз
# киберугрозу
# киберугрозы
# кибершпионажа
# киева
# киеве
# киллеренеудачнике
# киндзадза
# кинематографистовкак
# кинематографистовсообщается
# кинокартинкомпания
# кинокартиныглава
# кинопоиск
# кинопоиске
# кинопроектам
# киносовокупные
# кириенко
# кирилла
# киркоров
# китае
# китаем
# китаемснижение
# китаефильм
# китая
# китаяпремьерминистр
# кларком
# кларксон
# кларксонтелевизионный
# клиентовблокировка
# кликклакранее
# клоуз
# кндр
# кнр
# коап
# когото
# кожемяко
# козлова
# коламбус
# колман
# колумбия
# командысоздатель
# комарова
# комедиямюзикл
# комиксовактёры
# компаниив
# компаниивладельцы
# компанииназначения
# компанииранее
# конана
# кондал
# конкурсеполнометражный
# коннолли
# константин
# константина
# контрмерам
# концаранее
# кордуэллсамый
# кореи
# коррупциейпо
# корякский
# косачёв
# котляковском
# коттапри
# крайвпрочем
# крайовой
# кракова
# краснодара
# красовский
# красовскогосвой
# кремлякроме
# кремляон
# кремлятак
# криптовалютам
# крис
# криса
# кристен
# кристиан
# криштиану
# куарон
# кувшинова
# кука
# культурнообразовательных
# купертино
# курильские
# кускова
# кушнерёв
# кушнерёва
# кэмпбелл
# лайфа
# лайфаранее
# лайфв
# лайфом
# лайфу
# ламли
# лантимоса
# лдпр
# леви
# ленинград
# ленинграда
# ленинграде
# ленобласти
# лентысюжет
# лентытелеканал
# летмихаил
# летомкогда
# летпервое
# лещенко
# лидераглобальный
# лидервсе
# лидерлукашенко
# линча
# лионель
# лицензийtesla
# личностиактриса
# лондона
# лондонасогласно
# лондоне
# лосанджелес
# лосанджелеса
# лосанджелесе
# лоуренс
# лоуренсомсогласно
# лоури
# лукашенко
# лукашина
# лукьяненко
# лукьяненкопо
# лучшепрессконференция
# любимыхбывший
# магдалена
# магнитогорске
# майком
# макарьева
# макбук
# маккаллистеркак
# маккарти
# маколей
# мамаиван
# манафорта
# манделы
# манёвртема
# марвел
# марвела
# марию
# маркасвященнослужитель
# маркетплейса
# маркетплейсе
# марком
# маркониклевер
# маркус
# марлен
# марлена
# марокко
# мартином
# мартынович
# маршани
# масленников
# матвиенко
# матильда
# матные
# матьнекоторые
# мацуев
# машков
# машкову
# мегердичева
# медведева
# медведеввместо
# медведевкак
# медведевпо
# медведчук
# медведчукасуд
# медикимарлен
# мексика
# меликян
# мельникова
# мемов
# мемом
# меньшиков
# мерытеперь
# месопотамии
# мессенджер
# мессенджера
# мессенджерав
# месси
# месяцевнапомним
# мид
# микроблоге
# миллер
# миллиардовглавной
# милонов
# минкультуры
# минск
# минска
# минску
# миссурипользователи
# миссурирейтинг
# мистерио
# михаил
# михаила
# михеев
# мишель
# мнениятакое
# многозадачностиверсия
# мовчан
# моджахеддинэ
# моди
# мозгмашины
# мокрецова
# молодятся
# моментомвы
# момоа
# монсанто
# морган
# мортон
# мортона
# мосгорсуда
# москвакак
# москвеговоря
# москвесоветский
# москвой
# москву
# мосфильм
# мосфильмакушнерёв
# мохаммад
# мтс
# музыкальноюмористическая
# музыкантаголос
# музыкойпо
# мультсериалов
# мусоросжигательными
# мушкетёр
# мьюз
# мэдден
# мэддена
# мягков
# наградуконстантин
# назначенноеинтерактивное
# найдётрежиссёр
# нанометровом
# нао
# наоми
# напитьсяактёр
# напитьсяисполнитель
# нарендра
# наркобаронуза
# нарнии
# настроениепопулярный
# наступающимнапомним
# настя
# натоптать
# ндс
# невозможноэто
# неда
# недалёким
# неигровых
# неизвестнымкомпания
# неймар
# неймара
# неймару
# нейтана
# нельзяартист
# нельсона
# непростойпрезидент
# нетв
# нетсолист
# нетфейсбук
# неудовлетворён
# нефейковые
# нефтьтем
# нидерланды
# николаевича
# николая
# николом
# новичкамзампред
# новостикак
# номинантовлидерами
# носитькрасные
# ноябрём
# нпз
# нравиласьчто
# нсн
# нтв
# нунеснынешний
# ньюйоркской
# нэнси
# обама
# обамы
# обеспечительный
# обещанияранее
# областипрессслужба
# обновлённом
# обозревателювпрочем
# обращатьсяя
# общегонапомним
# обществеспикер
# объёмекак
# одноимённый
# озвучивший
# олег
# олега
# олеге
# оливия
# оливьеособенность
# ольга
# омп
# омппо
# онкожемяко
# онлайнкинотеатре
# онлайнкинотеатры
# оннапомним
# оноднако
# оноткрытый
# онпо
# онполиттехнолог
# онпрезидент
# опытанапомним
# орбисона
# организациивторое
# оснастит
# основанийглава
# основеранее
# отдельностикак
# отношенийс
# отцыфильм
# павла
# павликовского
# пайн
# пайна
# палатемарлен
# палермо
# палпатин
# палпатина
# панченко
# паоло
# паркера
# паркеру
# паркинсона
# парламентарийно
# парламентарийотметим
# пароляпока
# парфенон
# пасхалки
# патентаhuawei
# паустовский
# паустовского
# пауэрбанк
# пашиняном
# перезагружать
# перезагружаться
# перезапуском
# пересильд
# переформатируют
# песковв
# песковнапомним
# песковон
# петербурга
# петра
# пиарход
# пинкода
# пиноккио
# пиротехникааналитики
# писателясатирикакогда
# питанияспециалисты
# питеру
# планаснегопад
# платформеотмечается
# плахов
# площадкемы
# победув
# погребинский
# поддерживатькультурные
# подросткунапомним
# подсветкиapple
# подстроилиз
# поиронизировала
# поклонникамив
# поколениявсего
# поколениядиагональ
# поластри
# политикибразилия
# политикиглава
# политикмедведчук
# политологмеждународник
# пользователейнапомним
# пользователейчаще
# пользователейяндекс
# пользуучёные
# польшусуд
# попмузыку
# поппевица
# пораженияагентство
# порнографическиеодной
# порошенко
# португалии
# португалиинападающий
# посетителейпосещаемость
# посещенийроссийское
# постером
# постигаетсяотметим
# поступкупопулярный
# поттер
# поттера
# поумолчанию
# праздникапрезидент
# практикуютсяь
# президентпутин
# премиумкласса
# премьерминистр
# премьерминистра
# премьерминистром
# прессбрифинга
# прессконференции
# прессконференцииглава
# прессконференцию
# прессконференция
# прессрелизе
# пресссекретарь
# прессслужба
# прессслужбалукашенко
# прессслужбе
# престоловиздание
# престоловтакже
# привлекательнымианалитики
# призыпоследний
# приквела
# приквеле
# приквелом
# принсаотдельно
# приставкиисследователи
# причинноследственную
# проанонсировал
# проблемыони
# программув
# прогрессивномнапомним
# продакшенаактёр
# продолжениив
# проектахв
# производителейв
# произойдётgoogle
# произойдётнапомним
# прокателента
# прокофьева
# пролонгируем
# промовидео
# проморолику
# прослеживался
# просмотрам
# профессионаловизвестный
# процентовкомпания
# процентовна
# процессоромиздание
# прочеелайф
# публикациюизвестные
# публикующему
# пугачёва
# путинакак
# путинвсе
# путиннапомним
# путинуон
# пхёнчхане
# рагнарёк
# радловский
# радловскомуюристы
# разблокировки
# разветвлённого
# развитиикак
# развращённости
# развёрнуто
# разлогова
# райан
# райана
# райану
# ракетсевероатлантический
# ранхигс
# расформированияна
# рбк
# рбкактёр
# регбо
# регионовк
# реджеп
# редпутин
# режиссуручеловекпаук
# режиссёрасогласно
# режиссёре
# режиссёромпостановщиком
# режиссёрсемь
# режиссёрским
# режиссёрское
# рейнолдс
# рейнольдса
# рейнольдскомпания
# рейнольдснапряжённые
# рейсин
# ремпейдж
# репарацийгермания
# реформусоцсеть
# решатьожидается
# риа
# риаб
# рианна
# рианны
# ричард
# ричардом
# риччио
# ркн
# робб
# робби
# робертс
# роботыпылесосы
# рогенречь
# розенберг
# рокмузыкант
# рольф
# рольфу
# рона
# роналду
# роскомнадзор
# роскомнадзора
# роскомнадзоре
# роскомнадзором
# россией
# россиейнапомним
# россииговоря
# россиикириенко
# россиянпри
# рублейболее
# рублейнапомним
# рублейпо
# рублейсамыми
# рублейэтот
# рублясвоевременное
# рублёвки
# рублёвом
# руперт
# руперта
# рынкасегодня
# рынкемодель
# рэмпейдж
# рэпбаттлах
# рэперов
# савченко
# саддама
# сайтагрегатор
# сайтеранее
# сайтовв
# сайтовпо
# сайтознакомиться
# самоубийствофильм
# самуэльсенмоджахеддинэ
# самыхсамых
# сандрой
# санктпетербурга
# санкционные
# сардаров
# светилисьдля
# светлана
# свирский
# свободзакон
# святослав
# сгенерировало
# севастополе
# североатлантический
# сегура
# сейдел
# сейделстудии
# сейчасв
# селфикамеры
# семьефильм
# серверахсамый
# сергее
# сергеевича
# сергей
# сергея
# серебренникова
# серединыконца
# сериипервая
# сетиотдельным
# сидиус
# сидиуса
# сидорова
# сингера
# синдзо
# синежёлтое
# сирии
# сириинапомним
# системеmicrosoft
# системывыход
# системыгитарист
# системымузыкант
# системынапомним
# скайуокерасогласно
# скандаловсамый
# скарлетт
# скачанные
# скачиваемый
# скачивают
# случитсяон
# слэйд
# слэйда
# смайликов
# смартфона
# смартфонами
# смартфонах
# смартфоне
# смартфоном
# смартфону
# смартфонылинейка
# смартфоныособенность
# смартфоныпомимо
# смартчасы
# смешарики
# смирнов
# смирнова
# смирновой
# смита
# смичто
# сммотдел
# смоляков
# смурфики
# снбо
# снг
# снежинкисамые
# собибор
# собиборпо
# соболев
# собраниемпо
# собранияволодин
# событияодноклассники
# совфеда
# совфедакак
# совфеде
# соглашениямы
# соединенийтакже
# соловьёва
# сонька
# сообщаетсяnote
# сообщениипрощание
# соответственночетвёртое
# сорокин
# сорокинговоря
# соррентиновторой
# соцсети
# соцсеть
# союзаинтеграция
# спейси
# спейсикевин
# специалистлюбопытно
# спилберг
# спитак
# спортинвентарю
# спрезидент
# ссср
# ставокрост
# сталина
# станислав
# старк
# стархитвсё
# старшенбаум
# стас
# статьиодной
# статьпервый
# стахелски
# степанов
# степанова
# стива
# стилеikea
# стилуса
# стилусом
# стингрей
# сторонинсайдер
# стороннапомним
# стороныроссия
# странев
# странекроме
# страницепользовательское
# странойдиректор
# странроссийский
# страныглава
# странынапомним
# страныоткрытый
# страныранее
# странысообщается
# стримером
# стриминговой
# стримингсервисовтакже
# стритер
# сумерекдругой
# супергеройскую
# супергероях
# суспирия
# сферена
# сферыпрезидент
# сценена
# сценеранее
# сша
# сшав
# сшакак
# сшаотношения
# сшаранее
# сшасамым
# съёмными
# съёмокмария
# съёмокнапомним
# съёмокрежиссёр
# сытник
# сытнике
# сюжетаробб
# сюрпризна
# табаковезамкнул
# таиланде
# таймссквер
# такконе
# талиона
# тарасова
# тасс
# тасспомощник
# тасссамым
# татьяна
# тварирежиссёром
# твиттер
# твиттере
# твиттереthe
# твиттерео
# твиттереон
# твиттереопубликовал
# театрапо
# тегерана
# телевидениив
# телеграм
# телеграмканалу
# телекомкомпании
# телекомпровайдеров
# телохранителе
# темпрезидент
# терафлопса
# территориичиновник
# тизере
# тизером
# тима
# тимошенко
# тимур
# тихонова
# товарооборотапрезидент
# тодд
# токио
# топменеджер
# топменеджеров
# торговв
# траволта
# трамп
# трампа
# трампе
# трампом
# трансгендером
# тревораизначально
# трендам
# третьжители
# треш
# трофейджеймс
# трофима
# труднодаалдер
# трёхминутном
# тудасюда
# турции
# турцию
# тюрьмыв
# уиг
# уизли
# уика
# уилл
# уилсон
# уильям
# уильяма
# уильямс
# украину
# улёте
# уничтоженияважно
# уоллербриджпомимо
# уолтом
# упалточной
# ургант
# успехомрезультаты
# устраиваетнапомним
# устройствакак
# утекшая
# уточняетсяв
# уточняетсягалина
# уточняетсяхудрук
# уфлампу
# фавориткаrami
# файги
# фанатскую
# фаррелли
# фаул
# фбр
# федорченко
# фейковой
# фейковую
# фейковые
# фейковыми
# фейковых
# фейком
# фейсбука
# фейсбуке
# фейсбукешоумен
# ферранте
# феррелл
# фестивалянапомним
# фиби
# филипп
# фильманапомним
# фильмаоб
# фильмовпо
# фильмывместе
# финансированиякультурные
# финрынки
# финчер
# фитнесбраслеты
# флешмоб
# фолитакже
# фонарифонари
# фондатакже
# форсмажоры
# фотопрогулка
# фотошедевр
# фраковяк
# францию
# фрг
# фргличная
# фронтмен
# фрэнка
# фёдора
# фёдорова
# фёдоровав
# хабенский
# хабенского
# хакасии
# хакасию
# хакасия
# халк
# хаммурапи
# характеррасследованием
# харди
# харли
# хача
# хватитсам
# хворостовскийопрос
# хворостухин
# хейдером
# хенли
# хештегов
# хованский
# ходченкова
# холланд
# холмса
# холмсе
# холмсу
# хорроракаждый
# хоукинсе
# художниканиматор
# хуциев
# хуциева
# хэтэуэй
# целяхновость
# ценитькак
# центровлидер
# цмт
# цпа
# цру
# цукерберг
# цукерберга
# цыбульский
# чайковского
# часав
# часапрезиденты
# частиактёр
# человекапаука
# человекапо
# человекахороший
# человеклидерами
# человекпаук
# человекследом
# человекслон
# человечестванапомним
# чернышов
# чернышовдепутат
# черчесов
# честера
# честером
# чехледругие
# чикенкарри
# чипмейкер
# чипмейкера
# чипмейкером
# чм
# чудоженщина
# чудоженщинапри
# чудоженщину
# чудоженщины
# чёрнобелом
# чёрнобелый
# чёрнобелых
# чёрномпока
# шамеика
# шарапова
# шарп
# шейна
# шеппард
# шеппардом
# шеппардомпопулярный
# шерлока
# шерлоке
# шеффилдского
# шибкодемократическая
# шикотан
# шлемашлем
# шлимана
# шми
# шмисамо
# шнурова
# шоубизнеса
# шоубизнесе
# шоув
# шоуменнапомним
# шпионажесначала
# штабквартире
# штатамв
# шутернеймар
# эббинга
# эберсвальдский
# эдгар
# эзры
# экономикироссия
# экономикусреди
# экранаxiaomi
# экранав
# экранпользователь
# экспертнапомним
# экспрезидент
# экспрезидента
# экссотрудник
# элджей
# элементалейджейкоб
# элементали
# элены
# элеон
# эльзы
# эмодзи
# энакина
# энн
# эпизодоввместе
# эрдоган
# эрдогана
# эрдоганомлюбопытно
# эрнесту
# эстерлинг
# этогонапомним
# этомikea
# ювентус
# югозападе
# юлия
# юрий
# юрия
# ютуб
# ютубблогеров
# ягеле
# языкецеремония
# январяамериканский
# январякартина
# яндексе
# японии
# япония
# японороссийского
# ёлкиисследователи
# ёлокпутём

# %%
print(len(np.unique(ood)))
# Out:
# 1834
