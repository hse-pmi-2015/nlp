# %%
# -*- coding: utf-8 -*-
from __future__ import unicode_literals

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score
from sklearn.feature_extraction.text import TfidfVectorizer
import re
import string
from nltk.stem.snowball import RussianStemmer
import stop_words

import numpy as np
# %matplotlib inline

# %%
data = pd.read_csv("laba1.csv", header=[0, 1], index_col=0, encoding='utf-8')
data
# Out:
#                                              политика  \
#                                                 Title
# 0      Путин отверг возможность возврата к социализму
# 1   Путин пообещал поддерживать оппозиционных губе...
# 2   Главное — не "квасной". Путин назвал патриотиз...
# 3   Путин анонсировал переговоры с Пашиняном на сл...
# 4   Путин ответил на вопрос, хочет ли он править м...
# 5             Обновление пользовательского соглашения
# 6   Не как обычно. Политтехнолог перечислил главны...
# 7   От НДС и Сирии до Бутиной и рэпа. Эксперты оце...
# 8   Прорыв неизбежен. Политолог расшифровал сигнал...
# 9   "Президент — прагматик". Песков заявил, что Пу...
# 10  Песков заявил, что хаотичность действий США вы...
# 11  Хакеры вместо боеголовок. Пентагон изучит кибе...
# 12  Уж точно не "прагматичный сухарь". Кириенко оз...
# 13  Кириенко: Сопереживание — важная вещь для упра...
# 14  Лукашенко указал на важность всесторонних отно...
# 15  Лукашенко переживает, что Россия перестала счи...
# 16  Лукашенко предложил Путину "не тащить" текущие...
# 17  Путин поднимет энергетические вопросы на встре...
# 18  В Совфеде предложили заносить лживых иностранн...
# 19  Володин на встрече с Путиным предложил оценить...
# 20  Вице-губернаторы Петербурга Игорь Албин и Миха...
# 21  Песков объяснил необходимость ещё одной встреч...
# 22            Обновление пользовательского соглашения
# 23  Путин встретится с вновь избранными губернатор...
# 24  Порошенко анонсировал новые санкции против России
# 25  "Надо будет — договорюсь". Зеленский обещает о...
# 26  Кожемяко подготовит доклад для Путина о пробле...
# 27  Песков: Путин и Лукашенко продолжат обсуждение...
# 28  Рабочая суббота. В Кремле началась встреча Пут...
# 29  Путин и Лукашенко поздравили с наступающим Нов...
# 30  Ответные меры. Россия запретила импорт ряда ук...
# 31  Песков о сотрудничестве Москвы и Минска: Не пр...
# 32  Песков: Интеграция Москвы и Минска не должна т...
# 33  Абэ надеется "предметно" обсудить с Путиным ми...
# 34  В Интернет попали личные данные сотен немецких...
# 35           Президент Турции посетит Россию в январе
# 36  Пригласил на ВЭФ как главного гостя. Путин про...
# 37  "Вялая деградация". Пушков рассказал, что ждёт...
# 38  Суд Киева признал вмешательство украинских пол...
# 39  Зеленский попросил украинцев написать ему пред...
# 40  Глава МИД Ирана: Европа укрывает у себя террор...
# 41  Бразилия вышла из Глобального договора о миграции
# 42  Япония выразила надежду на поддержку США в воп...
# 43  Песков отреагировал на данные СМИ о "вмешатель...
# 44  НАТО заявило о готовности к диалогу с Москвой ...
# 45  Украинский министр назвал Крымский мост бутафо...
# 46  Эксперт считает, что США потеряли статус ведущ...
# 47  Эксперт рассказал, чем опасно избрание Зеленск...
# 48  Надо ценить. Медведев напомнил Минску о кредит...
# 49  Медведев высказался о компенсациях за налоговы...
#
#                                                        \
#                                                  Text
# 0   Глава государства при этом допустил, что возмо...
# 1   Все избранные главы регионов, даже представите...
# 2   Патриотизм должен выступать в роли основы для ...
# 20  ×\n\nОбновление пользовательского соглашения\n...
# 21  ×\n\nОбновление пользовательского соглашения\n...
# 22  Аксессуар был распечатан с помощью 3D-принтера...
# 23  Лидирующую позицию по количеству номинаций зан...
# 24  Спор между двумя авторами популярных американс...
# 25  Добиться удалось этого благодаря "Аквамену", п...
# 26  Чад Стахелски в очередной раз решил подтвердит...
# 27  Спустя много лет стало известно о том, что чёр...
# 28  ×\n\nОбновление пользовательского соглашения\n...
# 29  Перед каждой трансляцией сериала теперь должна...
# 30  В личный рейтинг экс-президента США вошло боле...
# 31  "Мегафон" проанализировал данные по количеству...
# 32  Прославленный кинорежиссёр и сценарист Марлен ...
# 33  Сайт-агрегатор Metacritic, специализирующийся ...
# 34  По мнению священнослужителя, фильм транслирует...
# 35  На втором месте оказалась кинолента "Ёлки Посл...
# 36  Компания Netflix поделилась тизером и постером...
# 37  Соответствующий список был составлен сайтом Fa...
# 38  Соответствующее заявление автор американской к...
# 39  Свои соболезнования выразили друзья и коллеги ...
# 40  Популярный американский актёр не появится на э...
# 41  Сериал про зомби вышел в лидер в связи с отсут...
# 42  Таким образом популярная американская актриса ...
# 43  По сравнению с результатом, который был продем...
# 44  Это произошло из-за того, что команда работала...
# 45  Он был одним из последних творцов золотого век...
# 46  По словам авторов шоу, "Бандерснэтч" можно счи...
# 47  По словам режиссёра специального эпизода, в нё...
# 48  Исполнитель роли Рона Уизли из популярной сери...
# 49  В прошлом году доля отечественных фильмов в ки...
#
#                                            технологии  \
#                                                 Title
# 0   ¯\_(ツ)_/¯ - В Windows 10 появятся смайлики из ...
# 1       Первый в мире веб-сайт запустили 28 лет назад
# 2   В 2019 году Steam перестанет работать на стары...
# 3   Появилось пятно. Пользователи iPad Pro 2017 го...
# 4   Смартфоны, одежда, фастфуд. Названы 20 любимых...
# 5             Обновление пользовательского соглашения
# 6   Facebook начал делить СМИ на "фейковые" и "неф...
# 7      Названо, какие iPad Apple выпустит в 2019 году
# 8   "Это нормально". В Apple прокомментировали сит...
# 9   Xiaomi представила "молодёжный" смартфон c гра...
# 10     Google не стала обжаловать штраф Роскомнадзора
# 11  Матвиенко объяснила необходимость закона о сув...
# 12  Samsung Galaxy Note 10 получит увеличенный дис...
# 13  Хакеры выводят из строя компьютеры на Windows ...
# 14  "Яндекс" выяснил, что покупают россияне к Ново...
# 15  "Одноклассники" назвали главные события 2018 года
# 16   Fortnite стала самой обсуждаемой игрой в Twitter
# 17            Цена PlayStation 4 Pro рухнула в России
# 18  Названы причины выпуска в декабре большинства ...
# 19  В 2018 году "ВКонтакте" выплатила 2 млрд рубле...
# 20  Названы самые высокооплачиваемые российские Yo...
# 21  "Мстители без конечностей". Названы самые смеш...
# 22       "Яндекс" удалил Telegram из поисковой выдачи
# 23  Эксперты: Россияне заинтересованы в iPhone, но...
# 24  IKEA выпустила инструкцию по "сборке" салата о...
# 25  Смартфоны, планшеты, умные часы. Названы лучши...
# 26          Москвичи стали чаще заказывать еду на дом
# 27  Снег, замри. 10 советов, как сделать снежный ф...
# 28  Названы самые популярные среди интернет-пирато...
# 29  "ВКонтакте" и Иван Ургант переформатируют "Кле...
# 30  Запрет iPhone, утечка данных. Главные скандалы...
# 31  Путин, "Мстители", Элджей. Названы главные тем...
# 32         Nokia 9 с пятью камерами появился на видео
# 33  Huawei представила бюджетный смартфон без скан...
# 34  Неймар променял празднование нового года на иг...
# 35  WhatsApp перестанет работать на некоторых теле...
# 36  Цукерберг продал акции Facebook, чтобы лечить ...
# 37            Обновление пользовательского соглашения
# 38  Apple предупредила инвесторов о замедлении тем...
# 39  Steam больше не поддерживает старые версии Win...
# 40  Роналду стал рекордсменом по числу подписчиков...
# 41  Смартфоны Redmi компании Xiaomi станут отдельн...
# 42  И они туда же. Первый складной Xiaomi появился...
# 43  Учёные нашли способ превращать новогодние ёлки...
# 44  Есть подтверждения: Apple уже занимается разра...
# 45  Tesla готовится начать продажи электромобиля M...
# 46  Акции Apple упали из-за провально низких прода...
# 47  Qualcomm заплатила 1,3 млрд евро за запрет про...
# 48  "Просто настали новые времена". Аналитики назв...
# 49  Touch ID в экране, USB-C. Аналитик назвал ново...
#
#                                                        \
#                                                  Text
# 0   Сейчас их ищут в Интернете и копируют, в следу...
# 1   Это сделал Тим Бернерс-Ли, британский учёный и...
# 2   Разработчики сервиса цифровой дистрибуции заяв...
# 3   Похоже, проблема заключается в подсветке. Одна...
# 4   Лидером восьмой год подряд остаётся Samsung, в...
# 5   По мнению экспертов, рост цен на связь неизбеж...
# 6   Соцсеть составляет досье на СМИ, которые цитир...
# 7   Авторитетный ресурс узнал, что в Купертино гот...
# 8   Вице-президент Apple по аппаратному обеспечени...
# 9   Бюджетная модель удивит оригинальными цветами ...
# 10  Компания отказалась комментировать, будет ли о...
# 11  В то же время она высказалась за широкую общес...
# 12  Авторитетный инсайдер поделился информацией о ...
# 13  Злоумышленники создали вредоносную ссылку, кот...
# 14  В топе приобретений через интернет-магазины — ...
# 15  Пользователи соцсети обсуждали кемеровскую тра...
# 16  Эта многопользовательская игра стала невероятн...
# 17  Популярная игровая консоль японского производи...
# 18  В 2017 году магазин App Store продал перед Нов...
# 19  В уходящем году пользователи самой популярной ...
# 20  Исследователи определили, какой доход с продаж...
# 21  Видимо, в 2018 году пользователи были обеспоко...
# 22  По имеющимся данным, сайт не отображается в по...
# 23  Смартфоны китайского бренда Xiaomi покупали в ...
# 24  Компания поиронизировала над собой, выпустив и...
# 25  Смартфон — по-прежнему лучший подарок. Также в...
# 26  Число заказов еды на дом среди столичных абоне...
# 27  Для кого-то зима — это холод и уныние, для дру...
# 28  "Собибор", "За гранью реальности" и "Гоголь. В...
# 29  Основным режимом игры станет бой, а не виктори...
# 30  Замедление iPhone\n\nВ декабре 2017 года Apple...
# 31  ×\n\nОбновление пользовательского соглашения\n...
# 32  Новый смартфон HMD Global удивит количеством м...
# 33  Устройство за 170 долларов узнает владельца в ...
# 34  Популярный бразильский футболист в настоящий м...
# 35  Сейчас пользователи гаджетов на устаревших опе...
# 36  Фонд создателя самой популярной социальной сет...
# 37  ×\n\nОбновление пользовательского соглашения\n...
# 38  Руководитель американской корпорации связывает...
# 39  Помимо операционных систем Windows XP и Window...
# 40  До этого популярный футболист заявлял о том, ч...
#
#
#                                                  Text
# 0   Ричард Мэдден признался, что рад гибели своего...
# 1   Собеседники Лайфа считают, что Берлину для нач...
# 2   ×\n\nОбновление пользовательского соглашения\n...
# 3   Прощание с актёром пройдёт в понедельник, 24 д...
# 4   Популярная российская теннисистка отметила, чт...
# 5   По словам певицы, его звучание будет похожим н...
# 6   ×\n\nОбновление пользовательского соглашения\n...
# 7   По словам замглавы Минкультуры Павла Степанова...
# 8   Граждане страны также выбрали музыканта года, ...
# 9   Народный артист России Михаил Боярский отмечае...
# 10  Сатирик написал сценарий картины, впервые выст...
# 11  Саундтрек к мюзиклу "Величайший шоумен" побил ...
# 12  В списке успешных картин — "Лёд", "Тренер", а ...
# 13  ×\n\nОбновление пользовательского соглашения\n...
# 14  ×\n\nОбновление пользовательского соглашения\n...
# 15  Опубликованные Шведской академией архивные док...
# 16  Популярный музыкант опубликовал композицию в т...
# 17  Популярный артист считает, что в российском шо...
# 18  Певец умер 1 января в Подмосковье, он нескольк...
# 19  В основе новой отечественной киноленты — празд...
# 20  Рейтинг кинокартин, которые больше всего интер...
# 21  При этом в российском прокате кинолента в обно...
# 22  Жена известного российского телеведущего Никол...
# 23  Создатели кинокартины "Птичий короб" при этом ...
# 24  В настоящий момент кассовые сборы новой отечес...
# 25  В настоящий момент творческая команда будущей ...
# 26  Исполнителя роли Промокашки в культовой картин...
# 27  Сам 93-летний народный артист СССР остаётся в ...
# 28  ×\n\nОбновление пользовательского соглашения\n...
# 29  В Голливуде в 76-й раз прошла церемония вручен...
# 30  Чаще всего британца можно было встретить в тел...
# 31  Заключительный, восьмой сезон популярного теле...
# 32  Компания Sony Pictures Entertainment снимет пр...
# 33  Прощание состоится 10 января в 11:00 в ритуаль...
# 34  Президент РФ Владимир Путин потребовал от губе...
# 35  При создании культурных центров в регионах стр...
# 36  Премьера многострадального американского комед...
# 37  Авторы картины обещают придерживаться феминист...
# 38  Всего планируется создать несколько мультиплик...
# 39  ×\n\nОбновление пользовательского соглашения\n...
# 40  По мнению Кевина Файги, постановщик, который б...
# 41  Композиция стала частью дебютного сольного аль...
# 42  Режиссёром пилотного эпизода будущего шоу теле...
# 43  По мнению исполнителя, зрителей также следует ...
# 44  ×\n\nОбновление пользовательского соглашения\n...
# 45  На данный момент автор работает над другим про...
# 46  Вместе с тем певица призналась, что какие-то в...
# 47  Чернышов уверен, что у самого исполнителя рыль...
# 48  Лидером по числу номинаций стал фильм "Фаворит...
# 49  Это первый за последние пять лет российский фи...

# %%
stemmer = RussianStemmer()

# %%
EXCLUDE_SYMBOLS_STR = u''.join(['№', '«', 'ђ', '°', '±', '‚', 'ћ', '‰', '…', '»', 'ѓ', 'µ', '·', 'ґ', 'њ', 'ї', 'џ', 'є', '‹',
                                '‡', '†', '¶', 'ќ', '€', '“', 'ў', '§', '„', '”', '\ufeff', '’', 'љ', '›', '•', '—', '‘', 
                                '\x7f', '\xad', '¤', '\xa0'])

# %%
regex_punct = re.compile('[%s]' % re.escape(string.punctuation))
regex_dig = re.compile('[%s]' % re.escape(string.digits))
regex_symb = re.compile('[%s]' % re.escape(EXCLUDE_SYMBOLS_STR))
regex_struct = re.compile('[%s]' % string.printable + string.whitespace)
emoji_pattern = re.compile("["
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+")

# %%
for category in data.columns.levels[0]:
    for key in data.columns.levels[1]:
        for i, item in enumerate(data[category][key]):
            item = re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', u'', item)
            itme = re.sub(' +' , ' ', item)
            item = item.strip().strip('\t').replace('\n', u'')
            item = regex_punct.sub('', item)
            item = regex_dig.sub('', item)
            item = regex_symb.sub(' ', item)
            item = regex_struct.sub('', item)
            item = re.sub(' +' , ' ', item.strip())
            item = emoji_pattern.sub('', item)
            tokens = []
            sp = item.lower().split()
            for word in sp:
                if word not in stop_words.get_stop_words('ru'):
                    tokens.append(word)
            tmp = [stemmer.stem(word) for word in tokens]
            data.loc[i, (category, key)] = u" ".join(tmp)

# %%
data
# Out:
#                                              политика  \
#                                                 Title
# 0              путин отверг возможн возврат социализм
# 1      путин пообеща поддержива оппозицион губернатор
# 2   главн квасн путин назва патриотизм основ укреп...
# 3       путин анонсирова переговор пашинян след недел
# 4                   путин ответ вопрос хочет прав мир
# 5                    обновлен пользовательск соглашен
# 6   политтехнолог перечисл главн фишк прессконфере...
# 7   ндс сир бутин рэп эксперт оцен готовн путин ди...
# 8   прор неизбеж политолог расшифрова сигнал путин...
# 9   президент прагматик песк заяв путин близк фило...
# 10  песк заяв хаотичн действ сша вызыва обеспокоен...
# 11  хакер вмест боеголовок пентагон изуч кибервозм...
# 12  точн прагматичн сухар кириенк озвуч качеств хо...
# 13                  кириенк сопереживан вещ управленц
# 14  лукашенк указа важност всесторон отношен москв...
# 15  лукашенк пережива росс переста счита белорусс ...
# 16       лукашенк предлож путин тащ текущ проблем нов
# 17  путин поднимет энергетическ вопрос встреч лука...
# 18  совфед предлож занос лжив иностра политик спис...
# 19  володин встреч путин предлож оцен конституц ак...
# 20  вицегубернатор петербург игор албин миха мокре...
# 21   песк объясн необходим встреч путин лукашенк конц
# 22                   обновлен пользовательск соглашен
# 23          путин встрет внов избра губернатор декабр
# 24                 порошенк анонсирова нов санкц росс
# 25   договор зеленск обеща обеспеч украин членств нат
# 26       кожемяк подготов доклад путин проблем примор
# 27  песк путин лукашенк продолжат обсужден спорн в...
# 28      рабоч суббот кремл нача встреч путин лукашенк
# 29  путин лукашенк поздрав наступа нов год народ с...
# 30   ответн мер росс запрет импорт ряд украинск товар
# 31  песк сотрудничеств москв минск присоединен инт...
# 32   песк интеграц москв минск должн тревож член еаэс
# 33       абэ надеет предметн обсуд путин мирн договор
# 34  интернет попа личн дан сот немецк политик знам...
# 35                    президент турц посет росс январ
# 36  приглас вэф главн гост путин провел телефон ра...
# 37     вял деградац пушк рассказа ждет отношен рф сша
# 38  суд киев призна вмешательств украинск политик ...
# 39  зеленск попрос украинц написа предвыборн программ
# 40                глав мид ира европ укрыва террорист
# 41                бразил вышл глобальн договор миграц
# 42  япон выраз надежд поддержк сша вопрос мирн дог...
# 43  песк отреагирова дан сми вмешательств росс выб...
# 44                 нат заяв готовн диалог москв дрсмд
# 45         украинск министр назва крымск мост бутафор
# 46  эксперт счита сша потеря статус ведущ игрок ме...
# 9                 фильм аквам лидер американск прокат
# 10         netflix снимет сериа помощник шерлок холмс
# 11    актрис галин тихонов скоропостижн умерл возраст
# 12                           россиян назва лучш фильм
# 13       кевин спейс вернул актер записа обращен виде
# 14  актер чудоженщин спел рождественск песн мультф...
# 15              съемк продолжен чудоженщин заверш фот
# 16                    назва график фильм disne выйдут
# 17       российск кин поб рекорд кассов сбор посещаем
# 18          дэвид духовн заинтересова групп ленинград
# 19             раскрыт подробн продолжен человекапаук
# 20                    как долж идеальн новогодн фильм
# 21        алиэкспресс порн девушк обложк внутр пример
# 22               блогер сдела шлем тор свет глаз виде
# 23                 назва номинант кинопрем золот орел
# 24            эдгар райт проспор оскар режиссер аквам
# 25            голливуд установ нов рекорд кассов сбор
# 26          режиссер джон уик надеет снят ремейк горц
# 27           гангстерск драм фильм дом оказа ненастоя
# 28  россиян предпочита фильм войн мультфильм комед...
# 29  польш обяза немецк телекана извин сериа антисемит
# 30    книг жен любим обам рассказа смотрел слуша чита
# 31                      топ фильм сериал верс мегафон
# 32  известн кинорежиссер марл хуц госпитализирова ...
# 33                        назва лучш нов сериал уходя
# 34  недалек ум мягк ответ митрополит рязанск крити...
# 35  комед полицейск рублевк возглав российск прока...
# 36            стал известн дат выход трет сезон стран
# 37             фильм marvel доминир рейтинг сам ожида
# 38     режиссер аквам попрос фанат фильм оскорбля люд
# 39             умер актер фильм лет владимир дыховичн
# 40                     disne сэконом доллар джон депп
# 41         ходяч мертвец сам скачива сред пират сериа
# 42  скарлетт йоханссон назва интернет кротов нор п...
# 43  рекордн млн рубл состав выручк кинотеатр росс ...
# 44  создател черн зерка назва причин перенос го се...
# 45                   обновлен пользовательск соглашен
# 46     стал известн й сезон черн зерка выйдет netflix
# 47  автор черн зерка фанат посмотр нов эпизод полност
# 48                    звезд гарр поттер смотрет фильм
# 49              российск кин поб рекорд сбор посещаем
#
#                                                        \
#                                                  Text
# 0   сет появ великолепн виде котор позвол кажд зри...
# 1   ×обновлен пользовательск соглашениям повыша ка...
# 2   фанат популярн актер выбира брутальн образ уди...
# 3   проект отказа шон лев ран работа популярн сери...
# 4   нов комикс звездн войн darth vader no подтверд...
# 5   ×обновлен пользовательск соглашениям повыша ка...
# 6   ×обновлен пользовательск соглашениям повыша ка...
# 7   сценар нов фильм должн написа комик шо субботн...
# 8   кинокритик журна the hollywood reporter выбра ...
# 9   северн америк фантастическ боевик вышел россий...
# 10  беспризорник станут нов главн геро сериа произ...
# 11  актрис театр кин галин тихонов умерл жизн скор...
# 12  лучш оказа кинодрам назван билборд границ эбби...
# 13  перв публичн высказыван звезд карточн домик сп...
# 14  крис пайн озвуч картин питер паркер исполн ком...
# 15  фильм главн рол котор сыгра актрис гал гадот в...
# 16  настоя момент студ планир выпуст будущ кинокар...
# 17  числ зрител кинотеатр стран превыс посетителей...
# 18  актер звезд сериал секретн материал блудлив ка...
# 19  сюжет будущ кинолент долж достаточн серьезн от...
# 20  ×обновлен пользовательск соглашениям повыша ка...
# 21  ×обновлен пользовательск соглашениям повыша ка...
# 22  аксессуар распечата помощ дпринтер модел блоге...
# 23  лидир позиц количеств номинац заня сраз киноле...
# 24  спор двум автор популярн американск кинолент с...
# 25  доб уда благодар аквамен продаж сеанс настоя м...
# 26  чад стахелск очередн реш подтверд журналист на...
# 27  спуст стал известн чернобел фильм ангел грязн ...
# 28  ×обновлен пользовательск соглашениям повыша ка...
# 29  кажд трансляц сериа должн появля информац перс...
# 30  личн рейтинг экспрезидент сша вошл книг фильм ...
# 31  мегафон проанализирова дан количеств просмотр ...
# 32  прославлен кинорежиссер сценарист марл хуц гос...
# 33  сайтагрегатор metacritic специализир сбор анал...
# 34  мнен священнослужител фильм транслир ид чуд до...
# 35  втор мест оказа кинолент елк последн трет мест...
# 36  компан netflix подел тизер постер продолжен по...
# 37  соответств список составл сайт fandang традици...
# 38  соответств заявлен автор американск кинолент р...
# 39  соболезнован выраз друз коллег актер режиссер ...
# 40  популярн американск актер появ экран рол капит...
# 41  сериа зомб вышел лидер связ отсутств нов эпизо...
# 42  так образ популярн американск актрис реш проко...
# 43  сравнен результат продемонстрирова прошл сумм ...
# 44  произошл изз команд работа интерактивн эпизод ...
# 45  одн последн творц золот век кинокомпан disne с...
# 46  слов автор шо бандерснэтч счита рождественск с...
# 47  слов режиссер специальн эпизод нем пасхалк воз...
# 48  исполнител рол рон уизл популярн сер кинолент ...
# 49  прошл дол отечествен фильм кинотеатр рф достиг...
#
#                                            технологии  \
#                                                 Title
# 0                   ¯ツ¯ windows появ смайлик иероглиф
# 1                                  мир вебсайт запуст
# 2                      ste перестанет работа стар mac
# 3      появ пятн пользовател ipad pro жал дефект экра
# 4     смартфон одежд фастфуд назва любим бренд россия
# 5                    обновлен пользовательск соглашен
# 6               facebook нача дел сми фейков нефейков
# 7                          назва как ipad appl выпуст
# 8   нормальн appl прокомментирова ситуац гнущ ipad...
# 9   xiaom представ молодежн смартфон c градиентн к...
# 10             googl стал обжалова штраф роскомнадзор
# 11      матвиенк объясн необходим закон суверен рунет
# 12             samsung galax not получ увеличен диспл
# 13  хакер вывод стро компьютер windows помощ ошибк...
# 14                    яндекс выясн покупа россиян нов
# 15                     одноклассник назва главн событ
# 16                     fortn стал обсужда игр twitter
# 17                    цен playstation pro рухнул росс
# 18  назва причин выпуск декабр большинств мобильн игр
# 19          вконтакт выплат млрд рубл разработчик игр
# 20    назва сам высокооплачива российск ыоутубеблогер
# 21       мстител конечн назва сам смешн запрос яндекс
# 22                   яндекс удал telegr поисков выдач
# 23  эксперт россиян заинтересова iphon покупа кита...
# 24               ike выпуст инструкц сборк салат олив
# 25     смартфон планшет умн час назва лучш подарк нов
# 26                       москвич стал заказыва ед дом
# 27             снег замр совет сдела снежн фотошедевр
# 28        назва сам популярн сред интернетпират фильм
# 29            вконтакт ива ургант переформатир клевер
# 30  запрет iphon утечк дан главн скандал индустр т...
# 31        путин мстител элдж назва главн тем вконтакт
# 32                            nok пят камер появ виде
# 33     huaw представ бюджетн смартфон сканер отпечатк
# 34            неймар променя празднован нов игр fortn
# 35         whatsapp перестанет работа некотор телефон
# 36  цукерберг прода акц facebook леч эпилепс болез...
# 37                   обновлен пользовательск соглашен
# 38  appl предупред инвестор замедлен темп продаж i...
# 39                   ste поддержива стар верс windows
# 40           роналд рекордсмен числ подписчик instagr
# 41    смартфон redm компан xiaom станут отдельн бренд
# 42                             складн xiaom появ виде
# 43     учен нашл способ превраща новогодн елк сладост
# 44              подтвержден appl занима разработк ios
# 45    tesl готов нача продаж электромобил model европ
# 46        акц appl упа изз провальн низк продаж iphon
# 47       qualcomm заплат млрд евр запрет продаж iphon
# 48  наста нов врем аналитик назва причин паден акц...
# 49  touch id экран usbc аналитик назва нововведен ...
#
#                                                        \
#                                                  Text
# 0   ищут интернет копир след найт операцион систем...
# 1   сдела тим бернерсл британск учен европейск орг...
# 2   разработчик сервис цифров дистрибуц заяв прекр...
# 3   похож проблем заключа подсветк одн област дисп...
# 4   лидер подряд оста samsung перв пятерк вход app...
# 5   мнен эксперт рост цен связ неизбеж мобильн опе...
# 6   соцсет составля дос сми цитир пользовател так ...
# 7   авторитетн ресурс узна купертин готов презента...
# 8   вицепрезидент appl аппаратн обеспечен дэн ричч...
# 9   бюджетн модел удив оригинальн цвет крышк высок...
# 10  компан отказа комментирова оплачива штраф прои...
# 11  высказа широк обществен дискусс допуст огранич...
# 12  авторитетн инсайдер подел информац флагман сти...
# 13  злоумышленник созда вредоносн ссылк начина пос...
# 14  топ приобретен интернетмагазин икр роликов кон...
# 15  пользовател соцсет обсужда кемеровск трагед чм...
# 16  многопользовательск игр стал невероятн успешн ...
# 17  популярн игров консол японск производител поде...
# 18  магазин app stor прода нов год приложен сумм д...
# 19  уходя пользовател популярн соцсет росс млн зап...
# 20  исследовател определ доход продаж реклам получ...
# 21  видим пользовател обеспоко отношен домашн живо...
# 22  имеющ дан сайт отобража поисковик российск пол...
# 23  смартфон китайск бренд xiaom покупа полтор раз...
# 24  компан поиронизирова выпуст инструкц сборк сал...
# 25  смартфон попрежн лучш подарок списк планшет см...
# 26  числ заказ ед дом сред столичн абонент билайн ...
# 27  когот зим холод унын – волшебн снежн фотограф ...
# 28  собибор гран реальност гогол ви стал лидер чис...
# 29  основн режим игр станет бо викторин прям эфир ...
# 30  замедлен ипhон декабр appl призна умышлен заме...
# 31  ×обновлен пользовательск соглашениям повыша ка...
# 32  нов смартфон hmd globa удив количеств модул ос...
# 33  устройств доллар узна владельц лиц правд предс...
# 34  популярн бразильск футболист настоя момент нач...
# 35  пользовател гаджет устаревш операцион систем с...
# 36  фонд создател популярн социальн сет разрабатыв...
# 37  ×обновлен пользовательск соглашениям повыша ка...
# 38  руководител американск корпорац связыва трен с...
# 39  помим операцион сист windows xp windows vist с...
# 40  популярн футболист заявля планир вернут сборн ...
# 41  бренд mi выход гаджет премиумкласс redm бюджет...
# 42  популярн китайск бренд готов гибк мобильн устр...
# 43  исследовател выясн срублен праздник дерев извл...
# 44  журналист обнаруж посещен сайт устройств нов о...
# 45  получен информац производител электрокар догов...
# 46  компан ожида прибыл ожида сообща слаб продаж с...
# 47  ран чипмейкер выигра компан купертин дел наруш...
# 48  эксперт усомн снижен спрос iphon вызва торгов ...
# 49  мнен эксперт след смартфон appl удив нов возмо...
#
#                                              культура  \
#                                                 Title
# 0   умрут робб старк игр престол предсказа мрачн фина
# 1   эксперт оцен услов возврат герман ценност выве...
# 2                    обновлен пользовательск соглашен
# 3   умер режиссер программ спокойн ноч малыш дмитр...
# 4        мар шарапов снял клип песн spic girls – виде
# 5                певиц риан рассказа фанат нов альбом
# 6            минкультур подвел итог конкурс любим муз
# 7      посвящен театр порта заработа полн объем январ
# 8                   козловск россиян выбра лучш актер
# 9   боярск главн мушкетер стран поведа лучш подарк...
# 10  чист русск сказк последн фильм миха задорнов п...
# 11           лидер чарт величайш шоум поб рекорд адел
# 12                         назва главн российск фильм
# 13              извест победител седьм сезон шо голос
# 14          путин поздрав хореограф юр григорович лет
# 15  паустовск вход числ основн кандидат нобелевск ...
# 16  гитарист que посвят нов песн космическ зонд – ...
# 17              юр лоз резк раскритикова голуб огонек
# 18               хват стал известн завещан крис кельм
# 19               российск фильм праздник вышел youtub
# 20               назва сам популярн фильм сред россия
# 21           стал известн дат выход фильм жилб дэдпул
# 22       угроз жен никол дроздов рассказа состоян муж
# 23                 зрител netflix устро опасн флешмоб
# 24                     фильм посмотрел полтор миллион
# 25      объявл нача работ перезапуск дже молчалив боб
# 26             прощан иван бортник состо театр таганк
# 27         супруг режиссер марл хуциев умерл реанимац
# 28  назва лучш фильм верс национальн обществ кинок...
# 29              назва победител кинопрем золот глобус
# 30  умер британск актер уил морга шеппард известн ...
# 31     опубликова перв кадр финальн сезон игр престол
# 32                son pictures снимет продолжен веном
# 33   спродюсирова ку киндзадз умер режиссер юр кушнер
# 34  путин потребова назва точн срок создан культур...
# 35  путин призва избега шаблон создан культурн цен...
# 36        уилл смит объяв начал съемок трет плох парн
# 37               марг робб получ главн рол фильм барб
# 38    режиссер дэдпул снимет мультфильм робот netflix
# 39               опубликова нов трейлер капита марвел
# 40  руководител студ marvel похвал режиссер страж ...
# 41  опубликова посмертн песн честер беннингтон вок...
# 42            назва актерск соста приквел игр престол
# 43       солист рук предлож ввест возрастн ценз музык
# 44  российск фильм заработа новогодн праздник млрд...
# 45  закр тем навсегд лукьяненк сообщ завершен сер ...
# 46  суд гурцк раскритикова предложен ввест цензур ...
# 47  прекрат жит грех депутат ответ предложен била ...
# 48                   объявл список номинант прем baft
# 49  российск фильм вошел главн конкурс роттердамск...
#
#
#                                                  Text
# 0   ричард мэдд призна рад гибел персонаж поскольк...
# 1   собеседник лайф счита берлин выплат рыночн сто...
# 2   ×обновлен пользовательск соглашениям повыша ка...
# 3   прощан актер пройдет понедельник декабр нов ар...
# 4   популярн российск теннисистк отмет смуща съемо...
# 5   слов певиц звучан похож музык котор писа боб м...
# 6   ×обновлен пользовательск соглашениям повыша ка...
# 7   слов замглав минкультур павл степанов интернет...
# 8   граждан стран выбра музыкант лидир строчк заня...
# 9   народн артист росс миха боярск отмеча декабр с...
# 10  сатирик написа сценар картин вперв выступ каче...
# 11  саундтрек мюзикл величайш шоум поб рекорд брит...
# 12  списк успешн картин лед тренер сиквел мультфил...
# 13  ×обновлен пользовательск соглашениям повыша ка...
# 14  ×обновлен пользовательск соглашениям повыша ка...
# 15  опубликова шведск академ архивн документ говор...
# 16  популярн музыкант опубликова композиц момент з...
# 17  популярн артист счита российск шоубизнес оста ...
# 18  певец умер январ подмосков проход лечен алкого...
# 19  основ нов отечествен кинолент праздник отмеча ...
# 20  рейтинг кинокартин интересова жител рф возглав...
# 21  российск прокат кинолент обновлен вариант офиц...
# 22  жен известн российск телеведущ никол дроздов т...
# 23  создател кинокартин птич короб призыва фанат о...
# 24  настоя момент кассов сбор нов отечествен драм ...
# 25  настоя момент творческ команд будущ кинолент н...
# 26  исполнител рол промокашк культов картин мест в...
# 27  летн народн артист ссср оста больниц приеха вм...
# 28  ×обновлен пользовательск соглашениям повыша ка...
# 29  голливуд й прошл церемон вручен кинопрем золот...
# 30  британц встрет телесериал вмест сво сын марк ш...
# 31  заключительн сезон популярн телевизион шо выйд...
# 32  компан son pictures entertainment снимет продо...
# 33  прощан состо январ ритуальн зал центральн клин...
# 34  президент рф владимир путин потребова губернат...
# 35  создан культурн центр регион стран избега шабл...
# 36  премьер многострадальн американск комедийн бое...
# 37  автор картин обеща придержива феминистск предс...
# 38  планир созда мультипликацион работ ориентирова...
# 39  ×обновлен пользовательск соглашениям повыша ка...
# 40  мнен кевин файг постановщик работа блокбастер ...
# 41  композиц стал част дебютн сольн альбом марк мо...
# 42  режиссер пилотн эпизод будущ шо телекана hbo в...
# 43  мнен исполнител зрител след предупрежда матерн...
# 44  ×обновлен пользовательск соглашениям повыша ка...
# 45  дан момент автор работа друг произведен собира...
# 46  вмест певиц призна какиет вещ сцен ошеломля пр...
# 47  черныш увер исполнител рыльц пушк относ вечн м...
# 48  лидер числ номинац фильм фаворитк претенд побе...
# 49  последн российск фильм участв основн конкурсеп...

# %%
vectorizer = TfidfVectorizer()

# %%
x = []
Y = []

for lbl, cotegory in enumerate(data.columns.levels[0]):
    Y.extend([lbl for i in range(50)])
    x.extend(data[cotegory]["Text"])
x = np.array(x)
Y = np.array(Y)

# %%
X = vectorizer.fit_transform(x)
X = X.toarray()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

# %%
import matplotlib.pyplot as plt
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.model_selection import StratifiedKFold
sKFold = StratifiedKFold(n_splits=5)

# %%
cagories = data.columns.levels[0]

# %%
# %%time
from sklearn.svm import SVC
svm = SVC(kernel='sigmoid', C=3, gamma=0.5)
svm.fit(X_train, Y_train)
Y_pred_SVM = svm.predict(X_test)
# Out:
# CPU times: user 336 ms, sys: 836 µs, total: 337 ms
# Wall time: 339 ms

# %%
print "Test data F1-score: ", f1_score(Y_test, Y_pred_SVM, average='macro')
# Out:
# Test data F1-score:  0.7382851067061593

# %%
cmt_SVM = confusion_matrix(Y_test, Y_pred_SVM)
plot_confusion_matrix(cmt_SVM, classes=cagories, normalize=True)
# Out:
# Normalized confusion matrix
# [[1.         0.         0.         0.        ]
#  [0.53333333 0.4        0.06666667 0.        ]
#  [0.11111111 0.         0.88888889 0.        ]
#  [0.1        0.         0.         0.9       ]]

# %%
P = precision_score(Y_test, Y_pred_SVM, average='macro')
R = recall_score(Y_test, Y_pred_SVM, average='macro')

print 'Precision: {}, Recall: {}'.format(P, R)
# Out:
# Precision: 0.815972222222, Recall: 0.797222222222
