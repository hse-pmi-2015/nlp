# %%
import os
import spacy
from spacy import displacy
import pandas as pd
from gensim.parsing.preprocessing import *
import stop_words

# %%
# !python -m spacy download xx

# %%
# !pip install spacy

# %%
PIPELINE = ['tagger', 'parser', 'ner']

# %%
df = pd.read_csv('corpus.csv',index_col=0)

corpus = []
for topic in df:
    corpus += df[topic].tolist()
    
corpus = pd.Series(corpus)
corpus = corpus.apply(lambda x: x.lower())
corpus = corpus.apply(strip_tags)
# corpus = corpus.apply(strip_punctuation2)
# corpus = corpus.apply(strip_numeric)
# corpus = corpus.apply(lambda x: re.sub(r'\w+:\/{2}[\d\w-]+(\.[\d\w-]+)*(?:(?:\/[^\s/]*))*', u' ', x))
# corpus = corpus.apply(lambda x: re.sub('«|»', ' ', x))
# corpus = corpus.apply(strip_multiple_whitespaces)
# corpus = corpus.apply(lambda x: x.partition(' – ')[2])
# corpus = [re.sub(' +' , ' ', doc) for doc in corpus]
corpus.iloc[-1]

print(df.shape)
# Out:
# (216, 4)

# %%
# texts = [t.replace('\n', ' ') for t in texts]
texts = corpus.copy()

# %%
# nlp = spacy.load('C:/Users/User/AppData/Local/Programs/Python/Python36/Lib/site-packages/xx_ent_wiki_sm/xx_ent_wiki_sm-2.0.0')
nlp = spacy.load('C:/Users/User/Desktop/work_files/универ/linguistic/spacy-ru-master/spacy-ru-master/ru2')
# for name in PIPELINE:
#     component = nlp.create_pipe(name)

# %%
nlp.pipeline
# Out:
# [('tagger', <spacy.pipeline.Tagger at 0x21b9294bba8>),
#  ('parser', <spacy.pipeline.DependencyParser at 0x21b929c3728>),
#  ('ner', <spacy.pipeline.EntityRecognizer at 0x21b929c3780>)]

# %%
# %%time

docs = [nlp(txt) for txt in texts[:50]]
# Out:
# Wall time: 3.46 s

# %%
df_pos = pd.DataFrame(columns=['Text', 'Lemma', 'POS', 'TAG', 'DEP', 'Shape', 'Stop Word'])

for token in docs[10]:
    df_pos = df_pos.append({'Text': token.text, 'Lemma': token.lemma_, 'POS': token.pos_, 'TAG': token.tag_, 
                            'DEP': token.dep_, 'Shape': token.shape_, 'Stop Word': token.is_stop}, ignore_index=True)
    
df_pos.head(1000000)
# Out:
#                Text           Lemma    POS  \
# 0                 [               [  PUNCT
# 1              \r\n            \r\n  SPACE
# 2        мурманская      мурманский    ADJ
# 3          область/        область/   NOUN
# 4                14              14    NUM
# 5           января/         января/   NOUN
# 6                би              би   NOUN
# 7                 -               -  PUNCT
# 8              порт            порт   NOUN
# 9                 -               -  PUNCT
# 10          вечером           вечер   NOUN
# 11               13              13    NUM
# 12           января          январь   NOUN
# 13               на              на    ADP
# 14             1277            1277    NUM
# 15               км        километр   NOUN
# 16       автодороги      автодороги   NOUN
# 17             р-21            р-21   NOUN
# 18                «               "  PUNCT
# 19             кола            кола   NOUN
# 20                »               »    AUX
# ...

# %% [markdown]
# ## NER

# %% [markdown]
# ### [annotation types](https://spacy.io/usage/linguistic-features#entity-types)

# %%
for doc in docs:
    displacy.render(doc, style='ent', jupyter=True)
    print('=============================================================================================================')
# Out:
# </br>мурманск/
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     17
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  января/ би-порт – на кольском проспекте в районе перекрёстка на улице шевченко произошло дорожно-транспортное происшествие. столкнулись «лада» и ваз.
# по предварительной информации в одной из искорёженных машин заблокирована девушка-пассажир. спасатели пытаются её достать из автомобиля. кроме мчс на месте работают сотрудники скорой помощи и дпс. ]</div>
# ...
# </br>мурманск/
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
# ...

# %%
df_ent = pd.DataFrame(columns=['Text', 'Start Char', 'End Char', 'Label'])

for ent in docs[10].ents:
    df_ent = df_ent.append({'Text': ent.text, 'Start Char': ent.start_char, 'End Char': ent.end_char, 'Label': ent.label_},
                           ignore_index=True)
    
df_ent.head(10000000)
# Out:
#            Text Start Char End Char     Label
# 0            14         23       25  CARDINAL
# 1            13         52       54  CARDINAL
# 2          1277         65       69      DATE
# 3  21:04.«ехала        201      213  CARDINAL
# 4    фольц.поло        232      242    PERSON
# 5        полосу        278      284  CARDINAL

# %% [markdown]
# ## Dependency Parsing

# %%
for sent in docs[10].sents:
    print(sent)
    tmp_doc = sent.as_doc()
    tmp_doc.user_data['title'] = sent.text
    displacy.render(tmp_doc, style='dep', jupyter=True, options={'compact': True})
# Out:
# [
# мурманская область/ 14 января/ би-порт - вечером 13 января на 1277 км автодороги р-21 «кола» произошло дтп с участием пяти автомобилей, в том числе грузового. информация об аварии поступила в мчс в 21:04.«ехала в одной из машин, фольц.поло, который вынесло в сугроб на левую полосу. так и не успели понять, откуда он взялся, приехал к нам в водительскую дверь. у нас в машине все целы, подушки сработали, и все были пристёгнуты. а вот в мерседесе не поняла, все ли в порядке», - пишет в социальной сети «вконтакте» валерия лавёрова.по сообщению очевидцев, в результате аварии никто серьёзно не пострадал. обстоятельства выясняются. ]
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" id="393-0" class="displacy" width="15200" height="1337.0" style="max-width: none; height: 1337.0px; color: #000000; background: #ffffff; font-family: Arial">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1247.0">
# ...

# %%
with open('C:/Users/User/Desktop/work_files/универ/linguistic/1grams-3/1grams-3.txt',encoding='utf8',) as file:
    word_forms = file.readlines()

# %%
word_forms = pd.Series(word_forms)

# %%
# word_forms.str.split('\t')
word_forms = word_forms.apply(lambda x: x.split('\n')[0])
words_list = word_forms.apply(lambda x: x.split('\t')[1])
freq_list = word_forms.apply(lambda x: x.split('\t')[0])
word_forms = pd.Series(data=freq_list.values,index=words_list.values)

# %%
word_forms.index = word_forms.index.str.lower()

# %%
tt = pd.DataFrame(data=[words_list.values,freq_list.values],columns = ['word','freq'])
# tt.drop_duplicates('word',inplace = True)
# tt.shape
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-17-4c5aebe37b59> in <module>()
# ----> 1 tt = pd.DataFrame(data=[words_list.values,freq_list.values],columns = ['word','freq'])
#       2 # tt.drop_duplicates('word',inplace = True)
#       3 # tt.shape
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     367                     if is_named_tuple(data[0]) and columns is None:
#     368                         columns = data[0]._fields
# --> 369                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     370                     columns = _ensure_index(columns)
#     371
#
# c:\users\user\appdata\local\programs\python\python36\lib\site-packages\pandas\core\frame.py in _to_arrays(data, columns, coerce_float, dtype)
# ...

# %%
words_list
# Out:
# 0                   и
# 1                   в
# 2                  не
# 3                  на
# 4                   с
# 5                 что
# 6                 как
# 7                   я
# 8                   к
# 9                  он
# 10                 по
# 11                  а
# 12                его
# 13                 из
# 14                это
# 15                 от
# 16                все
# 17                 за
# 18                  у
# 19                 же
# 20                 то
# 21                  В
# 22                 но
# 23                  о
# 24                  И
# 25                  А
# 26               было
# 27                для
# 28                так
# 29                  Я
#               ...
# 1054180     ячейковые
# 1054181          ячея
# 1054182       ячменек
# 1054183      ячменною
# 1054184         ячною
# 1054185           яша
# 1054186       яшмовой
# 1054187      яшмовыми
# 1054188         яшшик
# 1054189         ящере
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
vectorizer.fit(corpus)
X = vectorizer.transform(corpus)
vocab = vectorizer.vocabulary_
lv = len(vocab)

# %%
vectorizer.fit([corpus[doc_idx]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-3d29dee54982> in <module>()
# ----> 1 vectorizer.fit([corpus[doc_idx]])
#
# NameError: name 'doc_idx' is not defined

# %%
import numpy as np

# %%
word_forms['мурманск']
# Out:
# '331'

# %%
val = 0
i = 0
for doc_idx in range(len(corpus)):
    vectorizer = CountVectorizer()
    vectorizer.fit([corpus[doc_idx]])
#     x = vectorizer.transform(corpus[doc_idx])
    for word in vectorizer.vocabulary_.keys():
        try:
            freq = int(word_forms[word])/shit
            n_w = vectorizer.vocabulary_[word]
            val +=np.log((freq))*n_w 
        except:
            continue
np.exp(-val/lv)

# %%
def perplexity(docs):
    docs = np.asarray(docs)
    out_of_dict = []
    
    tmp_sum_docs = 0.0
    N = 0.0
    for doc in log_progress(docs):
        tmp_sum_words = 0.0
        for word in log_progress(words):
            freq = frequencies.get(word, TOL)
            freq_empirical = frequencies_empirical.get(word, 0.0)
            N += freq_empirical
            if freq == TOL:
                out_of_dict.append(word)
            tmp_sum_words += freq_empirical * np.log(freq)
        tmp_sum_docs += tmp_sum_words
        
    return np.exp(-tmp_sum_docs / N), out_of_dict

# %%
shit = 0
for freq in word_forms:
    shit += int(freq)

# %%
shit
# Out:
# 190827174

# %%
corpus[len(corpus)-1]
# Out:
# '[\r\nвенгрия/ 7 августа/ би-порт – сегодня в городе тольна соберутся 25 победителей ii международного творческого детского фотоконкурса «в объятиях природы». организаторами масштабного проекта выступают фонд содействия развитию муниципальных образований «ассоциация территорий расположения атомных электростанций», ао «концерн росэнергоатом» и венгерская аэс «пакш».\r\nгород полярные зори представят виктория серебренникова и екатерина таранникова. в течение десяти дней в рамках работы экологического лагеря ребят ждёт увлекательная экскурсионная программа по москве с визитом в экспозиционный центр концерна «росэнергоатом» и будапеште. в тольна российские школьники посетят серию мастер-классов от известного профессионального фотохудожника балинта винце.\r\nберег реки дунай, маковые поля, рыболовные пруды, венгерские деревушки и аэс «пакш» - список мест проведения уроков фотоискусства. запланированы и съемки метеоритного дождя.\r\nитогом экологического лагеря станут не только прекрасные 
# ...

# %%
X[0].todense()

# %%
vectorizer.vocabulary_
